# %% [markdown]
# # Sinhala → SSL Translation — Separate Decoder Vocabulary
# ## Architecture: XLM-RoBERTa Encoder + Custom SSL-Only Decoder Vocab
# ---
# **Key difference from previous version:**
# - Encoder input : XLM-RoBERTa tokenizer (250k vocab) — understands Sinhala
# - Decoder output: SSL-only vocabulary (~1,200 tokens) — **cannot predict outside SSL**
# - Model is architecturally impossible to output any non-SSL token

# %%
# !pip install transformers sentencepiece "sympy>=1.13.3" -q

import torch
print("PyTorch :", torch.__version__)
print("CUDA    :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU     :", torch.cuda.get_device_name(0))
    print("VRAM    :", round(torch.cuda.get_device_properties(0).total_memory/1e9,1), "GB")
# Out:
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
import os

class CFG:
    # ── Paths ──────────────────────────────────────────────────────────
    CORPUS_FILE   = "/kaggle/input/datasets/nadeenudantha/full-corpus-final/full-corpus.txt"
    OUTPUT_DIR    = "/kaggle/working/"
    MODEL_DIR     = "/kaggle/working/models"
    LOG_FILE      = "/kaggle/working/training_log.csv"

    # ── Encoder: mT5-base (input side only) ─────────────────────────
    ENCODER_MODEL = "google/mt5-base"
    ENC_DIM       = 768
    ENC_HEADS     = 12

    # ── Decoder: SSL-only vocabulary (output side) ─────────────────────
    PAD_IDX  = 0
    BOS_IDX  = 1
    EOS_IDX  = 2
    UNK_IDX  = 3
    OFFSET   = 4

    D_MODEL      = 512
    N_HEADS      = 8
    N_DEC_LAYERS = 4
    DIM_FFN      = 2048
    DROPOUT      = 0.1
    MAX_SRC_LEN  = 64
    MAX_TGT_LEN  = 32

    # ── Training (Lowered LRs for stability) ───────────────────────────
    EPOCHS       = 50
    BATCH_SIZE   = 16
    ENCODER_LR   = 1e-5
    DECODER_LR   = 1e-4
    WEIGHT_DECAY = 1e-2
    WARMUP_RATIO = 0.1
    GRAD_CLIP    = 1.0
    ACCUM_STEPS  = 2
    LABEL_SMOOTH = 0.1
    PATIENCE     = 10

    # ── Split ──────────────────────────────────────────────────────────
    TEST_RATIO   = 0.15
    VAL_RATIO    = 0.10
    SEED         = 42

    # ── Memory (Disabled AMP for nan-fix) ──────────────────────────────
    USE_AMP      = False
    GRAD_CKPT    = True
    NUM_WORKERS  = 2
    PIN_MEMORY   = True

os.makedirs(CFG.MODEL_DIR, exist_ok=True)
print("Config updated: Lower LRs and AMP=False to fix nan issues.")
# Out:
# Config updated: Lower LRs and AMP=False to fix nan issues.

# %%
import re, json, math, random, warnings
from pathlib import Path
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler, autocast
# MT5 uses the T5Tokenizer class internally
from transformers import T5Tokenizer, MT5EncoderModel, get_linear_schedule_with_warmup

warnings.filterwarnings("ignore")

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(CFG.SEED)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
class SSLVocabulary:
    """
    Dedicated decoder-side vocabulary containing ONLY your SSL gloss words.
    ─────────────────────────────────────────────────────────────────────
    Special tokens:
        0 → <PAD>
        1 → <BOS>
        2 → <EOS>
        3 → <UNK>

    Real SSL tokens start at index 4.

    The decoder output_proj layer has exactly SSL_VOCAB_SIZE outputs.
    It is architecturally impossible for the model to predict
    any token outside this vocabulary.
    """

    SPECIAL = {
        "<PAD>": 0,
        "<BOS>": 1,
        "<EOS>": 2,
        "<UNK>": 3,
    }

    def __init__(self):
        self.word2idx : Dict[str, int] = dict(self.SPECIAL)
        self.idx2word : Dict[int, str] = {v: k for k, v in self.SPECIAL.items()}
        self.word2id  : Dict[str, int] = {}   # gloss word → original SSL ID
        self.id2word  : Dict[int, str] = {}   # original SSL ID → gloss word

    # ── Build from corpus ──────────────────────────────────────────────
    def build(self, pairs: List[Dict]) -> "SSLVocabulary":
        idx = CFG.OFFSET   # start after special tokens
        for pair in pairs:
            for word, tid in zip(pair["gloss_words"], pair["target_ids"]):
                # Register SSL sign ID mapping
                self.word2id[word] = tid
                self.id2word[tid]  = word
                # Register in decoder vocab if new
                if word not in self.word2idx:
                    self.word2idx[word] = idx
                    self.idx2word[idx]  = word
                    idx += 1
        print(f"SSL decoder vocabulary:")
        print(f"  Special tokens  : 4  (PAD, BOS, EOS, UNK)")
        print(f"  SSL gloss words : {idx - CFG.OFFSET}")
        print(f"  Total vocab size: {idx}  ← decoder output size")
        print(f"  XLM-R vocab size: 250,002  ← encoder input size")
        print(f"  Model can ONLY output one of {idx} tokens")
        return self

    @property
    def size(self) -> int:
        return len(self.word2idx)

    # ── Encode/decode ──────────────────────────────────────────────────
    def encode(self, words: List[str]) -> List[int]:
        """Convert list of gloss words → decoder indices."""
        return [self.word2idx.get(w, CFG.UNK_IDX) for w in words]

    def decode(self, indices: List[int]) -> List[str]:
        """Convert decoder indices → gloss words (skip special tokens)."""
        return [
            self.idx2word[i] for i in indices
            if i >= CFG.OFFSET and i in self.idx2word
        ]

    def word_to_ssl_id(self, word: str) -> Optional[int]:
        """Get original SSL sign ID for a gloss word."""
        return self.word2id.get(word)

    # ── Save / load ────────────────────────────────────────────────────
    def save(self, path: str):
        data = {
            "word2idx": self.word2idx,
            "idx2word": {str(k): v for k, v in self.idx2word.items()},
            "word2id" : self.word2id,
            "id2word" : {str(k): v for k, v in self.id2word.items()},
        }
        with open(path, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"✓ SSL vocabulary saved → {path}")

    @classmethod
    def load(cls, path: str) -> "SSLVocabulary":
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)
        v = cls()
        v.word2idx = data["word2idx"]
        v.idx2word = {int(k): w for k, w in data["idx2word"].items()}
        v.word2id  = data["word2id"]
        v.id2word  = {int(k): w for k, w in data["id2word"].items()}
        return v

# %%
class CorpusParser:
    """
    Parses: sentence @ id:word | id:word | ...

    Encoder input  : Sinhala text  (tokenized by XLM-RoBERTa)
    Decoder output : SSL indices   (from SSLVocabulary, not XLM-R)
    """

    def __init__(self):
        self.pairs: List[Dict] = []

    def parse_file(self, path: str) -> "CorpusParser":
        with open(path, "r", encoding="utf-8") as f:
            raw = f.read()
        skipped = 0
        for line in raw.strip().splitlines():
            line = line.strip()
            if not line or "@" not in line:
                skipped += 1
                continue
            pair = self._parse_line(line)
            if pair:
                self.pairs.append(pair)
        print(f"✓ Parsed {len(self.pairs)} pairs | skipped {skipped}")
        return self

    def _parse_line(self, line: str) -> Optional[Dict]:
        src_raw, tgt_raw = line.split("@", 1)
        source      = src_raw.strip()
        gloss_words = []
        target_ids  = []
        for item in tgt_raw.strip().split("|"):
            item = item.strip()
            if ":" not in item:
                continue
            tid_str, word = item.split(":", 1)
            word = word.strip()
            try:    tid = int(tid_str.strip())
            except: continue
            gloss_words.append(word)
            target_ids.append(tid)
        if not gloss_words:
            return None
        return {
            "source"     : source,
            "gloss_words": gloss_words,
            "target_ids" : target_ids,
        }


# ── Parse + build SSL vocab ────────────────────────────────────────────
parser   = CorpusParser().parse_file(CFG.CORPUS_FILE)
ssl_vocab = SSLVocabulary().build(parser.pairs)
ssl_vocab.save(f"{CFG.MODEL_DIR}/ssl_vocab.json")

# Stats
src_lens = [len(p["source"].split())  for p in parser.pairs]
tgt_lens = [len(p["gloss_words"])     for p in parser.pairs]
print(f"\nDataset stats:")
print(f"  Pairs          : {len(parser.pairs)}")
print(f"  Max src words  : {max(src_lens)}")
print(f"  Max tgt words  : {max(tgt_lens)}")
print(f"  Avg tgt words  : {sum(tgt_lens)/len(tgt_lens):.1f}")
# Out:
# ✓ Parsed 9581 pairs | skipped 1
# SSL decoder vocabulary:
#   Special tokens  : 4  (PAD, BOS, EOS, UNK)
#   SSL gloss words : 1519
#   Total vocab size: 1523  ← decoder output size
#   XLM-R vocab size: 250,002  ← encoder input size
#   Model can ONLY output one of 1523 tokens
# ✓ SSL vocabulary saved → /kaggle/working/models/ssl_vocab.json
#
# Dataset stats:
#   Pairs          : 9581
#   Max src words  : 12
#   Max tgt words  : 20
#   Avg tgt words  : 5.0

# %%
def split_dataset(pairs):
    random.seed(CFG.SEED)
    data = pairs.copy()
    random.shuffle(data)
    n       = len(data)
    n_test  = max(1, int(n * CFG.TEST_RATIO))
    n_val   = max(1, int(n * CFG.VAL_RATIO))
    n_train = n - n_test - n_val
    train = data[:n_train]
    val   = data[n_train : n_train + n_val]
    test  = data[n_train + n_val :]
    print(f"Split → Train:{len(train)}  Val:{len(val)}  Test:{len(test)}")
    return train, val, test

train_pairs, val_pairs, test_pairs = split_dataset(parser.pairs)

for name, pairs in [("train", train_pairs),
                     ("val",   val_pairs),
                     ("test",  test_pairs)]:
    pd.DataFrame([{"source": p["source"],
                   "target": " ".join(p["gloss_words"])}
                  for p in pairs]).to_csv(
        f"{CFG.OUTPUT_DIR}/{name}_split.csv",
        index=False, encoding="utf-8")
print("✓ Split CSVs saved")
# Out:
# Split → Train:7186  Val:958  Test:1437
# ✓ Split CSVs saved

# %%
print(f"Loading encoder tokenizer: {CFG.ENCODER_MODEL}")
# Changed from MT5Tokenizer to T5Tokenizer
enc_tokenizer = T5Tokenizer.from_pretrained(CFG.ENCODER_MODEL)

# Quick check
sample = "අපි මගේ අම්මාට හරිම ආදරෙයි"
print(f"Sample tokenization: {enc_tokenizer.tokenize(sample)}")

class SinhalaSSLDataset(Dataset):
    def __init__(self, pairs, enc_tokenizer, ssl_vocab: SSLVocabulary):
        self.pairs         = pairs
        self.enc_tokenizer = enc_tokenizer
        self.ssl_vocab     = ssl_vocab

    def __len__(self): return len(self.pairs)

    def __getitem__(self, idx):
        pair = self.pairs[idx]
        src = self.enc_tokenizer(
            pair["source"],
            max_length    = CFG.MAX_SRC_LEN,
            padding       = "max_length",
            truncation    = True,
            return_tensors= "pt",
        )
        ssl_indices = self.ssl_vocab.encode(pair["gloss_words"])
        dec_input  = [CFG.BOS_IDX] + ssl_indices
        dec_target = ssl_indices   + [CFG.EOS_IDX]

        def pad(seq):
            seq = seq[:CFG.MAX_TGT_LEN]
            return seq + [CFG.PAD_IDX] * (CFG.MAX_TGT_LEN - len(seq))

        return {
            "input_ids"     : src["input_ids"].squeeze(0),
            "attention_mask": src["attention_mask"].squeeze(0),
            "dec_input"     : torch.tensor(pad(dec_input),  dtype=torch.long),
            "dec_target"    : torch.tensor(pad(dec_target), dtype=torch.long),
            "source_text"   : pair["source"],
            "gloss_words"   : pair["gloss_words"],
            "target_ids"    : pair["target_ids"],
        }

def collate_fn(batch):
    return {
        "input_ids"     : torch.stack([b["input_ids"]      for b in batch]),
        "attention_mask": torch.stack([b["attention_mask"]  for b in batch]),
        "dec_input"     : torch.stack([b["dec_input"]       for b in batch]),
        "dec_target"    : torch.stack([b["dec_target"]      for b in batch]),
        "source_text"   : [b["source_text" ]                for b in batch],
        "gloss_words"   : [b["gloss_words"]                 for b in batch],
        "target_ids"    : [b["target_ids"]                  for b in batch],
    }

train_ds = SinhalaSSLDataset(train_pairs, enc_tokenizer, ssl_vocab)
val_ds   = SinhalaSSLDataset(val_pairs,   enc_tokenizer, ssl_vocab)
test_ds  = SinhalaSSLDataset(test_pairs,  enc_tokenizer, ssl_vocab)

train_dl = DataLoader(train_ds, batch_size=CFG.BATCH_SIZE, shuffle=True,
                      collate_fn=collate_fn, num_workers=CFG.NUM_WORKERS,
                      pin_memory=CFG.PIN_MEMORY)
val_dl   = DataLoader(val_ds,   batch_size=CFG.BATCH_SIZE, shuffle=False,
                      collate_fn=collate_fn, num_workers=CFG.NUM_WORKERS,
                      pin_memory=CFG.PIN_MEMORY)
test_dl  = DataLoader(test_ds,  batch_size=CFG.BATCH_SIZE, shuffle=False,
                      collate_fn=collate_fn, num_workers=CFG.NUM_WORKERS,
                      pin_memory=CFG.PIN_MEMORY)

print(f"Dataloaders ready. mT5 vocab size: {enc_tokenizer.vocab_size}")
# Out:
# Loading encoder tokenizer: google/mt5-base
# tokenizer_config.json:   0%|          | 0.00/376 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Sample tokenization: ['▁', 'අපි', '▁ම', 'ගේ', '▁', 'අම්ම', 'ාට', '▁හරි', 'ම', '▁ආ', 'දර', 'ෙයි']
# Dataloaders ready. mT5 vocab size: 250100

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512, dropout=0.1):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe  = torch.zeros(max_len, d_model)
        pos = torch.arange(max_len).unsqueeze(1).float()
        div = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self, x):
        return self.dropout(x + self.pe[:, :x.size(1)])

class SinhalaSSLTransformer(nn.Module):
    def __init__(self, encoder, ssl_vocab: SSLVocabulary, cfg=CFG):
        super().__init__()
        self.cfg      = cfg
        self.ssl_vocab = ssl_vocab
        ssl_vocab_size = ssl_vocab.size

        self.encoder = encoder
        if cfg.GRAD_CKPT:
            self.encoder.gradient_checkpointing_enable()

        self.enc_proj = nn.Linear(cfg.ENC_DIM, cfg.D_MODEL) if cfg.ENC_DIM != cfg.D_MODEL else nn.Identity()

        self.dec_embedding = nn.Embedding(ssl_vocab_size, cfg.D_MODEL, padding_idx=cfg.PAD_IDX)
        nn.init.normal_(self.dec_embedding.weight, std=0.02)
        self.pos_enc = PositionalEncoding(cfg.D_MODEL, max_len=cfg.MAX_TGT_LEN + 10, dropout=cfg.DROPOUT)

        dec_layer = nn.TransformerDecoderLayer(
            d_model=cfg.D_MODEL,
            nhead=cfg.N_HEADS,
            dim_feedforward=cfg.DIM_FFN,
            dropout=cfg.DROPOUT,
            batch_first=True,
            norm_first=True
        )
        self.decoder = nn.TransformerDecoder(dec_layer, num_layers=cfg.N_DEC_LAYERS)
        self.output_proj = nn.Linear(cfg.D_MODEL, ssl_vocab_size, bias=False)

    def encode(self, input_ids, attention_mask):
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        hidden = outputs.last_hidden_state
        return self.enc_proj(hidden)

    def decode_step(self, tgt_ids, memory, attn_mask=None):
        tgt_len  = tgt_ids.size(1)
        # Fixed: mask generation parameters for consistency
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt_len).to(tgt_ids.device)
        tgt_pad  = (tgt_ids == CFG.PAD_IDX)
        mem_pad  = (attn_mask == 0) if attn_mask is not None else None
        tgt_emb  = self.pos_enc(self.dec_embedding(tgt_ids))
        return self.decoder(
            tgt=tgt_emb,
            memory=memory,
            tgt_mask=tgt_mask,
            tgt_key_padding_mask=tgt_pad,
            memory_key_padding_mask=mem_pad
        )

    def forward(self, input_ids, attention_mask, dec_input):
        memory  = self.encode(input_ids, attention_mask)
        dec_out = self.decode_step(dec_input, memory, attention_mask)
        return self.output_proj(dec_out)

print(f"Loading mT5 encoder: {CFG.ENCODER_MODEL}")
encoder = MT5EncoderModel.from_pretrained(CFG.ENCODER_MODEL)
model   = SinhalaSSLTransformer(encoder, ssl_vocab, CFG).to(DEVICE)

def token_accuracy(logits, targets):
    preds = logits.argmax(dim=-1)
    mask = (targets != CFG.PAD_IDX)
    correct = (preds == targets) & mask
    return correct.sum().item() / mask.sum().item() if mask.sum() > 0 else 0.0
# Out:
# Loading mT5 encoder: google/mt5-base
# config.json:   0%|          | 0.00/702 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 116, in auto_conversion
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 95, in auto_conversion
#     sha = get_conversion_pr_reference(api, pretrained_model_name_or_path, **cached_file_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 71, in get_conversion_pr_reference
#     spawn_conversion(token, private, model_id)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 47, in spawn_conversion
#     result = httpx.post(sse_url, follow_redirects=True, json=data).json()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 832, in json
#     return jsonlib.loads(self.content, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/decoder.py", line 338, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/json/decoder.py", line 356, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Loading weights:   0%|          | 0/112 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# MT5EncoderModel LOAD REPORT from: google/mt5-base
# Key                                                                  | Status     |  |
# ---------------------------------------------------------------------+------------+--+-
# decoder.block.{0...11}.layer.{0, 1, 2}.layer_norm.weight             | UNEXPECTED |  |
# decoder.block.{0...11}.layer.0.SelfAttention.v.weight                | UNEXPECTED |  |
# decoder.block.{0...11}.layer.1.EncDecAttention.k.weight              | UNEXPECTED |  |
# decoder.block.{0...11}.layer.0.SelfAttention.k.weight                | UNEXPECTED |  |
# decoder.block.{0...11}.layer.2.DenseReluDense.wo.weight              | UNEXPECTED |  |
# decoder.block.{0...11}.layer.0.SelfAttention.o.weight                | UNEXPECTED |  |
# decoder.embed_tokens.weight                                          | UNEXPECTED |  |
# decoder.block.{0...11}.layer.0.SelfAttention.q.weight                | UNEXPECTED |  |
# decoder.block.{0...11}.layer.2.DenseReluDense.wi_0.weight            | UNEXPECTED |  |
# decoder.block.{0...11}.layer.1.EncDecAttention.v.weight              | UNEXPECTED |  |
# decoder.block.{0...11}.layer.1.EncDecAttention.o.weight              | UNEXPECTED |  |
# decoder.block.{0...11}.layer.2.DenseReluDense.wi_1.weight            | UNEXPECTED |  |
# decoder.final_layer_norm.weight                                      | UNEXPECTED |  |
# decoder.block.{0...11}.layer.1.EncDecAttention.q.weight              | UNEXPECTED |  |
# lm_head.weight                                                       | UNEXPECTED |  |
# decoder.block.0.layer.0.SelfAttention.relative_attention_bias.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
optimizer = torch.optim.AdamW([
    {"params": model.encoder.parameters(),
     "lr": CFG.ENCODER_LR, "weight_decay": CFG.WEIGHT_DECAY},
    {"params": model.decoder.parameters(),
     "lr": CFG.DECODER_LR, "weight_decay": CFG.WEIGHT_DECAY},
    {"params": model.dec_embedding.parameters(),
     "lr": CFG.DECODER_LR, "weight_decay": 0.0},
    {"params": model.output_proj.parameters(),
     "lr": CFG.DECODER_LR, "weight_decay": 0.0},
    {"params": model.enc_proj.parameters(),
     "lr": CFG.DECODER_LR, "weight_decay": 0.0},
], eps=1e-8)

total_steps  = (len(train_dl) // CFG.ACCUM_STEPS) * CFG.EPOCHS
warmup_steps = int(total_steps * CFG.WARMUP_RATIO)

scheduler = get_linear_schedule_with_warmup(
    optimizer, warmup_steps, total_steps)
scaler    = GradScaler(enabled=CFG.USE_AMP)
criterion = nn.CrossEntropyLoss(
    ignore_index=CFG.PAD_IDX, label_smoothing=CFG.LABEL_SMOOTH)

print(f"Total steps  : {total_steps}")
print(f"Warmup steps : {warmup_steps}")
# Out:
# Total steps  : 11250
# Warmup steps : 1125

# %%
history = {"epoch":[], "train_loss":[], "val_loss":[],
           "train_acc":[], "val_acc":[]}

best_val_loss    = float("inf")
best_epoch       = 0
patience_counter = 0

def train_epoch():
    model.train()
    tot_loss = tot_acc = 0.0
    optimizer.zero_grad()
    for step, batch in enumerate(train_dl):
        ids   = batch["input_ids"].to(DEVICE)
        mask  = batch["attention_mask"].to(DEVICE)
        d_in  = batch["dec_input"].to(DEVICE)
        d_tgt = batch["dec_target"].to(DEVICE)
        with autocast(enabled=CFG.USE_AMP):
            logits = model(ids, mask, d_in)
            loss   = criterion(
                logits.reshape(-1, ssl_vocab.size),
                d_tgt.reshape(-1)) / CFG.ACCUM_STEPS
        scaler.scale(loss).backward()
        if (step + 1) % CFG.ACCUM_STEPS == 0:
            scaler.unscale_(optimizer)
            nn.utils.clip_grad_norm_(model.parameters(), CFG.GRAD_CLIP)
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            optimizer.zero_grad()
        tot_loss += loss.item() * CFG.ACCUM_STEPS
        tot_acc  += token_accuracy(logits.detach(), d_tgt)
    return tot_loss / len(train_dl), tot_acc / len(train_dl)

@torch.no_grad()
def validate(dl):
    model.eval()
    tot_loss = tot_acc = 0.0
    for batch in dl:
        ids   = batch["input_ids"].to(DEVICE)
        mask  = batch["attention_mask"].to(DEVICE)
        d_in  = batch["dec_input"].to(DEVICE)
        d_tgt = batch["dec_target"].to(DEVICE)
        with autocast(enabled=CFG.USE_AMP):
            logits = model(ids, mask, d_in)
            loss   = criterion(
                logits.reshape(-1, ssl_vocab.size),
                d_tgt.reshape(-1))
        tot_loss += loss.item()
        tot_acc  += token_accuracy(logits, d_tgt)
    return tot_loss / len(dl), tot_acc / len(dl)

print(f"{'─'*68}")
print(f"{'Epoch':>6} | {'TrainLoss':>9} | {'ValLoss':>7} | "
      f"{'TrainAcc':>8} | {'ValAcc':>6} | {'':>8}")
print(f"{'─'*68}")

for epoch in range(1, CFG.EPOCHS + 1):
    tr_loss, tr_acc = train_epoch()
    vl_loss, vl_acc = validate(val_dl)
    history["epoch"].append(epoch)
    history["train_loss"].append(tr_loss)
    history["val_loss"].append(vl_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(vl_acc)
    note = ""
    if not math.isnan(vl_loss) and vl_loss < best_val_loss:
        best_val_loss    = vl_loss
        best_epoch       = epoch
        patience_counter = 0
        note             = "✓ best"
        torch.save({"epoch": epoch, "model_state": model.state_dict(), "val_loss": vl_loss, "val_acc": vl_acc, "ssl_vocab_size": ssl_vocab.size}, f"{CFG.MODEL_DIR}/best_model.pt")
    else:
        patience_counter += 1
        if patience_counter >= CFG.PATIENCE:
            print(f"\nEarly stopping at epoch {epoch}")
            break
    print(f"{epoch:6d} | {tr_loss:9.4f} | {vl_loss:7.4f} | {tr_acc*100:7.2f}% | {vl_acc*100:5.2f}% | {note}")
# Out:
# ────────────────────────────────────────────────────────────────────
#  Epoch | TrainLoss | ValLoss | TrainAcc | ValAcc |
# ────────────────────────────────────────────────────────────────────
#      1 |    6.0766 |  5.0123 |   15.16% | 22.19% | ✓ best
#      2 |    4.8001 |  4.4423 |   23.76% | 26.02% | ✓ best
#      3 |    4.3194 |  4.0703 |   29.34% | 35.09% | ✓ best
#      4 |    3.9450 |  3.7201 |   37.02% | 42.50% | ✓ best
#      5 |    3.6651 |  3.5157 |   42.63% | 45.15% | ✓ best
#      6 |    3.4033 |  3.1627 |   47.20% | 53.64% | ✓ best
#      7 |    3.0956 |  2.8681 |   53.82% | 60.92% | ✓ best
#      8 |    2.8254 |  2.5932 |   59.79% | 67.52% | ✓ best
#      9 |    2.5734 |  2.4062 |   65.44% | 71.54% | ✓ best
#     10 |    2.3881 |  2.2595 |   68.93% | 74.84% | ✓ best
#     11 |    2.2173 |  2.0821 |   73.02% | 78.90% | ✓ best
#     12 |    2.0685 |  2.0000 |   76.46% | 81.53% | ✓ best
#     13 |    1.9639 |  1.9378 |   79.54% | 83.18% | ✓ best
#     14 |    1.8880 |  1.9006 |   81.06% | 83.47% | ✓ best
#     15 |    1.8300 |  1.8606 |   82.64% | 84.38% | ✓ best
#     16 |    1.7565 |  1.7879 |   84.43% | 86.31% | ✓ best
#     17 |    1.7062 |  1.7449 |   85.72% | 87.25% | ✓ best
#     18 |    1.6640 |  1.7239 |   86.71% | 88.03% | ✓ best
#     19 |    1.6295 |  1.7029 |   87.53% | 88.56% | ✓ best
#     20 |    1.5835 |  1.6779 |   88.77% | 89.23% | ✓ best
#     21 |    1.5550 |  1.6452 |   89.53% | 89.89% | ✓ best
#     22 |    1.5248 |  1.6462 |   90.21% | 89.93% |
#     23 |    1.5068 |  1.6159 |   90.82% | 90.45% | ✓ best
#     24 |    1.4738 |  1.6082 |   91.72% | 91.06% | ✓ best
#     25 |    1.4605 |  1.5900 |   91.92% | 91.49% | ✓ best
#     26 |    1.4305 |  1.5821 |   92.76% | 91.65% | ✓ best
#     27 |    1.4200 |  1.5728 |   93.15% | 92.06% | ✓ best
#     28 |    1.4061 |  1.5532 |   93.46% | 92.23% | ✓ best
#     29 |    1.3872 |  1.5620 |   94.11% | 92.14% |
#     30 |    1.3745 |  1.5521 |   94.23% | 92.58% | ✓ best
#     31 |    1.3601 |  1.5440 |   94.57% | 92.58% | ✓ best
#     32 |    1.3485 |  1.5310 |   94.80% | 92.80% | ✓ best
#     33 |    1.3350 |  1.5266 |   95.40% | 92.72% | ✓ best
#     34 |    1.3267 |  1.5232 |   95.57% | 92.54% | ✓ best
#     35 |    1.3228 |  1.5172 |   95.62% | 92.72% | ✓ best
#     36 |    1.3101 |  1.5165 |   96.11% | 92.98% | ✓ best
#     37 |    1.3037 |  1.5065 |   96.13% | 93.08% | ✓ best
#     38 |    1.2927 |  1.5024 |   96.51% | 93.20% | ✓ best
#     39 |    1.2877 |  1.5008 |   96.63% | 93.23% | ✓ best
#     40 |    1.2839 |  1.4959 |   96.78% | 93.20% | ✓ best
#     41 |    1.2741 |  1.4963 |   96.91% | 93.26% |
#     42 |    1.2717 |  1.4923 |   96.99% | 93.21% | ✓ best
#     43 |    1.2629 |  1.4855 |   97.29% | 93.35% | ✓ best
#     44 |    1.2612 |  1.4888 |   97.24% | 93.34% |
#     45 |    1.2578 |  1.4872 |   97.48% | 93.31% |
#     46 |    1.2529 |  1.4842 |   97.46% | 93.33% | ✓ best
#     47 |    1.2536 |  1.4831 |   97.41% | 93.38% | ✓ best
#     48 |    1.2489 |  1.4803 |   97.59% | 93.41% | ✓ best
#     49 |    1.2471 |  1.4782 |   97.69% | 93.47% | ✓ best
#     50 |    1.2467 |  1.4784 |   97.64% | 93.41% |

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle("Training History — SSL-Only Decoder Vocab", fontsize=13)
epochs = history["epoch"]

axes[0].plot(epochs, history["train_loss"], label="Train", color="#2563eb", lw=2)
axes[0].plot(epochs, history["val_loss"],   label="Val",   color="#dc2626", lw=2)
axes[0].axvline(best_epoch, color="#16a34a", linestyle="--", alpha=0.7,
                label=f"Best (ep {best_epoch})")
axes[0].set_title("Loss"); axes[0].set_xlabel("Epoch")
axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(epochs, [a*100 for a in history["train_acc"]],
             label="Train", color="#2563eb", lw=2)
axes[1].plot(epochs, [a*100 for a in history["val_acc"]],
             label="Val",   color="#dc2626", lw=2)
axes[1].axvline(best_epoch, color="#16a34a", linestyle="--", alpha=0.7)
axes[1].set_title("Token Accuracy (%)"); axes[1].set_xlabel("Epoch")
axes[1].legend(); axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{CFG.OUTPUT_DIR}/training_curves.png",
            dpi=150, bbox_inches="tight")
plt.show()

df_h = pd.DataFrame(history)
print("Top 5 epochs by Val Loss:")
print(df_h.nsmallest(5, "val_loss")
         [["epoch","train_loss","val_loss","train_acc","val_acc"]]
         .to_string(index=False))
# Out:
# Top 5 epochs by Val Loss:
#  epoch  train_loss  val_loss  train_acc  val_acc
#     49    1.247130  1.478212   0.976874 0.934685
#     50    1.246682  1.478370   0.976362 0.934090
#     48    1.248872  1.480261   0.975907 0.934125
#     47    1.253597  1.483070   0.974119 0.933815
#     46    1.252870  1.484203   0.974604 0.933277

# %%
# ── Load best model ────────────────────────────────────────────────────
ckpt = torch.load(f"{CFG.MODEL_DIR}/best_model.pt", map_location=DEVICE)
model.load_state_dict(ckpt["model_state"])
model.eval()
print(f"✓ Best model loaded (epoch {ckpt['epoch']}, "
      f"val_loss={ckpt['val_loss']:.4f}, "
      f"val_acc={ckpt['val_acc']*100:.2f}%)")


@torch.no_grad()
def beam_search(memory, attn_mask, beam_size=4):
    """
    At every step, logits shape is [SSL_VOCAB_SIZE] only.
    Every index in the output maps to a known SSL gloss word.
    Out-of-vocab prediction is architecturally impossible.
    """
    beams = [([CFG.BOS_IDX], 0.0)]
    done  = []

    for _ in range(CFG.MAX_TGT_LEN):
        cands = []
        for seq, score in beams:
            tgt     = torch.tensor([seq], device=DEVICE)
            dec_out = model.decode_step(tgt, memory, attn_mask)
            # logits over SSL vocab only — size ~1,204 not 250,000
            logits  = model.output_proj(dec_out[:, -1, :]).squeeze(0)
            lp      = F.log_softmax(logits, dim=-1)
            top_v, top_i = lp.topk(min(beam_size, ssl_vocab.size - 1))
            for v, i in zip(top_v.tolist(), top_i.tolist()):
                cands.append((seq + [i], score + v))

        cands.sort(key=lambda x: x[1], reverse=True)
        beams = []
        for seq, sc in cands[:beam_size * 2]:
            if seq[-1] == CFG.EOS_IDX:
                done.append((seq[1:-1], sc / max(len(seq)-2, 1)))
            else:
                beams.append((seq, sc))
            if len(beams) >= beam_size:
                break
        if not beams:
            break

    if done:
        done.sort(key=lambda x: x[1], reverse=True)
        return done[0][0]
    return beams[0][0][1:] if beams else []


def translate(text: str, beam_size: int = 4) -> Dict:
    model.eval()
    enc = enc_tokenizer(
        text, max_length=CFG.MAX_SRC_LEN,
        padding="max_length", truncation=True,
        return_tensors="pt").to(DEVICE)

    memory = model.encode(enc["input_ids"], enc["attention_mask"])
    indices = beam_search(memory, enc["attention_mask"], beam_size)

    # Decode SSL indices → gloss words
    # Every index is GUARANTEED to be a valid SSL gloss word
    gloss_words = ssl_vocab.decode(indices)

    # Map each gloss word → original SSL sign ID
    ssl_tokens = []
    for word in gloss_words:
        sid = ssl_vocab.word_to_ssl_id(word)
        ssl_tokens.append({"word": word, "sign_id": sid})

    return {
        "source"     : text,
        "gloss_words": gloss_words,
        "ssl_tokens" : ssl_tokens,
        "ssl_string" : " | ".join(
            f"{t['sign_id']}:{t['word']}" for t in ssl_tokens),
    }

print("✓ Translator ready")
print(f"  Decoder vocab size : {ssl_vocab.size} (SSL tokens only)")
print(f"  Encoder vocab size : {enc_tokenizer.vocab_size} (XLM-R)")
# Out:
# ✓ Best model loaded (epoch 49, val_loss=1.4782, val_acc=93.47%)
# ✓ Translator ready
#   Decoder vocab size : 1523 (SSL tokens only)
#   Encoder vocab size : 250100 (XLM-R)

# %%
rows = []
print(f"Evaluating {len(test_pairs)} test sentences ...\n")
print("─" * 70)

for i, pair in enumerate(test_pairs):
    pred = translate(pair["source"])

    correct_words  = pair["gloss_words"]
    correct_ids    = pair["target_ids"]
    pred_words     = pred["gloss_words"]
    pred_ids       = [t["sign_id"] for t in pred["ssl_tokens"]]

    correct_string = " | ".join(
        f"{tid}:{w}" for tid, w in zip(correct_ids, correct_words))

    word_overlap = len(set(correct_words) & set(pred_words)) / max(len(correct_words), 1)
    id_overlap   = len(set(correct_ids)   & set(pred_ids))   / max(len(correct_ids),   1)
    min_len      = min(len(correct_words), len(pred_words))
    pos_acc      = sum(1 for j in range(min_len)
                       if correct_words[j] == pred_words[j]) / max(len(correct_words), 1)
    exact        = int(correct_words == pred_words)

    rows.append({
        "source"           : pair["source"],
        "correct_words"    : " | ".join(correct_words),
        "predicted_words"  : " | ".join(pred_words),
        "correct_ids"      : " | ".join(str(x) for x in correct_ids),
        "predicted_ids"    : " | ".join(str(x) for x in pred_ids),
        "correct_string"   : correct_string,
        "predicted_string" : pred["ssl_string"],
        "word_overlap_%"   : round(word_overlap * 100, 1),
        "id_overlap_%"     : round(id_overlap   * 100, 1),
        "pos_accuracy_%"   : round(pos_acc      * 100, 1),
        "exact_match"      : exact,
        "correct_len"      : len(correct_words),
        "predicted_len"    : len(pred_words),
    })

    print(f"[{i+1}/{len(test_pairs)}] {pair['source']}")
    print(f"  Correct   : {correct_string}")
    print(f"  Predicted : {pred['ssl_string']}")
    print(f"  Overlap   : word={word_overlap*100:.0f}%  "
          f"id={id_overlap*100:.0f}%  exact={'✓' if exact else '✗'}")
    print()

df = pd.DataFrame(rows)
df.to_csv(f"{CFG.OUTPUT_DIR}/test_results.csv", index=False, encoding="utf-8")

print("=" * 55)
print("  TEST RESULTS")
print("=" * 55)
print(f"  Sentences         : {len(df)}")
print(f"  Word Overlap      : {df['word_overlap_%'].mean():.2f}%")
print(f"  SSL ID Overlap    : {df['id_overlap_%'].mean():.2f}%")
print(f"  Position Accuracy : {df['pos_accuracy_%'].mean():.2f}%")
print(f"  Exact Match       : {df['exact_match'].mean()*100:.2f}%")
print("=" * 55)
print(f"\n✓ Results → {CFG.OUTPUT_DIR}/test_results.csv")
# Out:
# Evaluating 1437 test sentences ...
#
# ──────────────────────────────────────────────────────────────────────
# [1/1437] පන්තියට එන්න.
#   Correct   : 910:පන්ති කාමරය | 699:ට | 389:එනවා
#   Predicted : 910:පන්ති කාමරය | 699:ට | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [2/1437] මට රුපියල් හතළිස්එකක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 53:41 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 53:41 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [3/1437] අද රැස්වීමට මිනිසුන් හතළිස්එකක් ආවා.
#   Correct   : 1264:රැස්වීම | 53:41 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 53:41 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [4/1437] මට රුපියල් එකසිය හතළිස්නවයක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 3:100 | 61:49 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 3:100 | 61:49 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [5/1437] ලාවන්‍යා දැන් එනවාද?
#   Correct   : 1292:ල් | 241:ආ | 1362:ව් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 801:දැන් | 389:එනවා | 779:ද?
#   Predicted : 1292:ල් | 241:ආ | 1362:ව් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 801:දැන් | 389:එනවා | 779:ද?
#   Overlap   : word=90%  id=90%  exact=✓
#
# [6/1437] අපි වතුර ගේන්න යන්නද?
#   Correct   : 185:අපි | 1336:වතුර | 647:ගේනවා | 1230:යන්න | 779:ද?
#   Predicted : 185:අපි | 1336:වතුර | 647:ගේනවා | 1230:යන්න | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [7/1437] අපි පවුලේ එකමුතුකම රකිනවා
#   Correct   : 185:අපි | 934:පව්ල | 645:ගේ | 1471:සමගි කරනවා | 257:ආරක්ෂාව
#   Predicted : 185:අපි | 934:පව්ල | 645:ගේ | 1566:හැමෝම | 257:ආරක්ෂාව
#   Overlap   : word=80%  id=80%  exact=✗
#
# [8/1437] අද රැස්වීමට මිනිසුන් අටසිය අසූනවයක් ආවා.
#   Correct   : 1264:රැස්වීම | 106:800 | 117:89 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 106:800 | 117:89 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [9/1437] අද රැස්වීමට මිනිසුන් විසිදහසක් ආවා.
#   Correct   : 1264:රැස්වීම | 22:20000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 22:20000 | 4:1000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✗
#
# [10/1437] අපි ගෙදර ඇවිත් පාඩම් කරනවා
#   Correct   : 185:අපි | 640:ගෙයක් | 389:එනවා | 330:ඉවරයි | 956:පාඩම් කරනවා
#   Predicted : 185:අපි | 636:ගෙදර | 389:එනවා | 330:ඉවරයි | 956:පාඩම් කරනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [11/1437] වෙළදසංකීර්ණය
#   Correct   : 1027:පොදු වෙළදසංකීර්ණය
#   Predicted : 275:ඇදුම් සෝදනවා | 132:ං | 132:ං | 478:ක් | 342:උ | 1257:ර් | 133:අ | 166:අද | 625:ගීතයක් | 133:අ | 1145:ම් | 1073:බ් | 133:අ
#   Overlap   : word=0%  id=0%  exact=✗
#
# [12/1437] විභාගයේ ප්‍රශ්න එකසිය තිස්හයක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 43:36 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 43:36 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [13/1437] අද රැස්වීමට මිනිසුන් දහදහසක් ආවා.
#   Correct   : 1264:රැස්වීම | 5:10000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 5:10000 | 4:1000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✗
#
# [14/1437] මේ කිරි රුපියල් එකසිය අසූදෙකක්.
#   Correct   : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 3:100 | 110:82 | 478:ක්
#   Predicted : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 3:100 | 110:82 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [15/1437] අද රැස්වීමට මිනිසුන් දහහයදහසක් ආවා.
#   Correct   : 1264:රැස්වීම | 5:10000 | 79:6000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 5:10000 | 79:6000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [16/1437] සන්ධ්‍යා හෙට සතුටින් ඉන්නවා
#   Correct   : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 1581:හෙට | 1464:සතුටු | 316:ඉන්නවා
#   Predicted : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 1581:හෙට | 1464:සතුටු | 316:ඉන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [17/1437] අමරා අද වැඩ කරන්නෙ නැ
#   Correct   : 133:අ | 1145:ම් | 133:අ | 1257:ර් | 241:ආ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 133:අ | 1145:ම් | 133:අ | 1257:ර් | 241:ආ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=88%  id=88%  exact=✓
#
# [18/1437] ඔයාට මහන්සි පාටයි.
#   Correct   : 408:ඔබ | 699:ට | 1142:මහන්සි | 951:පාට
#   Predicted : 408:ඔබ | 699:ට | 1142:මහන්සි
#   Overlap   : word=75%  id=75%  exact=✗
#
# [19/1437] නැහැ හෙට පාසල් තියෙනවා.
#   Correct   : 870:නැ | 1581:හෙට | 966:පාසල් කොඩිය | 758:තියෙනවා
#   Predicted : 870:නැ | 1581:හෙට | 334:ඉස්කෝලෙ | 758:තියෙනවා
#   Overlap   : word=75%  id=75%  exact=✗
#
# [20/1437] ගෙවත්තේ ගස් දෙසිය අසූඅටක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 20:200 | 116:88 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 20:200 | 116:88 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [21/1437] අම්මා අද සතුටින් ඉමු
#   Correct   : 194:අම්මා | 166:අද | 1464:සතුටු | 316:ඉන්නවා
#   Predicted : 194:අම්මා | 166:අද | 1464:සතුටු | 316:ඉන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [22/1437] අඩු කරන්න
#   Correct   : 150:අඩු කිරීම
#   Predicted : 150:අඩු කිරීම | 458:කරන්න
#   Overlap   : word=100%  id=100%  exact=✗
#
# [23/1437] අපි ලොකු ගොඩනැගිලි හදනවා.
#   Correct   : 185:අපි | 1323:ලොකුවට | 649:ගොඩනැගිලි | 1538:හදනවා
#   Predicted : 185:අපි | 1323:ලොකුවට | 649:ගොඩනැගිලි | 1538:හදනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [24/1437] ගුරුතුමී, අපට වැසිකිලි යන්න පුලුවන්ද?
#   Correct   : 627:ගුරුතුමිය | 188:අපිට | 1399:වැසිකිලිය | 1230:යන්න | 1012:පුලුවන් | 779:ද?
#   Predicted : 627:ගුරුතුමිය | 188:අපිට | 1399:වැසිකිලිය | 1230:යන්න | 1012:පුලුවන් | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [25/1437] ළාදුරු
#   Correct   : 1598:ළාදුරු
#   Predicted : 1518:සුලග
#   Overlap   : word=0%  id=0%  exact=✗
#
# [26/1437] ගීතයක් කියන්න.
#   Correct   : 625:ගීතයක් | 514:කියනවා
#   Predicted : 625:ගීතයක් | 478:ක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✗
#
# [27/1437] මම ගෙනාවේ නැහැ.
#   Correct   : 1128:මම | 647:ගේනවා | 330:ඉවරයි | 870:නැ
#   Predicted : 1128:මම | 647:ගේනවා | 330:ඉවරයි | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [28/1437] බෙහෙත් ගත්තද දන්නේ නැහැ.
#   Correct   : 1102:බෙහෙත් | 583:ගන්න | 330:ඉවරයි | 779:ද? | 788:දන්නෙ නැ | 870:නැ
#   Predicted : 1102:බෙහෙත් | 583:ගන්න | 330:ඉවරයි | 779:ද?
#   Overlap   : word=67%  id=67%  exact=✗
#
# [29/1437] අද රැස්වීමට මිනිසුන් එකසිය හැටක් ආවා.
#   Correct   : 1264:රැස්වීම | 3:100 | 77:60 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 3:100 | 77:60 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [30/1437] මම සිංදු කිව්වා.
#   Correct   : 1128:මම | 604:ගායනා | 514:කියනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 604:ගායනා | 514:කියනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [31/1437] මම රුපියල් හතලිස්නවදහසක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 51:40000 | 121:9000 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 51:40000 | 121:9000 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [32/1437] බොහොම හොදයි.
#   Correct   : 650:ගොඩාක් | 1587:හොද
#   Predicted : 1587:හොඳ | 1587:හොඳ
#   Overlap   : word=0%  id=50%  exact=✗
#
# [33/1437] ඔව් අපි ජාතික ගීය කියනවා.
#   Correct   : 415:ඔව් | 185:අපි | 687:ජාතික | 478:ක් | 514:කියනවා
#   Predicted : 415:ඔව් | 185:අපි | 687:ජාතික | 478:ක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [34/1437] අනිල් දැන් පොත කියවනවා
#   Correct   : 133:අ | 862:න් | 296:ඉ | 1292:ල් | 801:දැන් | 1024:පොත | 515:කියවනවා
#   Predicted : 133:අ | 862:න් | 296:ඉ | 1292:ල් | 801:දැන් | 1024:පොත | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [35/1437] අමිත් අද අංකුඹුර වැඩ කරනවා
#   Correct   : 133:අ | 1145:ම් | 296:ඉ | 739:ත් | 166:අද | 133:අ | 132:ං | 478:ක් | 342:උ | 1222:ඹ් | 342:උ | 1257:ර් | 133:අ | 1383:වැඩ කරනවා
#   Predicted : 133:අ | 1145:ම් | 296:ඉ | 739:ත් | 166:අද | 133:අ | 132:ං | 478:ක් | 342:උ | 1257:ර් | 133:අ | 1222:ඹ් | 342:උ | 1257:ර් | 133:අ | 1229:යනවා
#   Overlap   : word=71%  id=71%  exact=✗
#
# [36/1437] ක්‍රීඩා කරන එක ශරීරයට හොඳයි
#   Correct   : 483:ක්‍රීඩා | 1451:ශරීර කොටස් | 699:ට | 1587:හොඳ
#   Predicted : 483:ක්‍රීඩා | 458:කරන්න | 1504:සිරුර | 699:ට | 1587:හොඳ
#   Overlap   : word=75%  id=75%  exact=✗
#
# [37/1437] ගෙවත්තේ ගස් හාරදහස්සීයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 50:4000 | 3:100 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 50:4000 | 3:100 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [38/1437] ඔබ උදෑසන පාසලට වෙලාවට එනවා
#   Correct   : 408:ඔබ | 361:උදය | 334:ඉස්කෝලෙ | 699:ට | 1437:වෙලාව | 699:ට | 389:එනවා
#   Predicted : 408:ඔබ | 368:උදේ | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා
#   Overlap   : word=57%  id=57%  exact=✗
#
# [39/1437] අපි එයාට ස්තූති කරමු.
#   Correct   : 185:අපි | 421:ඔහු | 699:ට | 1487:ස්තූතියි | 1539:හදමු
#   Predicted : 185:අපි | 421:ඔහු | 699:ට | 1487:ස්තූතියි | 458:කරන්න
#   Overlap   : word=80%  id=80%  exact=✗
#
# [40/1437] පොලිසියට යන්න ප්‍රශ්නයක් නම්
#   Correct   : 1037:පොලිසිය | 699:ට | 1230:යන්න | 947:ප්‍රශ්න | 478:ක් | 857:නම්
#   Predicted : 1037:පොලිසිය | 699:ට | 1230:යන්න | 947:ප්‍රශ්න | 478:ක් | 758:තියෙනවා
#   Overlap   : word=83%  id=83%  exact=✗
#
# [41/1437] මම හයසිය හතළිස්අට පිටුව කියවනවා.
#   Correct   : 1128:මම | 78:600 | 60:48 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 78:600 | 60:48 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [42/1437] ඉෂාක් දැන් සින්දු කියනවා
#   Correct   : 296:ඉ | 1455:ෂ් | 241:ආ | 478:ක් | 801:දැන් | 625:ගීතයක් | 514:කියනවා
#   Predicted : 296:ඉ | 1455:ෂ් | 241:ආ | 478:ක් | 801:දැන් | 625:ගීතයක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [43/1437] අපට නිදිමතයි.
#   Correct   : 1119:මට | 886:නිදිමත
#   Predicted : 188:අපිට | 886:නිදිමත
#   Overlap   : word=50%  id=50%  exact=✗
#
# [44/1437] බඩ රිදෙනවා කියනවා.
#   Correct   : 196:අමාශය | 1443:වේදනාව | 514:කියනවා
#   Predicted : 196:අමාශය | 1443:වේදනාව | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [45/1437] පිට්ටු
#   Correct   : 985:පිට්ටු
#   Predicted : 999:පිහිනීම
#   Overlap   : word=0%  id=0%  exact=✗
#
# [46/1437] අපි අද වේලාසනින් ගෙදර යනවා
#   Correct   : 185:අපි | 166:අද | 299:ඉක්මනින් | 640:ගෙයක් | 1229:යනවා
#   Predicted : 185:අපි | 166:අද | 299:ඉක්මනින් | 640:ගෙයක් | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [47/1437] ගෙවත්තේ ගස් හත්සිය අසූවක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 92:700 | 105:80 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 92:700 | 105:80 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [48/1437] ඔව් ක්‍රිකට් තරගයක් ගැන තියෙනවා.
#   Correct   : 415:ඔව් | 481:ක්‍රිකට් | 730:තරගය | 478:ක් | 758:තියෙනවා
#   Predicted : 415:ඔව් | 482:ක්‍රිකට් ගහනවා | 730:තරගය | 478:ක් | 758:තියෙනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [49/1437] මම රුපියල් නවසිය විසිහතක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 120:900 | 30:27 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 120:900 | 30:27 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [50/1437] මට ඇපල් තුන්සිය හතරක් ඕන.
#   Correct   : 1119:මට | 277:ඇපල් | 35:300 | 47:4 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 277:ඇපල් | 35:300 | 47:4 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [51/1437] හොඳට සෙල්ලම් කරන්න ඕන.
#   Correct   : 1587:හොද | 699:ට | 1531:සෙල්ලම් කරනවා | 427:ඕන
#   Predicted : 1587:හොද | 699:ට | 1531:සෙල්ලම් කරනවා | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [52/1437] මම රුපියල් අටසිය හතළිස්හතක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 106:800 | 59:47 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 106:800 | 59:47 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [53/1437] ප්‍රමුත් දැන් බත් කෑවා
#   Correct   : 941:ප් | 1239:රකාරාංශය | 1145:ම් | 342:උ | 739:ත් | 801:දැන් | 1054:බත් | 442:කනවා | 330:ඉවරයි
#   Predicted : 941:ප් | 1239:රකාරාංශය | 1145:ම් | 342:උ | 739:ත් | 801:දැන් | 1054:බත් | 442:කනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [54/1437] ශ්‍යාමි හෙට වැඩට යන්න
#   Correct   : 1452:ශ් | 1223:යංශය | 241:ආ | 1145:ම් | 296:ඉ | 1581:හෙට | 1382:වැඩ | 699:ට | 389:එනවා
#   Predicted : 1452:ශ් | 1223:යංශය | 241:ආ | 1145:ම් | 296:ඉ | 1581:හෙට | 1382:වැඩ | 699:ට | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [55/1437] වැඩ කරන එක හොද ව්‍යායාමයක්.
#   Correct   : 1382:වැඩ | 458:කරන්න | 1587:හොද | 1371:ව්‍යායාම කරනවා
#   Predicted : 1382:වැඩ | 1587:හොද | 485:ක්‍රීඩාව | 478:ක්
#   Overlap   : word=50%  id=50%  exact=✗
#
# [56/1437] ළමයාට බත් පන්සිය හැටපහක් දෙන්න.
#   Correct   : 1595:ළමයා | 1054:බත් | 64:500 | 85:65 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 1054:බත් | 64:500 | 85:65 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [57/1437] දැන් වාඩි වෙන්න.
#   Correct   : 801:දැන් | 1373:වාඩිවෙන්න
#   Predicted : 801:දැන් | 1373:වාඩිවෙන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [58/1437] මට රුපියල් දෙසිය දහසයක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 20:200 | 14:16 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 20:200 | 14:16 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [59/1437] ජාතික ගීය කියන්න ඕන.
#   Correct   : 687:ජාතික | 478:ක් | 514:කියනවා | 427:ඕන
#   Predicted : 687:ජාතික | 478:ක් | 514:කියනවා | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [60/1437] මම කිරි දෙසිය දහසයක් ගත්තා.
#   Correct   : 1128:මම | 517:කිරි | 20:200 | 14:16 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 517:කිරි | 20:200 | 14:16 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [61/1437] එපා මට ලැජ්ජයි.
#   Correct   : 390:එපා | 1119:මට | 1294:ලැජ්ජාව
#   Predicted : 390:එපා | 1119:මට | 1294:ලැජ්ජාව
#   Overlap   : word=100%  id=100%  exact=✓
#
# [62/1437] මම ඇවිද්දා.
#   Correct   : 1128:මම | 284:ඇවිදිනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 284:ඇවිදිනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [63/1437] මම ගෙදර ගිහින් ඇදුම් සෝදනවා.
#   Correct   : 1128:මම | 640:ගෙයක් | 1229:යනවා | 330:ඉවරයි | 275:ඇදුම් සෝදනවා
#   Predicted : 1128:මම | 640:ගෙයක් | 1229:යනවා | 330:ඉවරයි | 275:ඇදුම් සෝදනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [64/1437] මුරුංගා කොල
#   Correct   : 1198:මුරුංගා කොල
#   Predicted : 1197:මුරුංගා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [65/1437] වචනයක් කියවන්න.
#   Correct   : 1332:වචනය | 478:ක් | 516:කියවන්න
#   Predicted : 1405:විද්‍යාව | 478:ක් | 516:කියවන්න
#   Overlap   : word=67%  id=67%  exact=✗
#
# [66/1437] විභාගෙ ලේසිද?
#   Correct   : 1412:විභාගය | 1317:ලේසි | 779:ද?
#   Predicted : 1412:විභාගය | 1317:ලේසි | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [67/1437] අද රැස්වීමට මිනිසුන් දහසයක් ආවා.
#   Correct   : 1264:රැස්වීම | 14:16 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 14:16 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [68/1437] කොළ පාටින් කොළ අදින්න.
#   Correct   : 569:කොළ | 951:පාට | 637:ගෙන් | 569:කොළ | 669:චිත්‍ර අදිනවා
#   Predicted : 569:කොළ | 569:කොළ | 569:කොළ | 669:චිත්‍ර අදිනවා
#   Overlap   : word=40%  id=40%  exact=✗
#
# [69/1437] ලොකු
#   Correct   : 1322:ලොකුම
#   Predicted : 1322:ලොකුම
#   Overlap   : word=100%  id=100%  exact=✓
#
# [70/1437] ප්‍රබෝධා හෙට සින්දු කියමු
#   Correct   : 941:ප් | 1239:රකාරාංශය | 1073:බ් | 426:ඕ | 850:ධ් | 241:ආ | 1581:හෙට | 625:ගීතයක් | 514:කියනවා
#   Predicted : 941:ප් | 1239:රකාරාංශය | 1073:බ් | 426:ඕ | 850:ධ් | 241:ආ | 1581:හෙට | 625:ගීතයක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [71/1437] අද රැස්වීමට මිනිසුන් අටසිය හැටහතක් ආවා.
#   Correct   : 1264:රැස්වීම | 106:800 | 87:67 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 106:800 | 87:67 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [72/1437] මට දොඩම් හත්සිය හැත්තෑපහක් ඕන.
#   Correct   : 1119:මට | 846:දොඩම් | 92:700 | 99:75 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 846:දොඩම් | 92:700 | 99:75 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [73/1437] මම රුපියල් පනහක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 63:50 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 63:50 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [74/1437] ඔව් අද අහස කළු කරලා.
#   Correct   : 415:ඔව් | 166:අද | 240:අහස | 465:කලු | 458:කරන්න | 330:ඉවරයි
#   Predicted : 415:ඔව් | 166:අද | 240:අහස | 465:කලු | 330:ඉවරයි
#   Overlap   : word=83%  id=83%  exact=✗
#
# [75/1437] ළමයාට රොටී හැත්තෑහයදහසක් දෙන්න.
#   Correct   : 1595:ළමයා | 1281:රොටී | 94:70000 | 79:6000 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 1281:රොටී | 94:70000 | 79:6000 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [76/1437] වදුරා
#   Correct   : 1342:වදුරා
#   Predicted : 848:දොඹකරය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [77/1437] මම අට පිටුව කියවනවා.
#   Correct   : 1128:මම | 104:8 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 104:8 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [78/1437] අද දවස හොදයි.
#   Correct   : 166:අද | 794:දවස | 1587:හොඳ
#   Predicted : 166:අද | 794:දවස | 1587:හොද
#   Overlap   : word=67%  id=100%  exact=✗
#
# [79/1437] කිරිඅල
#   Correct   : 518:කිරිඅල
#   Predicted : 517:කිරි
#   Overlap   : word=0%  id=0%  exact=✗
#
# [80/1437] ඔබ හෙට දවසට ලෑස්ති වෙනවා
#   Correct   : 408:ඔබ | 1581:හෙට | 794:දවස | 699:ට | 1523:සූදානම් කරනවා
#   Predicted : 408:ඔබ | 1581:හෙට | 794:දවස | 699:ට | 1523:සූදානම් කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [81/1437] අපි තල්ලු කරන්නේ නැහැ.
#   Correct   : 185:අපි | 736:තල්ලු කරනවා | 870:නැ
#   Predicted : 185:අපි | 736:තල්ලු කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [82/1437] අජන්ත හෙට එනවාද?
#   Correct   : 133:අ | 685:ජ් | 133:අ | 862:න් | 739:ත් | 133:අ | 1581:හෙට | 389:එනවා | 779:ද?
#   Predicted : 133:අ | 685:ජ් | 133:අ | 862:න් | 739:ත් | 133:අ | 1581:හෙට | 389:එනවා | 779:ද?
#   Overlap   : word=78%  id=78%  exact=✓
#
# [83/1437] අනිත් අයට කරදරයි.
#   Correct   : 181:අනුන් | 456:කරදර කරනවා
#   Predicted : 181:අනුන් | 699:ට | 456:කරදර කරනවා
#   Overlap   : word=100%  id=100%  exact=✗
#
# [84/1437] හැන්ද
#   Correct   : 1560:හැන්ද
#   Predicted : 1559:හැගුම්බර
#   Overlap   : word=0%  id=0%  exact=✗
#
# [85/1437] ඔබ ගුරුතුමියගෙන් ඉගෙන ගන්නවා
#   Correct   : 408:ඔබ | 627:ගුරුතුමිය | 637:ගෙන් | 302:ඉගෙනගන්නවා
#   Predicted : 408:ඔබ | 627:ගුරුතුමිය | 637:ගෙන් | 302:ඉගෙනගන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [86/1437] කබඩ් එක අරින්න පුලුවන්ද?
#   Correct   : 447:කබඩ් එක | 209:අරින්න | 1012:පුලුවන් | 779:ද?
#   Predicted : 447:කබඩ් එක | 209:අරින්න | 1012:පුලුවන් | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [87/1437] පීනනවා
#   Correct   : 1004:පීනනවා
#   Predicted : 1356:වවනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [88/1437] ළමයාට ගෙඩි පන්සිය අනූඑකක් දෙන්න.
#   Correct   : 1595:ළමයා | 635:ගෙඩියක් | 64:500 | 123:91 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 635:ගෙඩියක් | 64:500 | 123:91 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [89/1437] කෑම කන්න පටන් ගන්න
#   Correct   : 262:ආහාර | 442:කනවා | 907:පටන්ගන්න
#   Predicted : 262:ආහාර | 442:කනවා | 907:පටන්ගන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [90/1437] මම සූරියකාන්ත මලක් අදිනවා.
#   Correct   : 1128:මම | 1525:සූරියකාන්ත මල | 478:ක් | 669:චිත්‍ර අදිනවා
#   Predicted : 1128:මම | 1525:සූරියකාන්ත මල | 478:ක් | 669:චිත්‍ර අදිනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [91/1437] මම තුන්සිය හතළිස්හය පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 58:46 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 58:46 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [92/1437] අද රැස්වීමට මිනිසුන් අටසිය අනූහයක් ආවා.
#   Correct   : 1264:රැස්වීම | 106:800 | 128:96 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 106:800 | 128:96 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [93/1437] අපි හැමෝම කැමති විභාගය හොඳට පාස් වෙන්න
#   Correct   : 185:අපි | 1566:හැමෝම | 501:කැමති | 1412:විභාගය | 1587:හොද | 699:ට | 1473:සමත්
#   Predicted : 185:අපි | 1566:හැමෝම | 501:කැමති | 330:ඉවරයි | 1587:හොද | 699:ට | 957:පාඩම් කරන්න
#   Overlap   : word=71%  id=71%  exact=✗
#
# [94/1437] ඔබ වතුර බීලා එනවා
#   Correct   : 408:ඔබ | 1336:වතුර | 1103:බොනවා | 330:ඉවරයි | 389:එනවා
#   Predicted : 408:ඔබ | 1336:වතුර | 1103:බොනවා | 330:ඉවරයි | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [95/1437] අපට උදව් කරන්න කවුරු හරි එන්න.
#   Correct   : 188:අපිට | 363:උදව් කරනවා | 472:කවුද | 1548:හරි | 389:එනවා
#   Predicted : 188:අපිට | 363:උදව් කරනවා | 1020:පෙර | 389:එනවා | 330:ඉවරයි | 389:එනවා
#   Overlap   : word=60%  id=60%  exact=✗
#
# [96/1437] විභාගයේ ප්‍රශ්න නවයක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 118:9 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 118:9 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [97/1437] ළමයි එයාට බයයි.
#   Correct   : 1596:ළමයි | 421:ඔහු | 699:ට | 1060:බය
#   Predicted : 1596:ළමයි | 421:ඔහු | 699:ට | 1060:බය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [98/1437] අපි හවස එකට යනවා.
#   Correct   : 185:අපි | 1550:හවස | 1:1 | 699:ට | 1229:යනවා
#   Predicted : 185:අපි | 1550:හවස | 1:1 | 699:ට | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [99/1437] අජන්ත අද මුණ ගැසීම කරමු
#   Correct   : 133:අ | 685:ජ් | 133:අ | 862:න් | 739:ත් | 133:අ | 166:අද | 1186:මුණ ගැසීම
#   Predicted : 133:අ | 685:ජ් | 133:අ | 862:න් | 739:ත් | 133:අ | 166:අද | 1186:මුණ ගැසීම
#   Overlap   : word=75%  id=75%  exact=✓
#
# [100/1437] ඔව් ගුරුතුමී තාත්තා ගියා.
#   Correct   : 415:ඔව් | 627:ගුරුතුමිය | 745:තාත්තා | 1229:යනවා | 330:ඉවරයි
#   Predicted : 415:ඔව් | 627:ගුරුතුමිය | 745:තාත්තා | 1229:යනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [101/1437] ලිව්ම
#   Correct   : 1303:ලිව්ම
#   Predicted : 1307:ලීක්ස්
#   Overlap   : word=0%  id=0%  exact=✗
#
# [102/1437] ඔබ පැල වලට වතුර ටිකක් දානවා
#   Correct   : 408:ඔබ | 597:ගසට | 1336:වතුර | 705:ටිකයි | 478:ක් | 789:දමනවා
#   Predicted : 408:ඔබ | 596:ගස | 699:ට | 1336:වතුර | 705:ටිකයි | 478:ක් | 789:දමනවා
#   Overlap   : word=83%  id=83%  exact=✗
#
# [103/1437] මට රුපියල් තුන්සිය හැත්තෑඅටක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 35:300 | 102:78 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 35:300 | 102:78 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [104/1437] බල්ලා කෑ ගහන්නේ කොහොමද?
#   Correct   : 1066:බල්ලා | 505:කෑ ගහනවා | 568:කොහොමද
#   Predicted : 1066:බල්ලා | 442:කනවා | 568:කොහොමද
#   Overlap   : word=67%  id=67%  exact=✗
#
# [105/1437] මට රුපියල් අනූදහස්හත්දහසක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 122:90000 | 93:7000 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 122:90000 | 93:7000 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [106/1437] අපි කතාව අහමු.
#   Correct   : 185:අපි | 438:කතන්දරය | 239:අහමු
#   Predicted : 185:අපි | 438:කතන්දරය | 237:අහනවා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [107/1437] මම අම්මාට උදව් කරනවා.
#   Correct   : 1128:මම | 194:අම්මා | 699:ට | 363:උදව් කරනවා
#   Predicted : 1128:මම | 194:අම්මා | 699:ට | 363:උදව් කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [108/1437] විභාගයට පාඩම් කරන්න.
#   Correct   : 1412:විභාගය | 699:ට | 956:පාඩම් කරනවා | 957:පාඩම් කරන්න
#   Predicted : 1412:විභාගය | 699:ට | 957:පාඩම් කරන්න
#   Overlap   : word=75%  id=75%  exact=✗
#
# [109/1437] අපි ඉන්ටර්නෙට් එක බලනවා
#   Correct   : 185:අපි | 173:අන්තර්ජාලය | 1064:බලනවා
#   Predicted : 185:අපි | 679:ජනේලය | 1:1 | 1064:බලනවා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [110/1437] ඉරලා
#   Correct   : 323:ඉරලා
#   Predicted : 322:ඉරනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [111/1437] දැන් වෙලාව එකයි විසිපහයි.
#   Correct   : 801:දැන් | 1437:වෙලාව | 1:1 | 28:25
#   Predicted : 801:දැන් | 1437:වෙලාව | 1:1 | 28:25
#   Overlap   : word=100%  id=100%  exact=✓
#
# [112/1437] මම හත්සිය තිස්තුන පිටුව කියවනවා.
#   Correct   : 1128:මම | 92:700 | 40:33 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 92:700 | 40:33 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [113/1437] අපි දහම් පාසල් යන්න කැමතියි
#   Correct   : 185:අපි | 242:ආගම | 334:ඉස්කෝලෙ | 1230:යන්න | 501:කැමති
#   Predicted : 185:අපි | 1596:ළමයි | 334:ඉස්කෝලෙ | 1230:යන්න | 501:කැමති
#   Overlap   : word=80%  id=80%  exact=✗
#
# [114/1437] මට ගෙඩි නවසිය තුනක් ඕන.
#   Correct   : 1119:මට | 635:ගෙඩියක් | 120:900 | 33:3 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 635:ගෙඩියක් | 120:900 | 33:3 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [115/1437] ගිහාන් දැන් පාසල් යනවාද?
#   Correct   : 602:ග් | 296:ඉ | 1551:හ් | 241:ආ | 862:න් | 801:දැන් | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා | 779:ද?
#   Predicted : 602:ග් | 296:ඉ | 1551:හ් | 241:ආ | 862:න් | 801:දැන් | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [116/1437] මම දැන් බත් කන්නෙ නැ
#   Correct   : 1128:මම | 801:දැන් | 1054:බත් | 442:කනවා | 870:නැ
#   Predicted : 1128:මම | 801:දැන් | 1054:බත් | 442:කනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [117/1437] ළමයාට කරවල පන්සිය දොළොසක් දෙන්න.
#   Correct   : 1595:ළමයා | 459:කරවිල | 64:500 | 10:12 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 459:කරවිල | 64:500 | 10:12 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [118/1437] අපට පෑනක් නෑ.
#   Correct   : 188:අපිට | 978:පෑන | 478:ක් | 870:නැ
#   Predicted : 188:අපිට | 978:පෑන | 478:ක් | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [119/1437] ලාවන්‍යා අද බත් කෑවා
#   Correct   : 1292:ල් | 241:ආ | 1362:ව් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 166:අද | 1054:බත් | 442:කනවා | 330:ඉවරයි
#   Predicted : 1292:ල් | 241:ආ | 1362:ව් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 166:අද | 1054:බත් | 442:කනවා | 330:ඉවරයි
#   Overlap   : word=91%  id=91%  exact=✓
#
# [120/1437] මට රුපියල් එක්දහස් හත්සියක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 4:1000 | 92:700 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 4:1000 | 92:700 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [121/1437] අපි හැමදාම ඇත්ත කියමු.
#   Correct   : 185:අපි | 1564:හැමදාම | 268:ඇත්ත | 514:කියනවා | 1539:හදමු
#   Predicted : 185:අපි | 1564:හැමදාම | 268:ඇත්ත | 514:කියනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [122/1437] උදේට කාලා නැතුව ඇති.
#   Correct   : 368:උදේ | 699:ට | 442:කනවා | 330:ඉවරයි | 870:නැ
#   Predicted : 368:උදේ | 699:ට | 442:කනවා | 330:ඉවරයි | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [123/1437] අකලංක දැන් පාඩම් කරනවාද?
#   Correct   : 133:අ | 478:ක් | 133:අ | 1292:ල් | 133:අ | 132:ං | 478:ක් | 133:අ | 801:දැන් | 956:පාඩම් කරනවා | 779:ද?
#   Predicted : 133:අ | 478:ක් | 133:අ | 1292:ල් | 133:අ | 132:ං | 478:ක් | 133:අ | 801:දැන් | 956:පාඩම් කරනවා | 779:ද?
#   Overlap   : word=64%  id=64%  exact=✓
#
# [124/1437] අද රැස්වීමට මිනිසුන් දෙසිය හැටඑකක් ආවා.
#   Correct   : 1264:රැස්වීම | 20:200 | 81:61 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 20:200 | 81:61 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [125/1437] මම අඹ හත්සිය දහහතරක් ගත්තා.
#   Correct   : 1128:මම | 198:අඹ | 92:700 | 12:14 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 198:අඹ | 92:700 | 12:14 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [126/1437] ගෙවත්තේ ගස් නවසිය හැත්තෑපහක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 120:900 | 99:75 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 120:900 | 99:75 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [127/1437] නියපොතු කපලාද තියෙන්නේ?
#   Correct   : 890:නියපොතු | 445:කපනවා | 758:තියෙනවා | 779:ද?
#   Predicted : 890:නියපොතු | 445:කපනවා | 330:ඉවරයි | 779:ද?
#   Overlap   : word=75%  id=75%  exact=✗
#
# [128/1437] ශක්තිමත්
#   Correct   : 1483:සවිමත්
#   Predicted : 1483:සවිමත්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [129/1437] අපි ගස් උඩ කෑම තියමු.
#   Correct   : 185:අපි | 596:ගස | 350:උඩ | 262:ආහාර | 757:තියමු
#   Predicted : 185:අපි | 596:ගස | 645:ගේ | 262:ආහාර | 756:තියන්න
#   Overlap   : word=60%  id=60%  exact=✗
#
# [130/1437] ඔයාට හාස්‍ය කරන්න කැමතිද?
#   Correct   : 408:ඔබ | 699:ට | 1557:හාස්‍ය | 458:කරන්න | 501:කැමති | 779:ද?
#   Predicted : 408:ඔබ | 699:ට | 1254:රස්නය | 501:කැමති | 779:ද?
#   Overlap   : word=67%  id=67%  exact=✗
#
# [131/1437] බදාදා
#   Correct   : 1055:බදාදා
#   Predicted : 794:දවස | 645:ගේ | 796:ද් | 133:අ | 1232:ය් | 133:අ | 166:අද | 1054:බත් | 442:කනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [132/1437] අද රැස්වීමට මිනිසුන් හාරදහස්හත්සියක් ආවා.
#   Correct   : 1264:රැස්වීම | 50:4000 | 92:700 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 50:4000 | 92:700 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [133/1437] අපට සීතලයි.
#   Correct   : 188:අපිට | 1508:සිීතල
#   Predicted : 188:අපිට | 1508:සිීතල
#   Overlap   : word=100%  id=100%  exact=✓
#
# [134/1437] දෙන්න පුලුවන්ද?
#   Correct   : 835:දෙන්න | 1012:පුලුවන් | 779:ද?
#   Predicted : 835:දෙන්න | 1012:පුලුවන් | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [135/1437] සව්
#   Correct   : 1482:සව්
#   Predicted : 1205:මෙ | 1272:රුපියල් | 133:අ | 478:ක් | 342:උ | 1257:ර් | 133:අ | 1362:ව් | 296:ඉ | 739:ත් | 133:අ
#   Overlap   : word=0%  id=0%  exact=✗
#
# [136/1437] අද රැස්වීමට මිනිසුන් හතලිස්දහසක් ආවා.
#   Correct   : 1264:රැස්වීම | 51:40000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 51:40000 | 36:3000 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✗
#
# [137/1437] රස්නය වැඩි වෙයිද?
#   Correct   : 1254:රස්නය | 1384:වැඩි | 779:ද?
#   Predicted : 1254:රස්නය | 1384:වැඩි | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [138/1437] විභාගයේ ප්‍රශ්න එකසිය තිසක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 34:30 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 34:30 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [139/1437] වතුර බෝතලයක් ගේන්න.
#   Correct   : 1336:වතුර | 647:ගේනවා
#   Predicted : 1336:වතුර | 354:උණුවතුර බෝතලය | 478:ක් | 647:ගේනවා
#   Overlap   : word=100%  id=100%  exact=✗
#
# [140/1437] ඔබ මහන්සි වී නිදනවා
#   Correct   : 408:ඔබ | 1142:මහන්සි | 330:ඉවරයි | 887:නිදියනවා
#   Predicted : 408:ඔබ | 1142:මහන්සි | 221:අවදිවෙන්න
#   Overlap   : word=50%  id=50%  exact=✗
#
# [141/1437] ගෙවත්තේ ගස් එකසිය අනූහතක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 3:100 | 129:97 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 3:100 | 129:97 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [142/1437] මල් රෝස පාටයි.
#   Correct   : 1132:මල් | 1285:රෝස පාට
#   Predicted : 1132:මල් | 1132:මල් | 951:පාට
#   Overlap   : word=50%  id=50%  exact=✗
#
# [143/1437] මේ කිරි රුපියල් තුන්සිය අසූහතරක්.
#   Correct   : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 35:300 | 112:84 | 478:ක්
#   Predicted : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 35:300 | 112:84 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [144/1437] අපි අහනවා.
#   Correct   : 185:අපි | 237:අහනවා
#   Predicted : 185:අපි | 237:අහනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [145/1437] අද රැස්වීමට මිනිසුන් හයදහස්හත්සියක් ආවා.
#   Correct   : 1264:රැස්වීම | 79:6000 | 92:700 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 79:6000 | 92:700 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [146/1437] යාලුවෝ එක්ක කතා කරන්න
#   Correct   : 1233:යාලුවන් | 1470:සමග | 439:කතා කරනවා
#   Predicted : 1234:යාලුවා | 1470:සමග | 439:කතා කරනවා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [147/1437] මම වයසට ගියා.
#   Correct   : 1128:මම | 1347:වයස | 699:ට | 1229:යනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1347:වයස | 699:ට | 1229:යනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [148/1437] අපි බිව්වා.
#   Correct   : 185:අපි | 1103:බොනවා | 330:ඉවරයි
#   Predicted : 185:අපි | 1103:බොනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [149/1437] ඔබට පුලුවන්.
#   Correct   : 410:ඔබට | 1012:පුලුවන්
#   Predicted : 410:ඔබට | 1012:පුලුවන්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [150/1437] ඔව් මම ගොඩාක් කැමති.
#   Correct   : 415:ඔව් | 1128:මම | 650:ගොඩාක් | 501:කැමති
#   Predicted : 415:ඔව් | 1128:මම | 650:ගොඩාක් | 501:කැමති
#   Overlap   : word=100%  id=100%  exact=✓
#
# [151/1437] ගෙවත්තේ ගස් දහතුනක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 11:13 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 11:13 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [152/1437] හදමු
#   Correct   : 1539:හදමු
#   Predicted : 1538:හදනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [153/1437] මම බිත්තර හයදහසක් ගත්තා.
#   Correct   : 1128:මම | 1087:බිත්තර | 79:6000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1087:බිත්තර | 79:6000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [154/1437] ශක්තිය ගන්න.
#   Correct   : 853:ධෛර්යය | 583:ගන්න
#   Predicted : 168:අද්‍යාපන සහතිකය | 583:ගන්න
#   Overlap   : word=50%  id=50%  exact=✗
#
# [155/1437] මට අඹ නවදහස්හයසියක් ඕන.
#   Correct   : 1119:මට | 198:අඹ | 121:9000 | 78:600 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 198:අඹ | 121:9000 | 78:600 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [156/1437] කොළ.
#   Correct   : 569:කොළ
#   Predicted : 569:කොළ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [157/1437] ගෙවත්තේ ගස් එකසිය අනූඅටක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 3:100 | 130:98 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 3:100 | 130:98 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [158/1437] ගේට්ටුව වහලද?
#   Correct   : 646:ගේට්ටුව | 1357:වසනවා | 330:ඉවරයි | 779:ද?
#   Predicted : 646:ගේට්ටුව | 1357:වසනවා | 779:ද?
#   Overlap   : word=75%  id=75%  exact=✗
#
# [159/1437] කාඩ් ගහනවා
#   Correct   : 489:කාඩ් ගහනවා
#   Predicted : 492:කාරය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [160/1437] බංකුව
#   Correct   : 1045:බංකුව
#   Predicted : 1080:බැංකුව
#   Overlap   : word=0%  id=0%  exact=✗
#
# [161/1437] කැරට් කෑවම ලස්සන වෙනවා.
#   Correct   : 503:කැරට් | 442:කනවා | 330:ඉවරයි | 1290:ලස්සන
#   Predicted : 503:කැරට් | 442:කනවා | 330:ඉවරයි | 1290:ලස්සන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [162/1437] මට රුපියල් පන්දහස්දෙසියක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 65:5000 | 20:200 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 65:5000 | 20:200 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [163/1437] මට රුපියල් නවදහස්තුන්සියක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 121:9000 | 35:300 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 121:9000 | 35:300 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [164/1437] හොරෙන් බලන්න එපා.
#   Correct   : 1590:හොරකම් කරනවා | 1065:බලන්න | 390:එපා
#   Predicted : 1587:හොද | 1065:බලන්න | 390:එපා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [165/1437] ඔරුව
#   Correct   : 413:ඔරුව
#   Predicted : 414:ඔලුව
#   Overlap   : word=0%  id=0%  exact=✗
#
# [166/1437] අපි හවස හතරට යනවා.
#   Correct   : 185:අපි | 1550:හවස | 47:4 | 699:ට | 1229:යනවා
#   Predicted : 185:අපි | 1550:හවස | 47:4 | 699:ට | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [167/1437] මම ගෝවා පනස්දහස්හයදහස්හත්සිය අසූනවයක් ගත්තා.
#   Correct   : 1128:මම | 658:ගෝවා | 66:50000 | 79:6000 | 92:700 | 117:89 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 658:ගෝවා | 66:50000 | 79:6000 | 92:700 | 117:89 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [168/1437] ඔයාට ගණන් පුලුවන්.
#   Correct   : 408:ඔබ | 699:ට | 581:ගණන් කරනවා | 1012:පුලුවන්
#   Predicted : 408:ඔබ | 699:ට | 581:ගණන් කරනවා | 1012:පුලුවන්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [169/1437] කෑම ටිකක් කන්න බඩගිනිනම්
#   Correct   : 262:ආහාර | 705:ටිකයි | 442:කනවා | 1048:බඩගිනි
#   Predicted : 262:ආහාර | 705:ටිකයි | 442:කනවා | 1048:බඩගිනි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [170/1437] අපේ වත්ත අලවතුගොඩ
#   Correct   : 190:අපේ | 587:ගම | 133:අ | 1292:ල් | 133:අ | 1362:ව් | 133:අ | 739:ත් | 342:උ | 602:ග් | 405:ඔ | 710:ඩ් | 133:අ
#   Predicted : 190:අපේ | 587:ගම | 133:අ | 1292:ල් | 133:අ | 1362:ව් | 133:අ | 739:ත් | 342:උ | 1362:ව් | 133:අ
#   Overlap   : word=54%  id=54%  exact=✗
#
# [171/1437] ගෙවත්තේ ගස් අටසිය අසූනවයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 106:800 | 117:89 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 106:800 | 117:89 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [172/1437] අදීශාන් හෙට පාසල් යමු
#   Correct   : 133:අ | 796:ද් | 335:ඊ | 1452:ශ් | 241:ආ | 862:න් | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Predicted : 133:අ | 796:ද් | 335:ඊ | 1452:ශ් | 241:ආ | 862:න් | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Overlap   : word=100%  id=100%  exact=✓
#
# [173/1437] නැ ගුරුතුමී මට බඩගිනි නැ.
#   Correct   : 870:නැ | 627:ගුරුතුමිය | 1119:මට | 1048:බඩගිනි | 870:නැ
#   Predicted : 870:නැ | 627:ගුරුතුමිය | 1128:මම | 1048:බඩගිනි | 870:නැ
#   Overlap   : word=60%  id=60%  exact=✗
#
# [174/1437] නුවන් මට පොතක් දුන්නා
#   Correct   : 862:න් | 342:උ | 1362:ව් | 133:අ | 862:න් | 1119:මට | 1024:පොත | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 862:න් | 342:උ | 1362:ව් | 133:අ | 862:න් | 1119:මට | 1024:පොත | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=90%  id=90%  exact=✓
#
# [175/1437] මේ බිත්තර රුපියල් දෙසිය විස්සක්.
#   Correct   : 1205:මෙ | 1087:බිත්තර | 1272:රුපියල් | 20:200 | 19:20 | 478:ක්
#   Predicted : 1205:මෙ | 1087:බිත්තර | 1272:රුපියල් | 20:200 | 19:20 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [176/1437] මට රුපියල් හාරසිය අනූතුනක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 49:400 | 125:93 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 49:400 | 125:93 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [177/1437] අද වැඩ ඉවරයි.
#   Correct   : 166:අද | 1382:වැඩ | 330:ඉවරයි
#   Predicted : 166:අද | 1382:වැඩ | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [178/1437] අදීශාන් හෙට සින්දු කියමු
#   Correct   : 133:අ | 796:ද් | 335:ඊ | 1452:ශ් | 241:ආ | 862:න් | 1581:හෙට | 625:ගීතයක් | 514:කියනවා
#   Predicted : 133:අ | 796:ද් | 335:ඊ | 1452:ශ් | 241:ආ | 862:න් | 1581:හෙට | 625:ගීතයක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [179/1437] අද රැස්වීමට මිනිසුන් දෙසිය දහහතරක් ආවා.
#   Correct   : 1264:රැස්වීම | 20:200 | 12:14 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 20:200 | 12:14 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [180/1437] ඔයාට තේරුණද?
#   Correct   : 408:ඔබ | 699:ට | 769:තේරුනාද
#   Predicted : 408:ඔබ | 699:ට | 854:නටනවා | 330:ඉවරයි | 779:ද?
#   Overlap   : word=67%  id=67%  exact=✗
#
# [181/1437] අගෝස්තු
#   Correct   : 143:අගෝස්තු
#   Predicted : 658:ගෝවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [182/1437] දිනේෂ් දැන් වැඩට එන්න
#   Correct   : 796:ද් | 296:ඉ | 862:න් | 401:ඒ | 1455:ෂ් | 801:දැන් | 1382:වැඩ | 699:ට | 389:එනවා
#   Predicted : 796:ද් | 296:ඉ | 862:න් | 401:ඒ | 1455:ෂ් | 801:දැන් | 1382:වැඩ | 699:ට | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [183/1437] මම රුපියල් එකසිය තිස්නවයක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 3:100 | 46:39 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 3:100 | 46:39 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [184/1437] නැහැ අපි වැඩ කරන්න කැමතියි.
#   Correct   : 870:නැ | 185:අපි | 1382:වැඩ | 458:කරන්න | 501:කැමති
#   Predicted : 870:නැ | 185:අපි | 1382:වැඩ | 458:කරන්න | 501:කැමති
#   Overlap   : word=100%  id=100%  exact=✓
#
# [185/1437] ඇයි එයා හැමදාම පරක්කු?
#   Correct   : 283:ඇයි | 421:ඔහු | 1564:හැමදාම | 917:පරක්කු
#   Predicted : 283:ඇයි | 408:ඔබ | 1564:හැමදාම | 917:පරක්කු
#   Overlap   : word=75%  id=75%  exact=✗
#
# [186/1437] මම හයසිය හැටදෙක පිටුව කියවනවා.
#   Correct   : 1128:මම | 78:600 | 82:62 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 78:600 | 82:62 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [187/1437] අංජලී හෙට බත් කනවා
#   Correct   : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 1581:හෙට | 1054:බත් | 442:කනවා
#   Predicted : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 1581:හෙට | 1054:බත් | 442:කනවා
#   Overlap   : word=89%  id=89%  exact=✓
#
# [188/1437] අංජලී අද අකුරණ යනවා
#   Correct   : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 166:අද | 133:අ | 478:ක් | 342:උ | 1257:ර් | 133:අ | 715:ණ් | 133:අ | 1229:යනවා
#   Predicted : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 166:අද | 133:අ | 478:ක් | 342:උ | 1257:ර් | 133:අ | 715:ණ් | 133:අ | 1229:යනවා
#   Overlap   : word=73%  id=73%  exact=✓
#
# [189/1437] මම ගරු කරා.
#   Correct   : 1128:මම | 590:ගරු කරනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 590:ගරු කරනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [190/1437] හැගීම්
#   Correct   : 1558:හැගීම්
#   Predicted : 1561:හැන්දෑව
#   Overlap   : word=0%  id=0%  exact=✗
#
# [191/1437] අපි අද චිත්‍රයක් ඇන්දා
#   Correct   : 185:අපි | 166:අද | 669:චිත්‍ර අදිනවා | 330:ඉවරයි
#   Predicted : 185:අපි | 166:අද | 667:චිත්‍ර | 478:ක් | 669:චිත්‍ර අදිනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✗
#
# [192/1437] තාත්තා අපට අලුත් පෑනක් ගෙනත් දුන්නා
#   Correct   : 745:තාත්තා | 188:අපිට | 217:අලුත් | 978:පෑන | 478:ක් | 647:ගේනවා | 330:ඉවරයි | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 745:තාත්තා | 188:අපිට | 217:අලුත් | 978:පෑන | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=78%  id=78%  exact=✗
#
# [193/1437] තර්කානුකූල වෙන්න.
#   Correct   : 732:තර්ක කරනවා
#   Predicted : 732:තර්ක කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [194/1437] තාත්තා දැන් බසය ට යනවා
#   Correct   : 745:තාත්තා | 801:දැන් | 1070:බසය | 699:ට | 1229:යනවා
#   Predicted : 745:තාත්තා | 801:දැන් | 1070:බසය | 699:ට | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [195/1437] මම අටසිය පහ පිටුව කියවනවා.
#   Correct   : 1128:මම | 106:800 | 62:5 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 106:800 | 5:5 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=80%  exact=✓
#
# [196/1437] ගෙවත්තේ ගස් හාරසිය අසූවක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 49:400 | 105:80 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 49:400 | 105:80 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [197/1437] පන්තියේ වැඩ කරන කොට කතා කරන්න තහනම්
#   Correct   : 910:පන්ති කාමරය | 645:ගේ | 1383:වැඩ කරනවා | 439:කතා කරනවා | 738:තහනම්
#   Predicted : 910:පන්ති කාමරය | 645:ගේ | 1383:වැඩ කරනවා | 738:තහනම් | 738:තහනම්
#   Overlap   : word=80%  id=80%  exact=✗
#
# [198/1437] මට රුපියල් හතළිස්හතක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 59:47 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 59:47 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [199/1437] විභාගයේ ප්‍රශ්න තිසක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 34:30 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 34:30 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [200/1437] මට රුපියල් පන්සිය එකක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 64:500 | 1:1 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 64:500 | 1:1 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [201/1437] මද්‍යම රාත්‍රිය
#   Correct   : 1123:මද්‍යම රාත්‍රිය
#   Predicted : 170:අද්‍යාපනය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [202/1437] ඔයා රෙදි සෝදනවද?
#   Correct   : 408:ඔබ | 1278:රෙදි සෝදනවා | 779:ද?
#   Predicted : 408:ඔබ | 1274:රෙදි | 779:ද?
#   Overlap   : word=67%  id=67%  exact=✗
#
# [203/1437] මට නම් ගණිතය අමාරුයි.
#   Correct   : 1119:මට | 857:නම් | 582:ගණිතය | 195:අමාරු
#   Predicted : 1119:මට | 857:නම් | 582:ගණිතය | 195:අමාරු
#   Overlap   : word=100%  id=100%  exact=✓
#
# [204/1437] අද රැස්වීමට මිනිසුන් තුන්දහස්පන්සියක් ආවා.
#   Correct   : 1264:රැස්වීම | 36:3000 | 64:500 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 36:3000 | 64:500 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [205/1437] අපි හැමදාම හොඳින් ඉන්නවා.
#   Correct   : 185:අපි | 1564:හැමදාම | 1587:හොද | 316:ඉන්නවා
#   Predicted : 185:අපි | 1564:හැමදාම | 1587:හොද | 316:ඉන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [206/1437] පාර කපනවා
#   Correct   : 965:පාර කපනවා
#   Predicted : 965:පාර කපනවා | 445:කපනවා
#   Overlap   : word=100%  id=100%  exact=✗
#
# [207/1437] අපි ලස්සන වෙන්නම්.
#   Correct   : 185:අපි | 1290:ලස්සන
#   Predicted : 185:අපි | 1290:ලස්සන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [208/1437] ඉතුරු කරන්න එපා ඔක්කොම කන්න.
#   Correct   : 308:ඉතුරුයි | 458:කරන්න | 390:එපා | 187:අපි සියලු දෙනාම | 442:කනවා
#   Predicted : 330:ඉවරයි | 458:කරන්න | 390:එපා | 1566:හැමෝම | 442:කනවා
#   Overlap   : word=60%  id=60%  exact=✗
#
# [209/1437] ලසන්ත දැන් සතුටින් ඉමු
#   Correct   : 1292:ල් | 133:අ | 1485:ස් | 133:අ | 862:න් | 739:ත් | 133:අ | 801:දැන් | 1464:සතුටු | 316:ඉන්නවා
#   Predicted : 1292:ල් | 133:අ | 1485:ස් | 133:අ | 862:න් | 739:ත් | 133:අ | 801:දැන් | 1464:සතුටු | 316:ඉන්නවා
#   Overlap   : word=80%  id=80%  exact=✓
#
# [210/1437] මම නවසිය දොළොස පිටුව කියවනවා.
#   Correct   : 1128:මම | 120:900 | 10:12 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 120:900 | 10:12 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [211/1437] ගෙවත්තේ ගස් හත්සිය හතළිස්හයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 92:700 | 58:46 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 92:700 | 58:46 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [212/1437] ගෙවත්තේ ගස් හත්සිය අසූඑකක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 92:700 | 109:81 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 92:700 | 109:81 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [213/1437] ළමයාට රොටී එකසිය හතරක් දෙන්න.
#   Correct   : 1595:ළමයා | 1281:රොටී | 3:100 | 47:4 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 1281:රොටී | 3:100 | 47:4 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [214/1437] අපට හෙම්බිරිස්සාව.
#   Correct   : 188:අපිට | 1529:සෙම්ප්‍රතිශ්‍යාව
#   Predicted : 188:අපිට | 1399:වැසිකිලිය
#   Overlap   : word=50%  id=50%  exact=✗
#
# [215/1437] මට රුපියල් හාරසිය හතළිස්තුනක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 49:400 | 55:43 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 49:400 | 55:43 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [216/1437] ළමයාට කෙසෙල් පහළොස් දහසක් දෙන්න.
#   Correct   : 1595:ළමයා | 543:කෙසෙල් | 5:10000 | 65:5000 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 543:කෙසෙල් | 5:10000 | 65:5000 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [217/1437] මම උදේ දොළොසට එනවා.
#   Correct   : 1128:මම | 368:උදේ | 10:12 | 699:ට | 389:එනවා
#   Predicted : 1128:මම | 368:උදේ | 10:12 | 699:ට | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [218/1437] ඔව් යාළුවෝ ඉන්නවානේ.
#   Correct   : 415:ඔව් | 1234:යාලුවා | 316:ඉන්නවා
#   Predicted : 415:ඔව් | 1233:යාලුවන් | 316:ඉන්නවා | 779:ද?
#   Overlap   : word=67%  id=67%  exact=✗
#
# [219/1437] ඔව් අපි කඩදාසි කපනවා.
#   Correct   : 415:ඔව් | 185:අපි | 433:කඩදාසිය | 445:කපනවා
#   Predicted : 415:ඔව් | 185:අපි | 433:කඩදාසිය | 445:කපනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [220/1437] නැ ගුරුතුමී කොළ පාටයි.
#   Correct   : 870:නැ | 627:ගුරුතුමිය | 569:කොළ | 951:පාට
#   Predicted : 870:නැ | 627:ගුරුතුමිය | 569:කොළ | 951:පාට
#   Overlap   : word=100%  id=100%  exact=✓
#
# [221/1437] ඔහු දැන් වැඩට යනවා
#   Correct   : 421:ඔහු | 801:දැන් | 1382:වැඩ | 699:ට | 1229:යනවා
#   Predicted : 421:ඔහු | 801:දැන් | 1382:වැඩ | 699:ට | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [222/1437] ළමයාට බිත්තර දහදහසක් දෙන්න.
#   Correct   : 1595:ළමයා | 1087:බිත්තර | 5:10000 | 4:1000 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 1087:බිත්තර | 5:10000 | 4:1000 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [223/1437] මදුරුවා
#   Correct   : 1125:මදුරුවා
#   Predicted : 1175:මිනිත්තු | 478:ක් | 133:අ | 1145:ම් | 241:ආ | 1292:ල් | 296:ඉ | 166:අද | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Overlap   : word=0%  id=0%  exact=✗
#
# [224/1437] අපේ ලිපිනය කොළඹ
#   Correct   : 190:අපේ | 1299:ලිපිනය | 478:ක් | 405:ඔ | 1597:ළ් | 133:අ | 1145:ම් | 1073:බ් | 133:අ
#   Predicted : 190:අපේ | 1299:ලිපිනය | 478:ක් | 405:ඔ | 1597:ළ් | 133:අ | 1145:ම් | 1073:බ් | 133:අ
#   Overlap   : word=89%  id=89%  exact=✓
#
# [225/1437] ළමයාට කිරි පන්සිය විසිහතක් දෙන්න.
#   Correct   : 1595:ළමයා | 517:කිරි | 64:500 | 30:27 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 517:කිරි | 64:500 | 30:27 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [226/1437] සිහින දකින්න.
#   Correct   : 780:දකිනවා
#   Predicted : 1126:මන්දගාමී | 235:අහගන්නවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [227/1437] ප්‍රියන්ත අද සතුටින් ඉන්නවා
#   Correct   : 941:ප් | 1239:රකාරාංශය | 296:ඉ | 1232:ය් | 133:අ | 862:න් | 739:ත් | 133:අ | 166:අද | 1464:සතුටු | 316:ඉන්නවා
#   Predicted : 941:ප් | 1239:රකාරාංශය | 296:ඉ | 1232:ය් | 133:අ | 862:න් | 739:ත් | 133:අ | 166:අද | 1464:සතුටු | 316:ඉන්නවා
#   Overlap   : word=91%  id=91%  exact=✓
#
# [228/1437] ප්‍රශ්නයට උත්තර ලියන්න.
#   Correct   : 947:ප්‍රශ්න | 699:ට | 1001:පිළිතුර | 1301:ලියන්න
#   Predicted : 947:ප්‍රශ්න | 699:ට | 1001:පිළිතුර | 1300:ලියනවා
#   Overlap   : word=75%  id=75%  exact=✗
#
# [229/1437] ගෙවත්තේ ගස් නවසිය තිස්එකක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 120:900 | 39:31 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 120:900 | 39:31 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [230/1437] අපි ගෙදර වැඩ කළේ නෑ.
#   Correct   : 185:අපි | 334:ඉස්කෝලෙ | 1382:වැඩ | 458:කරන්න | 330:ඉවරයි | 870:නැ
# ...
#   Correct   : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 166:අද | 910:පන්ති කාමරය | 165:අතුගාන්න
#   Predicted : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 166:අද | 910:පන්ති කාමරය | 165:අතුගාන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1369/1437] රොස්ට් කරන ලද පාන්
#   Correct   : 1283:රොස්ට් කරන ලද පාන්
#   Predicted : 1590:හොරකම් කරනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1370/1437] මම රුපියල් නවසිය තිස්පහක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 120:900 | 42:35 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 120:900 | 42:35 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1371/1437] මට කෝපි දෙසිය අනූඑකක් ඕන.
#   Correct   : 1119:මට | 574:කෝපි | 20:200 | 123:91 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 574:කෝපි | 20:200 | 123:91 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1372/1437] අංජලී දැන් වැඩ කරනවාද?
#   Correct   : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 801:දැන් | 1383:වැඩ කරනවා | 779:ද?
#   Predicted : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 801:දැන් | 1383:වැඩ කරනවා | 779:ද?
#   Overlap   : word=89%  id=89%  exact=✓
#
# [1373/1437] දමිත් අද පාසල් යනවාද?
#   Correct   : 796:ද් | 133:අ | 1145:ම් | 296:ඉ | 739:ත් | 166:අද | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා | 779:ද?
#   Predicted : 796:ද් | 133:අ | 1145:ම් | 296:ඉ | 739:ත් | 166:අද | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1374/1437] ඔව් ඉක්මනින් ගිහින් එන්න.
#   Correct   : 415:ඔව් | 299:ඉක්මනින් | 624:ගිහින් එන්න
#   Predicted : 415:ඔව් | 299:ඉක්මනින් | 1229:යනවා | 330:ඉවරයි | 624:ගිහින් එන්න
#   Overlap   : word=100%  id=100%  exact=✗
#
# [1375/1437] හෙට මම ප්‍රශ්න අහනවා.
#   Correct   : 1581:හෙට | 1128:මම | 947:ප්‍රශ්න | 237:අහනවා
#   Predicted : 1581:හෙට | 1128:මම | 947:ප්‍රශ්න | 237:අහනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1376/1437] මට කරවල නවසිය හතළිස්දෙකක් ඕන.
#   Correct   : 1119:මට | 459:කරවිල | 120:900 | 54:42 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 459:කරවිල | 120:900 | 54:42 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1377/1437] බෙදෙන්න එපා.
#   Correct   : 1097:බෙදීම | 390:එපා
#   Predicted : 1097:බෙදීම | 390:එපා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1378/1437] අපි පරිසරය ආරක්ෂා කරන්න ඕන
#   Correct   : 185:අපි | 922:පරිසරය | 257:ආරක්ෂාව | 458:කරන්න | 427:ඕන
#   Predicted : 185:අපි | 922:පරිසරය | 257:ආරක්ෂාව | 427:ඕන
#   Overlap   : word=80%  id=80%  exact=✗
#
# [1379/1437] මම හෙට එනවාද?
#   Correct   : 1128:මම | 1581:හෙට | 389:එනවා | 779:ද?
#   Predicted : 1128:මම | 1581:හෙට | 389:එනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1380/1437] මම කැරට් වලට ආසයි.
#   Correct   : 1128:මම | 503:කැරට් | 699:ට | 261:ආශාව
#   Predicted : 1128:මම | 503:කැරට් | 699:ට | 261:ආශාව
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1381/1437] විභාගයේ ප්‍රශ්න තුන්සිය අසූවක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 35:300 | 105:80 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 35:300 | 105:80 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1382/1437] සන්ධ්‍යා අද වැඩ කරන්නෙ නැ
#   Correct   : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1383/1437] මට රුපියල් පන්දහස්සීයක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 65:5000 | 3:100 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 65:5000 | 3:100 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1384/1437] බෑගය අරගෙන පන්තියට යන්න
#   Correct   : 967:පාසල් බෑගය | 584:ගන්නවා | 910:පන්ති කාමරය | 699:ට | 1230:යන්න
#   Predicted : 967:පාසල් බෑගය | 584:ගන්නවා | 330:ඉවරයි | 910:පන්ති කාමරය | 699:ට | 1230:යන්න
#   Overlap   : word=100%  id=100%  exact=✗
#
# [1385/1437] ක්‍රිශාන්ත අද වැඩ කරන්නෙ නැ
#   Correct   : 478:ක් | 1239:රකාරාංශය | 296:ඉ | 1452:ශ් | 241:ආ | 862:න් | 739:ත් | 133:අ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 941:ප් | 1239:රකාරාංශය | 296:ඉ | 1452:ශ් | 241:ආ | 862:න් | 739:ත් | 133:අ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=91%  id=91%  exact=✗
#
# [1386/1437] මම තුන්සිය හත පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 90:7 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 90:7 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1387/1437] ළමයාට කෝපි තුන්දහස්සීයක් දෙන්න.
#   Correct   : 1595:ළමයා | 574:කෝපි | 36:3000 | 3:100 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 574:කෝපි | 36:3000 | 3:100 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1388/1437] අතුල දැන් බත් උයනවා
#   Correct   : 133:අ | 739:ත් | 342:උ | 1292:ල් | 133:අ | 801:දැන් | 1054:බත් | 375:උයනවා
#   Predicted : 133:අ | 739:ත් | 342:උ | 1292:ල් | 133:අ | 801:දැන් | 1054:බත් | 375:උයනවා
#   Overlap   : word=88%  id=88%  exact=✓
#
# [1389/1437] අපි විදුහල්පතිතුමාගේ කතාව අහනවා
#   Correct   : 185:අපි | 1408:විදුහල්පති | 645:ගේ | 438:කතන්දරය | 237:අහනවා
#   Predicted : 185:අපි | 1408:විදුහල්පති | 645:ගේ | 438:කතන්දරය | 1064:බලනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [1390/1437] කාලය නාස්ති කරන්න එපා.
#   Correct   : 494:කාල සටහන | 869:නාස්ති කරනවා | 390:එපා
#   Predicted : 1437:වෙලාව | 869:නාස්ති කරනවා | 390:එපා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [1391/1437] වතුර වීදුරුවක් බොන්න උදේට
#   Correct   : 1338:වතුරබොන වීදුරුව | 478:ක් | 1103:බොනවා | 368:උදේ
#   Predicted : 1336:වතුර | 354:උණුවතුර බෝතලය | 1103:බොනවා | 368:උදේ | 699:ට
#   Overlap   : word=50%  id=50%  exact=✗
#
# [1392/1437] හොදයි අපි කියන්නම්.
#   Correct   : 1587:හොඳ | 185:අපි | 514:කියනවා
#   Predicted : 1587:හොඳ | 185:අපි | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1393/1437] ගෙවත්තේ ගස් එකසිය පනස්හතරක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 3:100 | 70:54 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 3:100 | 70:54 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1394/1437] අපට නිදිමතයි වගේ.
#   Correct   : 188:අපිට | 886:නිදිමත | 1331:වගේ
#   Predicted : 188:අපිට | 886:නිදිමත | 1331:වගේ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1395/1437] මට රුපියල් තුනක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 33:3 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 33:3 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1396/1437] වට්ටක්කා
#   Correct   : 1333:වට්ටක්කා
#   Predicted : 1206:මෙට්ටය | 133:අ | 1145:ම් | 133:අ | 1292:ල් | 296:ඉ | 478:ක් | 133:අ | 166:අද | 1336:වතුර | 1292:ල් | 133:අ
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1397/1437] හැමෝම සත්‍ය කතා කරනවා
#   Correct   : 1566:හැමෝම | 268:ඇත්ත | 439:කතා කරනවා
#   Predicted : 1566:හැමෝම | 268:ඇත්ත | 439:කතා කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1398/1437] මම තුන්සිය හැටහතර පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 84:64 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 84:64 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1399/1437] අංජලී දැන් වතුර බොනවාද?
#   Correct   : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 801:දැන් | 1336:වතුර | 1103:බොනවා | 779:ද?
#   Predicted : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 801:දැන් | 1336:වතුර | 1103:බොනවා | 779:ද?
#   Overlap   : word=90%  id=90%  exact=✓
#
# [1400/1437] අපි ගේට්ටුව ළඟට යමුද?
#   Correct   : 185:අපි | 646:ගේට්ටුව | 1593:ළඟට | 1231:යමු | 779:ද?
#   Predicted : 185:අපි | 646:ගේට්ටුව | 1593:ළඟට | 1231:යමු | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1401/1437] ඔව් දැන් හරි.
#   Correct   : 415:ඔව් | 801:දැන් | 1548:හරි
#   Predicted : 415:ඔව් | 801:දැන් | 1548:හරි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1402/1437] ළමයාට ගෝවා දෙසිය හතළිස්එකක් දෙන්න.
#   Correct   : 1595:ළමයා | 658:ගෝවා | 20:200 | 53:41 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 658:ගෝවා | 20:200 | 53:41 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1403/1437] අපට පෑනක් ගන්න ඕන.
#   Correct   : 188:අපිට | 978:පෑන | 478:ක් | 583:ගන්න | 427:ඕන
#   Predicted : 188:අපිට | 978:පෑන | 478:ක් | 583:ගන්න | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1404/1437] මට ඇපල් හාරදහස්අටසියක් ඕන.
#   Correct   : 1119:මට | 277:ඇපල් | 50:4000 | 106:800 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 277:ඇපල් | 50:4000 | 106:800 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1405/1437] මම කෝපි දහහතක් ගත්තා.
#   Correct   : 1128:මම | 574:කෝපි | 15:17 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 574:කෝපි | 15:17 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1406/1437] මම නාස්ති කරන්නේ නැහැ.
#   Correct   : 1128:මම | 869:නාස්ති කරනවා | 870:නැ
#   Predicted : 1128:මම | 869:නාස්ති කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1407/1437] සංජීව දැන් සින්දු කියනවාද?
#   Correct   : 1485:ස් | 133:අ | 132:ං | 685:ජ් | 335:ඊ | 1362:ව් | 133:අ | 801:දැන් | 625:ගීතයක් | 514:කියනවා | 779:ද?
#   Predicted : 1485:ස් | 133:අ | 132:ං | 685:ජ් | 335:ඊ | 1362:ව් | 133:අ | 801:දැන් | 625:ගීතයක් | 514:කියනවා | 779:ද?
#   Overlap   : word=91%  id=91%  exact=✓
#
# [1408/1437] අද රැස්වීමට මිනිසුන් හැටදෙකක් ආවා.
#   Correct   : 1264:රැස්වීම | 82:62 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 82:62 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1409/1437] අම්මා දැන් මුණ ගැසීම කරමු
#   Correct   : 194:අම්මා | 801:දැන් | 1186:මුණ ගැසීම
#   Predicted : 194:අම්මා | 801:දැන් | 1186:මුණ ගැසීම
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1410/1437] ඇස් වලට නරකයි.
#   Correct   : 287:ඇස | 699:ට | 858:නරක
#   Predicted : 596:ගස | 699:ට | 1060:බය
#   Overlap   : word=33%  id=33%  exact=✗
#
# [1411/1437] අපි අඳින්න ඕන පැන්සලෙන්ද පෑනෙන්ද
#   Correct   : 185:අපි | 669:චිත්‍ර අදිනවා | 427:ඕන | 972:පැන්සල | 637:ගෙන් | 779:ද? | 978:පෑන | 637:ගෙන් | 779:ද?
#   Predicted : 185:අපි | 669:චිත්‍ර අදිනවා | 427:ඕන | 972:පැන්සල | 637:ගෙන් | 779:ද? | 978:පෑන | 637:ගෙන් | 779:ද?
#   Overlap   : word=78%  id=78%  exact=✓
#
# [1412/1437] මම රුපියල් එක්දහස් පන්සියක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 4:1000 | 64:500 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 4:1000 | 64:500 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1413/1437] අද රැස්වීමට මිනිසුන් එකසිය හැත්තෑඅටක් ආවා.
#   Correct   : 1264:රැස්වීම | 3:100 | 102:78 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Predicted : 1264:රැස්වීම | 3:100 | 102:78 | 478:ක් | 389:එනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1414/1437] මම දැන් සින්දු කියමු
#   Correct   : 1128:මම | 801:දැන් | 625:ගීතයක් | 514:කියනවා
#   Predicted : 1128:මම | 801:දැන් | 625:ගීතයක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1415/1437] පිරිසිදුකම වැදගත්.
#   Correct   : 996:පිරිසුදු කරනවා | 1386:වැදගත්
#   Predicted : 996:පිරිසුදු කරනවා | 1386:වැදගත්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1416/1437] අජන්ත අද බත් කෑවා
#   Correct   : 133:අ | 685:ජ් | 133:අ | 862:න් | 739:ත් | 133:අ | 166:අද | 1054:බත් | 442:කනවා | 330:ඉවරයි
#   Predicted : 133:අ | 685:ජ් | 133:අ | 862:න් | 739:ත් | 133:අ | 166:අද | 1054:බත් | 442:කනවා | 330:ඉවරයි
#   Overlap   : word=80%  id=80%  exact=✓
#
# [1417/1437] මම මිටි වෙන්නම්.
#   Correct   : 1128:මම | 1170:මිටි
#   Predicted : 1128:මම | 1170:මිටි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1418/1437] සුවය
#   Correct   : 1521:සුවය
#   Predicted : 1347:වයස
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1419/1437] යොහාන් හෙට පොතක් කියවනවා
#   Correct   : 1232:ය් | 405:ඔ | 1551:හ් | 241:ආ | 862:න් | 1581:හෙට | 1024:පොත | 478:ක් | 515:කියවනවා
#   Predicted : 1232:ය් | 405:ඔ | 1551:හ් | 241:ආ | 862:න් | 1581:හෙට | 1024:පොත | 515:කියවනවා
#   Overlap   : word=89%  id=89%  exact=✗
#
# [1420/1437] මේසය පිරිසිදු කරන්න.
#   Correct   : 1210:මේසය | 996:පිරිසුදු කරනවා
#   Predicted : 1210:මේසය | 996:පිරිසුදු කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1421/1437] මේ ගෝවා රුපියල් තුන්සිය හැත්තෑහතක්.
#   Correct   : 1205:මෙ | 658:ගෝවා | 1272:රුපියල් | 35:300 | 101:77 | 478:ක්
#   Predicted : 1205:මෙ | 658:ගෝවා | 1272:රුපියල් | 35:300 | 101:77 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1422/1437] ගෑස් ලිප
#   Correct   : 613:ගෑස් ලිප
#   Predicted : 613:ගෑස් ලිප
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1423/1437] ප්‍රමුත් මට සල්ලි දුන්නා
#   Correct   : 941:ප් | 1239:රකාරාංශය | 1145:ම් | 342:උ | 739:ත් | 1119:මට | 1194:මුදල් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 941:ප් | 1239:රකාරාංශය | 1145:ම් | 342:උ | 739:ත් | 1119:මට | 1194:මුදල් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1424/1437] ගීතක හෙට පාසල් යමු
#   Correct   : 602:ග් | 335:ඊ | 739:ත් | 133:අ | 478:ක් | 133:අ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Predicted : 602:ග් | 335:ඊ | 739:ත් | 133:අ | 478:ක් | 133:අ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Overlap   : word=90%  id=90%  exact=✓
#
# [1425/1437] මට රුපියල් හාරසිය හතළිස්හතක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 49:400 | 59:47 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 49:400 | 59:47 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1426/1437] මම බිත්තර එකසිය අසූතුනක් ගත්තා.
#   Correct   : 1128:මම | 1087:බිත්තර | 3:100 | 111:83 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1087:බිත්තර | 3:100 | 111:83 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1427/1437] ගෙවත්තේ ගස් දහනවයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 17:19 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 17:19 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1428/1437] මම මේකට ලියන්න ඕන දිග උත්තරයක්ද
#   Correct   : 1128:මම | 1205:මෙ | 699:ට | 1300:ලියනවා | 427:ඕන | 806:දිග | 1001:පිළිතුර | 478:ක් | 779:ද?
#   Predicted : 1128:මම | 1205:මෙ | 699:ට | 1300:ලියනවා | 427:ඕන | 806:දිග | 1001:පිළිතුර | 478:ක් | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1429/1437] මම තුන්සිය පනස්හත පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 73:57 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 73:57 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1430/1437] සෙම්ගෙඩි
#   Correct   : 1527:සෙම්ගෙඩි
#   Predicted : 1528:සෙම්ප්‍රතික්ශාව
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1431/1437] මේ රොටී රුපියල් විසිහතරක්.
#   Correct   : 1205:මෙ | 1281:රොටී | 1272:රුපියල් | 27:24 | 478:ක්
#   Predicted : 1205:මෙ | 1281:රොටී | 1272:රුපියල් | 27:24 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1432/1437] මට රුපියල් හත්සිය විසිහතක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 92:700 | 30:27 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 92:700 | 30:27 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1433/1437] කසුන් අද මුණගැහෙමු
#   Correct   : 478:ක් | 133:අ | 1485:ස් | 342:උ | 862:න් | 166:අද | 1189:මුණගැහෙමු
#   Predicted : 478:ක් | 133:අ | 1485:ස් | 342:උ | 862:න් | 166:අද | 1189:මුණගැහෙමු
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1434/1437] ලාවන්‍යා දැන් සතුටින් ඉන්නවා
#   Correct   : 1292:ල් | 241:ආ | 1362:ව් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 801:දැන් | 1464:සතුටු | 316:ඉන්නවා
#   Predicted : 1292:ල් | 241:ආ | 1362:ව් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 801:දැන් | 1464:සතුටු | 316:ඉන්නවා
#   Overlap   : word=90%  id=90%  exact=✓
#
# [1435/1437] අම්මා දැන් වැඩ කරනවාද?
#   Correct   : 194:අම්මා | 801:දැන් | 1383:වැඩ කරනවා | 779:ද?
#   Predicted : 194:අම්මා | 801:දැන් | 1383:වැඩ කරනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1436/1437] මම ගෙඩි විස්සහතරදහසක් ගත්තා.
#   Correct   : 1128:මම | 635:ගෙඩියක් | 22:20000 | 50:4000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 635:ගෙඩියක් | 22:20000 | 50:4000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1437/1437] මට බිත්තර තුන්සිය විසිහයක් ඕන.
#   Correct   : 1119:මට | 1087:බිත්තර | 35:300 | 29:26 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1087:බිත්තර | 35:300 | 29:26 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# =======================================================
#   TEST RESULTS
# =======================================================
#   Sentences         : 1437
#   Word Overlap      : 82.65%
#   SSL ID Overlap    : 82.69%
#   Position Accuracy : 81.39%
#   Exact Match       : 70.49%
# =======================================================
#
# ✓ Results → /kaggle/working//test_results.csv

# %%
# ═══════════════════════════════════════════════════════════════════════
# TRANSLATE UNSEEN SINHALA SENTENCES
# Every predicted token is GUARANTEED to be a valid SSL sign token.
# No fuzzy matching needed — out-of-vocab is architecturally impossible.
# ═══════════════════════════════════════════════════════════════════════

UNSEEN_SENTENCES = [
    "ඔයා කොහෙද ඉන්නේ",
    "මම ගෙදර යනවා",
    "ඔයාගේ නම මොකක්ද",
    "අපි හෙට ගමට යමු",
    "ඔබට ස්තූතියි",
    "මම 1ට පාසලට එනවා",
    "මම එකට පාසලට එනවා",
    "අපි සියලු දෙනාම නිමල් සමග යනවා",
    "කුමාර හෙට ගෙදර යනවා",
    "ඇය හෙට කතරගම යනවා",
    "ඔහු ඊයෙ ගම්පහ ගියා",
    "ගුරුවරයා අඹ දහයක් ගෙනාවා"
    "අපි හෙට පාසලට එනවද?",
    "අපි හෙට තැබිලි බොමු"
    # ← add more here
]

print("=" * 65)
print("  UNSEEN SENTENCE PREDICTIONS  (SSL-only decoder)")
print("=" * 65)

for text in UNSEEN_SENTENCES:
    result = translate(text, beam_size=4)
    print(f"\nSource     : {result['source']}")
    print(f"SSL output : {result['ssl_string']}")
    print(f"Tokens     :")
    for tok in result["ssl_tokens"]:
        print(f"  {tok['word']:20s} → Sign ID: {tok['sign_id']}")
    print("-" * 65)


def predict_single(sinhala_text: str) -> Dict:
    """Translate a single Sinhala sentence. Usage: predict_single('ඔයා හොඳද')"""
    result = translate(sinhala_text, beam_size=4)
    print(f"Source : {result['source']}")
    print(f"Output : {result['ssl_string']}")
    return result

# predict_single("ඔයා හොඳද")
# Out:
# =================================================================
#   UNSEEN SENTENCE PREDICTIONS  (SSL-only decoder)
# =================================================================
#
# Source     : ඔයා කොහෙද ඉන්නේ
# SSL output : 408:ඔබ | 567:කොහේද | 316:ඉන්නවා
# Tokens     :
#   ඔබ                   → Sign ID: 408
#   කොහේද                → Sign ID: 567
#   ඉන්නවා               → Sign ID: 316
# -----------------------------------------------------------------
#
# Source     : මම ගෙදර යනවා
# SSL output : 1128:මම | 640:ගෙයක් | 1229:යනවා
# Tokens     :
#   මම                   → Sign ID: 1128
#   ගෙයක්                → Sign ID: 640
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : ඔයාගේ නම මොකක්ද
# SSL output : 409:ඔබගේ | 1064:සම්පූර්ණ නම | 1212:මොකක්ද
# Tokens     :
#   ඔබගේ                 → Sign ID: 409
#   සම්පූර්ණ නම          → Sign ID: 1064
#   මොකක්ද               → Sign ID: 1212
# -----------------------------------------------------------------
#
# Source     : අපි හෙට ගමට යමු
# SSL output : 185:අපි | 1581:හෙට | 478:ක් | 405:ඔ | 1597:ළ් | 133:අ | 1145:ම් | 1073:බ් | 133:අ | 699:ට | 1231:යමු
# Tokens     :
#   අපි                  → Sign ID: 185
#   හෙට                  → Sign ID: 1581
#   ක්                   → Sign ID: 478
#   ඔ                    → Sign ID: 405
#   ළ්                   → Sign ID: 1597
#   අ                    → Sign ID: 133
#   ම්                   → Sign ID: 1145
#   බ්                   → Sign ID: 1073
#   අ                    → Sign ID: 133
#   ට                    → Sign ID: 699
#   යමු                  → Sign ID: 1231
# -----------------------------------------------------------------
#
# Source     : ඔබට ස්තූතියි
# SSL output : 410:ඔබට | 1487:ස්තූතියි
# Tokens     :
#   ඔබට                  → Sign ID: 410
#   ස්තූතියි             → Sign ID: 1487
# -----------------------------------------------------------------
#
# Source     : මම 1ට පාසලට එනවා
# SSL output : 1128:මම | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා
# Tokens     :
#   මම                   → Sign ID: 1128
#   හෙට                  → Sign ID: 1581
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   එනවා                 → Sign ID: 389
# -----------------------------------------------------------------
#
# Source     : මම එකට පාසලට එනවා
# SSL output : 1128:මම | 3:100 | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා
# Tokens     :
#   මම                   → Sign ID: 1128
#   100                  → Sign ID: 3
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   එනවා                 → Sign ID: 389
# -----------------------------------------------------------------
#
# Source     : අපි සියලු දෙනාම නිමල් සමග යනවා
# SSL output : 185:අපි | 187:අපි සියලු දෙනාම | 138:අක්කා | 1470:සමග | 1229:යනවා
# Tokens     :
#   අපි                  → Sign ID: 185
#   අපි සියලු දෙනාම      → Sign ID: 187
#   අක්කා                → Sign ID: 138
#   සමග                  → Sign ID: 1470
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : කුමාර හෙට ගෙදර යනවා
# SSL output : 478:ක් | 342:උ | 1145:ම් | 241:ආ | 1257:ර් | 133:අ | 1581:හෙට | 640:ගෙයක් | 699:ට | 1229:යනවා
# Tokens     :
#   ක්                   → Sign ID: 478
#   උ                    → Sign ID: 342
#   ම්                   → Sign ID: 1145
#   ආ                    → Sign ID: 241
#   ර්                   → Sign ID: 1257
#   අ                    → Sign ID: 133
#   හෙට                  → Sign ID: 1581
#   ගෙයක්                → Sign ID: 640
#   ට                    → Sign ID: 699
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : ඇය හෙට කතරගම යනවා
# SSL output : 263:ඇ | 1581:හෙට | 133:අ | 478:ක් | 342:උ | 1257:ර් | 133:අ | 602:ග් | 133:අ | 1145:ම් | 133:අ | 1229:යනවා
# Tokens     :
#   ඇ                    → Sign ID: 263
#   හෙට                  → Sign ID: 1581
#   අ                    → Sign ID: 133
#   ක්                   → Sign ID: 478
#   උ                    → Sign ID: 342
#   ර්                   → Sign ID: 1257
#   අ                    → Sign ID: 133
#   ග්                   → Sign ID: 602
#   අ                    → Sign ID: 133
#   ම්                   → Sign ID: 1145
#   අ                    → Sign ID: 133
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : ඔහු ඊයෙ ගම්පහ ගියා
# SSL output : 421:ඔහු | 1581:හෙට | 588:ගම්පහ | 1229:යනවා | 330:ඉවරයි
# Tokens     :
#   ඔහු                  → Sign ID: 421
#   හෙට                  → Sign ID: 1581
#   ගම්පහ                → Sign ID: 588
#   යනවා                 → Sign ID: 1229
#   ඉවරයි                → Sign ID: 330
# -----------------------------------------------------------------
#
# Source     : ගුරුවරයා අඹ දහයක් ගෙනාවාඅපි හෙට පාසලට එනවද?
# SSL output : 626:ගුරුතුමා | 133:අ | 1145:ම් | 133:අ | 862:න් | 1223:යංශය | 241:ආ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා | 779:ද?
# Tokens     :
#   ගුරුතුමා             → Sign ID: 626
#   අ                    → Sign ID: 133
#   ම්                   → Sign ID: 1145
#   අ                    → Sign ID: 133
#   න්                   → Sign ID: 862
#   යංශය                 → Sign ID: 1223
#   ආ                    → Sign ID: 241
#   හෙට                  → Sign ID: 1581
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   එනවා                 → Sign ID: 389
#   ද?                   → Sign ID: 779
# -----------------------------------------------------------------
#
# Source     : අපි හෙට තැබිලි බොමු
# SSL output : 185:අපි | 1581:හෙට | 1087:බිත්තර | 1103:බොනවා
# Tokens     :
#   අපි                  → Sign ID: 185
#   හෙට                  → Sign ID: 1581
#   බිත්තර               → Sign ID: 1087
#   බොනවා                → Sign ID: 1103
# -----------------------------------------------------------------
