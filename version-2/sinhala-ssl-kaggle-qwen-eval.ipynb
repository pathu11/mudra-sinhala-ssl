# %% [markdown]
# # Sinhala → SSL Translation — Separate Decoder Vocabulary
# ## Architecture: Qwen3 0.6B Encoder + Custom SSL-Only Decoder Vocab
# ---
# **Key difference from previous version:**
# - Encoder input : Qwen3 tokenizer — understands Sinhala with high-efficiency subwords
# - Decoder output: SSL-only vocabulary (~1,500 tokens) — **cannot predict outside SSL**
# - Model is architecturally impossible to output any non-SSL token

# %%
# !pip install transformers sentencepiece -q

import torch
print("PyTorch :", torch.__version__)
print("CUDA    :", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU     :", torch.cuda.get_device_name(0))
    print("VRAM    :", round(torch.cuda.get_device_properties(0).total_memory/1e9,1), "GB")
# Out:
# PyTorch : 2.10.0+cu128
# CUDA    : True
# GPU     : Tesla T4
# VRAM    : 15.6 GB

# %%
import os

class CFG:
    # ── Paths ──────────────────────────────────────────────────────────
    CORPUS_FILE   = "/kaggle/input/datasets/nadeenudantha/full-corpus3-converted/full-corpus3-converted.txt"
    OUTPUT_DIR    = "/kaggle/working"
    MODEL_DIR     = "/kaggle/working/models"
    LOG_FILE      = "/kaggle/working/training_log.csv"

    # ── Encoder: Qwen3 0.6B ──────────────────────────────────────────
    ENCODER_MODEL = "Qwen/Qwen3-0.6B-Base"
    ENC_DIM       = 1024
    ENC_HEADS     = 16

    # ── Decoder: SSL-only vocabulary (output side) ─────────────────────
    PAD_IDX  = 0
    BOS_IDX  = 1
    EOS_IDX  = 2
    UNK_IDX  = 3
    OFFSET   = 4

    D_MODEL      = 512
    N_HEADS      = 8
    N_DEC_LAYERS = 4
    DIM_FFN      = 2048
    DROPOUT      = 0.1
    MAX_SRC_LEN  = 64
    MAX_TGT_LEN  = 32

    # ── Training ───────────────────────────────────────────────────────
    EPOCHS       = 50
    BATCH_SIZE   = 32
    ENCODER_LR   = 2e-5
    DECODER_LR   = 5e-4
    WEIGHT_DECAY = 1e-2
    WARMUP_RATIO = 0.1
    GRAD_CLIP    = 1.0
    ACCUM_STEPS  = 1
    LABEL_SMOOTH = 0.1
    PATIENCE     = 10

    # ── Split ──────────────────────────────────────────────────────────
    TEST_RATIO   = 0.15
    VAL_RATIO    = 0.10
    SEED         = 42

    # ── Memory ─────────────────────────────────────────────────────────
    USE_AMP      = True
    GRAD_CKPT    = False
    NUM_WORKERS  = 2
    PIN_MEMORY   = True

os.makedirs(CFG.MODEL_DIR, exist_ok=True)
print("Config ready for Qwen3 0.6B (Dim: 1024)")
# Out:
# Config ready for Qwen3 0.6B (Dim: 1024)

# %%
# !pip install --upgrade transformers -q
import re, json, math, random, warnings
from pathlib import Path
from typing import List, Dict, Tuple, Optional

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import GradScaler, autocast
from transformers import AutoTokenizer, AutoModel, get_linear_schedule_with_warmup

warnings.filterwarnings("ignore")

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(CFG.SEED)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 90.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.5/645.5 kB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 98.3 MB/s eta 0:00:00
# Device: cuda

# %%
class SSLVocabulary:
    """
    Dedicated decoder-side vocabulary containing ONLY your SSL gloss words.
    ─────────────────────────────────────────────────────────────────────
    Special tokens:
        0 → <PAD>
        1 → <BOS>
        2 → <EOS>
        3 → <UNK>

    Real SSL tokens start at index 4.

    The decoder output_proj layer has exactly SSL_VOCAB_SIZE outputs.
    It is architecturally impossible for the model to predict
    any token outside this vocabulary.
    """

    SPECIAL = {
        "<PAD>": 0,
        "<BOS>": 1,
        "<EOS>": 2,
        "<UNK>": 3,
    }

    def __init__(self):
        self.word2idx : Dict[str, int] = dict(self.SPECIAL)
        self.idx2word : Dict[int, str] = {v: k for k, v in self.SPECIAL.items()}
        self.word2id  : Dict[str, int] = {}   # gloss word → original SSL ID
        self.id2word  : Dict[int, str] = {}   # original SSL ID → gloss word

    # ── Build from corpus ──────────────────────────────────────────────
    def build(self, pairs: List[Dict]) -> "SSLVocabulary":
        idx = CFG.OFFSET   # start after special tokens
        for pair in pairs:
            for word, tid in zip(pair["gloss_words"], pair["target_ids"]):
                # Register SSL sign ID mapping
                self.word2id[word] = tid
                self.id2word[tid]  = word
                # Register in decoder vocab if new
                if word not in self.word2idx:
                    self.word2idx[word] = idx
                    self.idx2word[idx]  = word
                    idx += 1
        print(f"SSL decoder vocabulary:")
        print(f"  Special tokens  : 4  (PAD, BOS, EOS, UNK)")
        print(f"  SSL gloss words : {idx - CFG.OFFSET}")
        print(f"  Total vocab size: {idx}  ← decoder output size")
        print(f"  XLM-R vocab size: 250,002  ← encoder input size")
        print(f"  Model can ONLY output one of {idx} tokens")
        return self

    @property
    def size(self) -> int:
        return len(self.word2idx)

    # ── Encode/decode ──────────────────────────────────────────────────
    def encode(self, words: List[str]) -> List[int]:
        """Convert list of gloss words → decoder indices."""
        return [self.word2idx.get(w, CFG.UNK_IDX) for w in words]

    def decode(self, indices: List[int]) -> List[str]:
        """Convert decoder indices → gloss words (skip special tokens)."""
        return [
            self.idx2word[i] for i in indices
            if i >= CFG.OFFSET and i in self.idx2word
        ]

    def word_to_ssl_id(self, word: str) -> Optional[int]:
        """Get original SSL sign ID for a gloss word."""
        return self.word2id.get(word)

    # ── Save / load ────────────────────────────────────────────────────
    def save(self, path: str):
        data = {
            "word2idx": self.word2idx,
            "idx2word": {str(k): v for k, v in self.idx2word.items()},
            "word2id" : self.word2id,
            "id2word" : {str(k): v for k, v in self.id2word.items()},
        }
        with open(path, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=2)
        print(f"✓ SSL vocabulary saved → {path}")

    @classmethod
    def load(cls, path: str) -> "SSLVocabulary":
        with open(path, "r", encoding="utf-8") as f:
            data = json.load(f)
        v = cls()
        v.word2idx = data["word2idx"]
        v.idx2word = {int(k): w for k, w in data["idx2word"].items()}
        v.word2id  = data["word2id"]
        v.id2word  = {int(k): w for k, w in data["id2word"].items()}
        return v

# %%
class CorpusParser:
    """
    Parses: sentence @ id:word | id:word | ...

    Encoder input  : Sinhala text  (tokenized by XLM-RoBERTa)
    Decoder output : SSL indices   (from SSLVocabulary, not XLM-R)
    """

    def __init__(self):
        self.pairs: List[Dict] = []

    def parse_file(self, path: str) -> "CorpusParser":
        with open(path, "r", encoding="utf-8") as f:
            raw = f.read()
        skipped = 0
        for line in raw.strip().splitlines():
            line = line.strip()
            if not line or "@" not in line:
                skipped += 1
                continue
            pair = self._parse_line(line)
            if pair:
                self.pairs.append(pair)
        print(f"✓ Parsed {len(self.pairs)} pairs | skipped {skipped}")
        return self

    def _parse_line(self, line: str) -> Optional[Dict]:
        src_raw, tgt_raw = line.split("@", 1)
        source      = src_raw.strip()
        gloss_words = []
        target_ids  = []
        for item in tgt_raw.strip().split("|"):
            item = item.strip()
            if ":" not in item:
                continue
            tid_str, word = item.split(":", 1)
            word = word.strip()
            try:    tid = int(tid_str.strip())
            except: continue
            gloss_words.append(word)
            target_ids.append(tid)
        if not gloss_words:
            return None
        return {
            "source"     : source,
            "gloss_words": gloss_words,
            "target_ids" : target_ids,
        }


# ── Parse + build SSL vocab ────────────────────────────────────────────
parser   = CorpusParser().parse_file(CFG.CORPUS_FILE)
ssl_vocab = SSLVocabulary().build(parser.pairs)
ssl_vocab.save(f"{CFG.MODEL_DIR}/ssl_vocab.json")

# Stats
src_lens = [len(p["source"].split())  for p in parser.pairs]
tgt_lens = [len(p["gloss_words"])     for p in parser.pairs]
print(f"\nDataset stats:")
print(f"  Pairs          : {len(parser.pairs)}")
print(f"  Max src words  : {max(src_lens)}")
print(f"  Max tgt words  : {max(tgt_lens)}")
print(f"  Avg tgt words  : {sum(tgt_lens)/len(tgt_lens):.1f}")
# Out:
# ✓ Parsed 11021 pairs | skipped 0
# SSL decoder vocabulary:
#   Special tokens  : 4  (PAD, BOS, EOS, UNK)
#   SSL gloss words : 1531
#   Total vocab size: 1535  ← decoder output size
#   XLM-R vocab size: 250,002  ← encoder input size
#   Model can ONLY output one of 1535 tokens
# ✓ SSL vocabulary saved → /kaggle/working/models/ssl_vocab.json
#
# Dataset stats:
#   Pairs          : 11021
#   Max src words  : 12
#   Max tgt words  : 17
#   Avg tgt words  : 5.2

# %%
def split_dataset(pairs):
    random.seed(CFG.SEED)
    data = pairs.copy()
    random.shuffle(data)
    n       = len(data)
    n_test  = max(1, int(n * CFG.TEST_RATIO))
    n_val   = max(1, int(n * CFG.VAL_RATIO))
    n_train = n - n_test - n_val
    train = data[:n_train]
    val   = data[n_train : n_train + n_val]
    test  = data[n_train + n_val :]
    print(f"Split → Train:{len(train)}  Val:{len(val)}  Test:{len(test)}")
    return train, val, test

train_pairs, val_pairs, test_pairs = split_dataset(parser.pairs)

for name, pairs in [("train", train_pairs),
                     ("val",   val_pairs),
                     ("test",  test_pairs)]:
    pd.DataFrame([{"source": p["source"],
                   "target": " ".join(p["gloss_words"])}
                  for p in pairs]).to_csv(
        f"{CFG.OUTPUT_DIR}/{name}_split.csv",
        index=False, encoding="utf-8")
print("✓ Split CSVs saved")
# Out:
# Split → Train:8266  Val:1102  Test:1653
# ✓ Split CSVs saved

# %%
print(f"Loading encoder tokenizer: {CFG.ENCODER_MODEL}")
enc_tokenizer = AutoTokenizer.from_pretrained(CFG.ENCODER_MODEL)

class SinhalaSSLDataset(Dataset):
    def __init__(self, pairs, enc_tokenizer, ssl_vocab: SSLVocabulary):
        self.pairs         = pairs
        self.enc_tokenizer = enc_tokenizer
        self.ssl_vocab     = ssl_vocab

    def __len__(self): return len(self.pairs)

    def __getitem__(self, idx):
        pair = self.pairs[idx]
        src = self.enc_tokenizer(
            pair["source"],
            max_length    = CFG.MAX_SRC_LEN,
            padding       = "max_length",
            truncation    = True,
            return_tensors= "pt",
        )
        ssl_indices = self.ssl_vocab.encode(pair["gloss_words"])
        dec_input  = [CFG.BOS_IDX] + ssl_indices
        dec_target = ssl_indices   + [CFG.EOS_IDX]

        def pad(seq):
            seq = seq[:CFG.MAX_TGT_LEN]
            return seq + [CFG.PAD_IDX] * (CFG.MAX_TGT_LEN - len(seq))

        return {
            "input_ids"     : src["input_ids"].squeeze(0),
            "attention_mask": src["attention_mask"].squeeze(0),
            "dec_input"     : torch.tensor(pad(dec_input),  dtype=torch.long),
            "dec_target"    : torch.tensor(pad(dec_target), dtype=torch.long),
            "source_text"   : pair["source"],
            "gloss_words"   : pair["gloss_words"],
            "target_ids"    : pair["target_ids"],
        }

def collate_fn(batch):
    return {
        "input_ids"     : torch.stack([b["input_ids"]      for b in batch]),
        "attention_mask": torch.stack([b["attention_mask"]  for b in batch]),
        "dec_input"     : torch.stack([b["dec_input"]       for b in batch]),
        "dec_target"    : torch.stack([b["dec_target"]      for b in batch]),
        "source_text"   : [b["source_text"]                 for b in batch],
        "gloss_words"   : [b["gloss_words"]                 for b in batch],
        "target_ids"    : [b["target_ids"]                  for b in batch],
    }

train_ds = SinhalaSSLDataset(train_pairs, enc_tokenizer, ssl_vocab)
val_ds   = SinhalaSSLDataset(val_pairs,   enc_tokenizer, ssl_vocab)
test_ds  = SinhalaSSLDataset(test_pairs,  enc_tokenizer, ssl_vocab)

train_dl = DataLoader(train_ds, batch_size=CFG.BATCH_SIZE, shuffle=True,
                      collate_fn=collate_fn, num_workers=CFG.NUM_WORKERS,
                      pin_memory=CFG.PIN_MEMORY)
val_dl   = DataLoader(val_ds,   batch_size=CFG.BATCH_SIZE, shuffle=False,
                      collate_fn=collate_fn, num_workers=CFG.NUM_WORKERS,
                      pin_memory=CFG.PIN_MEMORY)
test_dl  = DataLoader(test_ds,  batch_size=CFG.BATCH_SIZE, shuffle=False,
                      collate_fn=collate_fn, num_workers=CFG.NUM_WORKERS,
                      pin_memory=CFG.PIN_MEMORY)

print(f"\nDataloaders ready with {CFG.ENCODER_MODEL}")
# Out:
# Loading encoder tokenizer: Qwen/Qwen3-0.6B-Base
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Dataloaders ready with Qwen/Qwen3-0.6B-Base

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512, dropout=0.1):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        pe  = torch.zeros(max_len, d_model)
        pos = torch.arange(max_len).unsqueeze(1).float()
        div = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(pos * div)
        pe[:, 1::2] = torch.cos(pos * div)
        self.register_buffer("pe", pe.unsqueeze(0))
    def forward(self, x):
        return self.dropout(x + self.pe[:, :x.size(1)])

class SinhalaSSLTransformer(nn.Module):
    def __init__(self, encoder, ssl_vocab: SSLVocabulary, cfg=CFG):
        super().__init__()
        self.cfg      = cfg
        self.ssl_vocab = ssl_vocab
        ssl_vocab_size = ssl_vocab.size

        self.encoder = encoder
        if cfg.GRAD_CKPT:
            self.encoder.gradient_checkpointing_enable()

        self.enc_proj = nn.Linear(cfg.ENC_DIM, cfg.D_MODEL) if cfg.ENC_DIM != cfg.D_MODEL else nn.Identity()

        self.dec_embedding = nn.Embedding(ssl_vocab_size, cfg.D_MODEL, padding_idx=cfg.PAD_IDX)
        nn.init.normal_(self.dec_embedding.weight, std=0.02)
        self.pos_enc = PositionalEncoding(cfg.D_MODEL, max_len=cfg.MAX_TGT_LEN + 10, dropout=cfg.DROPOUT)

        dec_layer = nn.TransformerDecoderLayer(d_model=cfg.D_MODEL, nhead=cfg.N_HEADS, dim_feedforward=cfg.DIM_FFN, dropout=cfg.DROPOUT, batch_first=True, norm_first=True)
        self.decoder = nn.TransformerDecoder(dec_layer, num_layers=cfg.N_DEC_LAYERS)
        self.output_proj = nn.Linear(cfg.D_MODEL, ssl_vocab_size, bias=False)

    def encode(self, input_ids, attention_mask):
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        hidden = outputs.last_hidden_state
        hidden = hidden.to(self.enc_proj.weight.dtype)
        return self.enc_proj(hidden)

    def decode_step(self, tgt_ids, memory, attn_mask=None):
        tgt_len  = tgt_ids.size(1)
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(tgt_len, device=tgt_ids.device).bool()
        tgt_pad  = (tgt_ids == CFG.PAD_IDX)
        mem_pad  = (attn_mask == 0) if attn_mask is not None else None
        tgt_emb  = self.pos_enc(self.dec_embedding(tgt_ids))
        return self.decoder(tgt=tgt_emb, memory=memory, tgt_mask=tgt_mask, tgt_key_padding_mask=tgt_pad, memory_key_padding_mask=mem_pad)

    def forward(self, input_ids, attention_mask, dec_input):
        memory  = self.encode(input_ids, attention_mask)
        dec_out = self.decode_step(dec_input, memory, attention_mask)
        return self.output_proj(dec_out)

print(f"Loading Qwen encoder: {CFG.ENCODER_MODEL}")
encoder = AutoModel.from_pretrained(CFG.ENCODER_MODEL, trust_remote_code=True,attn_implementation="sdpa", torch_dtype=torch.bfloat16)
model   = SinhalaSSLTransformer(encoder, ssl_vocab, CFG).to(DEVICE)

# Freeze entire encoder
for p in model.encoder.parameters():
    p.requires_grad = False

# Unfreeze last 4 encoder layers
for layer in model.encoder.layers[-4:]:
    for p in layer.parameters():
        p.requires_grad = True

if torch.cuda.device_count() > 1:
    model = nn.DataParallel(model)

def _get_base(m):
    while hasattr(m, '_orig_mod'): m = m._orig_mod
    while hasattr(m, 'module'):    m = m.module
    return m
_base = _get_base(model)

model = torch.compile(model)
# Out:
# Loading Qwen encoder: Qwen/Qwen3-0.6B-Base
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]

# %%
optimizer = torch.optim.AdamW([
    {"params": _base.encoder.parameters(),       "lr": CFG.ENCODER_LR, "weight_decay": CFG.WEIGHT_DECAY},
    {"params": _base.decoder.parameters(),       "lr": CFG.DECODER_LR, "weight_decay": CFG.WEIGHT_DECAY},
    {"params": _base.dec_embedding.parameters(), "lr": CFG.DECODER_LR, "weight_decay": 0.0},
    {"params": _base.output_proj.parameters(),   "lr": CFG.DECODER_LR, "weight_decay": 0.0},
    {"params": _base.enc_proj.parameters(),      "lr": CFG.DECODER_LR, "weight_decay": 0.0},
], eps=1e-8)

total_steps  = (len(train_dl) // CFG.ACCUM_STEPS) * CFG.EPOCHS
warmup_steps = int(total_steps * CFG.WARMUP_RATIO)

scheduler = get_linear_schedule_with_warmup(
    optimizer, warmup_steps, total_steps)
scaler    = GradScaler(enabled=CFG.USE_AMP)
criterion = nn.CrossEntropyLoss(
    ignore_index=CFG.PAD_IDX, label_smoothing=CFG.LABEL_SMOOTH)

print(f"Total steps  : {total_steps}")
print(f"Warmup steps : {warmup_steps}")


def token_accuracy(logits, targets):
    """Accuracy over non-PAD SSL tokens only."""
    preds   = logits.argmax(dim=-1)
    mask    = (targets != CFG.PAD_IDX)
    correct = ((preds == targets) & mask).sum().item()
    total   = mask.sum().item()
    return correct / total if total > 0 else 0.0
# Out:
# Total steps  : 12950
# Warmup steps : 1295

# %%
# history = {"epoch":[], "train_loss":[], "val_loss":[], "train_acc":[], "val_acc":[]}
# best_val_loss = float("inf")
# best_epoch = 0
# patience_counter = 0

# _enc_dtype = _base.encoder.dtype

# model.to(DEVICE)
# model.to(_enc_dtype)

# # BFloat16 usually doesn't need GradScaler
# use_scaler = CFG.USE_AMP and _enc_dtype == torch.float16

# def train_epoch():
#     model.train()
#     tot_loss = tot_acc = 0.0
#     optimizer.zero_grad()
#     for step, batch in enumerate(train_dl):
#         ids   = batch["input_ids"].to(DEVICE)
#         mask  = batch["attention_mask"].to(DEVICE)
#         d_in  = batch["dec_input"].to(DEVICE)
#         d_tgt = batch["dec_target"].to(DEVICE)

#         with autocast(enabled=CFG.USE_AMP, dtype=_enc_dtype):
#             logits = model(ids, mask, d_in)
#             loss   = criterion(logits.reshape(-1, ssl_vocab.size), d_tgt.reshape(-1)) / CFG.ACCUM_STEPS

#         if use_scaler:
#             scaler.scale(loss).backward()
#         else:
#             loss.backward()

#         if (step + 1) % CFG.ACCUM_STEPS == 0:
#             if use_scaler:
#                 scaler.unscale_(optimizer)
#                 nn.utils.clip_grad_norm_(model.parameters(), CFG.GRAD_CLIP)
#                 scaler.step(optimizer)
#                 scaler.update()
#             else:
#                 nn.utils.clip_grad_norm_(model.parameters(), CFG.GRAD_CLIP)
#                 optimizer.step()
#             scheduler.step()
#             optimizer.zero_grad()

#         tot_loss += loss.item() * CFG.ACCUM_STEPS
#         tot_acc  += token_accuracy(logits.detach(), d_tgt)
#     return tot_loss / len(train_dl), tot_acc / len(train_dl)

# @torch.no_grad()
# def validate(dl):
#     model.eval()
#     tot_loss = tot_acc = 0.0
#     for batch in dl:
#         ids, mask = batch["input_ids"].to(DEVICE), batch["attention_mask"].to(DEVICE)
#         d_in, d_tgt = batch["dec_input"].to(DEVICE), batch["dec_target"].to(DEVICE)
#         with autocast(enabled=CFG.USE_AMP, dtype=_enc_dtype):
#             logits = model(ids, mask, d_in)
#             loss   = criterion(logits.reshape(-1, ssl_vocab.size), d_tgt.reshape(-1))
#         tot_loss += loss.item()
#         tot_acc  += token_accuracy(logits, d_tgt)
#     return tot_loss / len(dl), tot_acc / len(dl)

# print(f"{'─'*68}\n{'Epoch':>6} | {'TrainLoss':>9} | {'ValLoss':>7} | {'TrainAcc':>8} | {'ValAcc':>6} | {'':>8}\n{'─'*68}")

# import time
# train_start = time.time()
# for epoch in range(1, CFG.EPOCHS + 1):
#     tr_loss, tr_acc = train_epoch()
#     vl_loss, vl_acc = validate(val_dl)
#     history["epoch"].append(epoch); history["train_loss"].append(tr_loss); history["val_loss"].append(vl_loss)
#     history["train_acc"].append(tr_acc); history["val_acc"].append(vl_acc)
#     note = ""
#     if vl_loss < best_val_loss:
#         best_val_loss, best_epoch, patience_counter, note = vl_loss, epoch, 0, "✓ best"
#         torch.save({"epoch": epoch, "model_state": model.state_dict(), "val_loss": vl_loss, "ssl_vocab_size": ssl_vocab.size}, f"{CFG.MODEL_DIR}/best_model.pt")
#     else:
#         patience_counter += 1
#         if patience_counter >= CFG.PATIENCE: break
#     print(f"{epoch:6d} | {tr_loss:9.4f} | {vl_loss:7.4f} | {tr_acc*100:7.2f}% | {vl_acc*100:5.2f}% | {note}")
# print(f"Training time: {(time.time() - train_start) / 60:.2f} min")

# torch.save(model.state_dict(), f"{CFG.MODEL_DIR}/final_model.pt")
# pd.DataFrame(history).to_csv(CFG.LOG_FILE, index=False)

# %%
# fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# fig.suptitle("Training History — SSL-Only Decoder Vocab", fontsize=13)
# epochs = history["epoch"]

# axes[0].plot(epochs, history["train_loss"], label="Train", color="#2563eb", lw=2)
# axes[0].plot(epochs, history["val_loss"],   label="Val",   color="#dc2626", lw=2)
# axes[0].axvline(best_epoch, color="#16a34a", linestyle="--", alpha=0.7,
#                 label=f"Best (ep {best_epoch})")
# axes[0].set_title("Loss"); axes[0].set_xlabel("Epoch")
# axes[0].legend(); axes[0].grid(alpha=0.3)

# axes[1].plot(epochs, [a*100 for a in history["train_acc"]],
#              label="Train", color="#2563eb", lw=2)
# axes[1].plot(epochs, [a*100 for a in history["val_acc"]],
#              label="Val",   color="#dc2626", lw=2)
# axes[1].axvline(best_epoch, color="#16a34a", linestyle="--", alpha=0.7)
# axes[1].set_title("Token Accuracy (%)"); axes[1].set_xlabel("Epoch")
# axes[1].legend(); axes[1].grid(alpha=0.3)

# plt.tight_layout()
# plt.savefig(f"{CFG.OUTPUT_DIR}/training_curves.png",
#             dpi=150, bbox_inches="tight")
# plt.show()

# df_h = pd.DataFrame(history)
# print("Top 5 epochs by Val Loss:")
# print(df_h.nsmallest(5, "val_loss")
#          [["epoch","train_loss","val_loss","train_acc","val_acc"]]
#          .to_string(index=False))

# %%
# ── Load best model ────────────────────────────────────────────────────
#ckpt = torch.load(f"{CFG.MODEL_DIR}/best_model.pt", map_location=DEVICE)
#model.load_state_dict(ckpt["model_state"])

ckpt = torch.load(f"/kaggle/input/models/nadeenudantha/sinhala-ssl-kaggle-qwen/transformers/default/2/models/best_model.pt", map_location=DEVICE)
state_dict = {k[len("module."):] if k.startswith("module.") else k: v
              for k, v in ckpt["model_state"].items()}
model.load_state_dict(state_dict)

model.eval()
_base = _get_base(model)
print(f"✓ Best model loaded (epoch {ckpt['epoch']}, "
      f"val_loss={ckpt['val_loss']:.4f}")


@torch.no_grad()
def beam_search(memory, attn_mask, beam_size=4):
    beams = [([CFG.BOS_IDX], 0.0)]
    done  = []

    for _ in range(CFG.MAX_TGT_LEN):
        cands = []
        for seq, score in beams:
            tgt     = torch.tensor([seq], device=DEVICE)
            dec_out = _base.decode_step(tgt, memory, attn_mask)
            logits  = _base.output_proj(dec_out[:, -1, :]).squeeze(0)
            lp      = F.log_softmax(logits, dim=-1)
            top_v, top_i = lp.topk(min(beam_size, ssl_vocab.size - 1))
            for v, i in zip(top_v.tolist(), top_i.tolist()):
                cands.append((seq + [i], score + v))

        cands.sort(key=lambda x: x[1], reverse=True)
        beams = []
        for seq, sc in cands[:beam_size * 2]:
            if seq[-1] == CFG.EOS_IDX:
                done.append((seq[1:-1], sc / max(len(seq)-2, 1)))
            else:
                beams.append((seq, sc))
            if len(beams) >= beam_size:
                break
        if not beams:
            break

    if done:
        done.sort(key=lambda x: x[1], reverse=True)
        return done[0][0]
    return beams[0][0][1:] if beams else []


def translate(text: str, beam_size: int = 4) -> Dict:
    model.eval()
    enc = enc_tokenizer(
        text, max_length=CFG.MAX_SRC_LEN,
        padding="max_length", truncation=True,
        return_tensors="pt").to(DEVICE)
    
    memory = _base.encode(enc["input_ids"], enc["attention_mask"])
    indices = beam_search(memory, enc["attention_mask"], beam_size)

    gloss_words = ssl_vocab.decode(indices)
    ssl_tokens = []
    for word in gloss_words:
        sid = ssl_vocab.word_to_ssl_id(word)
        ssl_tokens.append({"word": word, "sign_id": sid})

    return {
        "source"     : text,
        "gloss_words": gloss_words,
        "ssl_tokens" : ssl_tokens,
        "ssl_string" : " | ".join(
            f"{t['sign_id']}:{t['word']}" for t in ssl_tokens),
    }

print("✓ Translator ready")
print(f"  Decoder vocab size : {ssl_vocab.size} (SSL tokens only)")
print(f"  Encoder vocab size : {enc_tokenizer.vocab_size} (Qwen3)")
# Out:
# ✓ Best model loaded (epoch 42, val_loss=1.3959
# ✓ Translator ready
#   Decoder vocab size : 1535 (SSL tokens only)
#   Encoder vocab size : 151643 (Qwen3)

# %%
rows = []
print(f"Evaluating {len(test_pairs)} test sentences ...\n")
print("─" * 70)

import time
eval_start = time.time()
for i, pair in enumerate(test_pairs):
    pred = translate(pair["source"])

    correct_words  = pair["gloss_words"]
    correct_ids    = pair["target_ids"]
    pred_words     = pred["gloss_words"]
    pred_ids       = [t["sign_id"] for t in pred["ssl_tokens"]]

    correct_string = " | ".join(
        f"{tid}:{w}" for tid, w in zip(correct_ids, correct_words))

    word_overlap = len(set(correct_words) & set(pred_words)) / max(len(correct_words), 1)
    id_overlap   = len(set(correct_ids)   & set(pred_ids))   / max(len(correct_ids),   1)
    min_len      = min(len(correct_words), len(pred_words))
    pos_acc      = sum(1 for j in range(min_len)
                       if correct_words[j] == pred_words[j]) / max(len(correct_words), 1)
    exact        = int(correct_words == pred_words)

    rows.append({
        "source"           : pair["source"],
        "correct_words"    : " | ".join(correct_words),
        "predicted_words"  : " | ".join(pred_words),
        "correct_ids"      : " | ".join(str(x) for x in correct_ids),
        "predicted_ids"    : " | ".join(str(x) for x in pred_ids),
        "correct_string"   : correct_string,
        "predicted_string" : pred["ssl_string"],
        "word_overlap_%"   : round(word_overlap * 100, 1),
        "id_overlap_%"     : round(id_overlap   * 100, 1),
        "pos_accuracy_%"   : round(pos_acc      * 100, 1),
        "exact_match"      : exact,
        "correct_len"      : len(correct_words),
        "predicted_len"    : len(pred_words),
    })

    print(f"[{i+1}/{len(test_pairs)}] {pair['source']}")
    print(f"  Correct   : {correct_string}")
    print(f"  Predicted : {pred['ssl_string']}")
    print(f"  Overlap   : word={word_overlap*100:.0f}%  "
          f"id={id_overlap*100:.0f}%  exact={'✓' if exact else '✗'}")
    print()

eval_secs = time.time() - eval_start
print(f"Eval: {eval_secs:.2f}s  |  Avg: {eval_secs/len(test_pairs)*1000:.1f}ms/sentence")

df = pd.DataFrame(rows)
df.to_csv(f"{CFG.OUTPUT_DIR}/test_results.csv", index=False, encoding="utf-8")

print("=" * 55)
print("  TEST RESULTS")
print("=" * 55)
print(f"  Sentences         : {len(df)}")
print(f"  Word Overlap      : {df['word_overlap_%'].mean():.2f}%")
print(f"  SSL ID Overlap    : {df['id_overlap_%'].mean():.2f}%")
print(f"  Position Accuracy : {df['pos_accuracy_%'].mean():.2f}%")
print(f"  Exact Match       : {df['exact_match'].mean()*100:.2f}%")
print("=" * 55)
print(f"\n✓ Results → {CFG.OUTPUT_DIR}/test_results.csv")
# Out:
# Evaluating 1653 test sentences ...
#
# ──────────────────────────────────────────────────────────────────────
# [1/1653] කෞෂල්‍ය හෙට වතුර බොනවා
#   Correct   : 478:ක් | 561:ගයනු කිත්ත | 1455:ෂ් | 133:අ | 1292:ල් | 1223:යංශය | 1581:හෙට | 1336:වතුර | 1103:බොනවා
#   Predicted : 478:ක් | 561:ගයනු කිත්ත | 1455:ෂ් | 133:අ | 1292:ල් | 1223:යංශය | 1581:හෙට | 1336:වතුර | 1103:බොනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [2/1653] ක්‍රිශාන්ත අද බත් උයනවා
#   Correct   : 478:ක් | 1239:රකාරාංශය | 296:ඉ | 1452:ශ් | 241:ආ | 862:න් | 739:ත් | 133:අ | 166:අද | 1054:බත් | 375:උයනවා
#   Predicted : 478:ක් | 1239:රකාරාංශය | 296:ඉ | 1452:ශ් | 241:ආ | 862:න් | 739:ත් | 133:අ | 166:අද | 1054:බත් | 375:උයනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [3/1653] හැමවෙලේම
#   Correct   : 1565:හැමවෙලේම
#   Predicted : 1566:හැමෝම
#   Overlap   : word=0%  id=0%  exact=✗
#
# [4/1653] මම රුපියල් 423 ක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 49:400 | 26:23 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 49:400 | 26:23 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [5/1653] අපි ගිලන් රථයට කතා කරනවා
#   Correct   : 185:අපි | 623:ගිලන්‍ රථය | 699:ට | 439:කතා කරනවා
#   Predicted : 185:අපි | 619:ගියා | 699:ට | 439:කතා කරනවා
#   Overlap   : word=75%  id=75%  exact=✗
#
# [6/1653] උප්පැන්න සහතිකය ගන්න
#   Correct   : 374:උප්පැන්න සහතිකය | 583:ගන්න
#   Predicted : 374:උප්පැන්න සහතිකය | 583:ගන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [7/1653] ළමයි පාසලේ ගොඩනැගිලි හදන්න දෙනවා
#   Correct   : 1596:ළමයි | 334:ඉස්කෝලෙ | 649:ගොඩනැගිලි | 1538:හදනවා | 834:දෙනවා
#   Predicted : 1596:ළමයි | 334:ඉස්කෝලෙ | 650:ගොඩාක් | 649:ගොඩනැගිලි | 1538:හදනවා | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✗
#
# [8/1653] අපි බොරු කියන්නම්.
#   Correct   : 185:අපි | 1104:බොරු | 514:කියනවා
#   Predicted : 185:අපි | 1104:බොරු | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [9/1653] අපි ගුරුවරුන්ට ණයගැතියි.
#   Correct   : 185:අපි | 628:ගුරුවරු | 699:ට | 714:ණය
#   Predicted : 185:අපි | 628:ගුරුවරු | 699:ට | 714:ණය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [10/1653] මට ගෝවා 284 ක් ඕන.
#   Correct   : 1119:මට | 658:ගෝවා | 20:200 | 112:84 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 658:ගෝවා | 20:200 | 112:84 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [11/1653] ඔව් තේ බොන්න කැමතියි.
#   Correct   : 415:ඔව් | 768:තේ | 1103:බොනවා | 501:කැමති
#   Predicted : 415:ඔව් | 768:තේ | 1103:බොනවා | 501:කැමති
#   Overlap   : word=100%  id=100%  exact=✓
#
# [12/1653] අපි එන්නද?
#   Correct   : 185:අපි | 389:එනවා | 779:ද?
#   Predicted : 185:අපි | 389:එනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [13/1653] මල් පෝච්චිය රතු පාට කරමු.
#   Correct   : 1134:මල් පෝච්චිය | 1243:රතු | 951:පාට | 952:පාට කරනවා
#   Predicted : 1134:මල් පෝච්චිය | 1243:රතු | 951:පාට
#   Overlap   : word=75%  id=75%  exact=✗
#
# [14/1653] ටිකක් පුලුවන් ගුරුතුමී.
#   Correct   : 705:ටිකයි | 1012:පුලුවන් | 627:ගුරුතුමිය
#   Predicted : 705:ටිකයි | 1012:පුලුවන් | 627:ගුරුතුමිය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [15/1653] හොඳයි අපි තේරුම් ගත්තා.
#   Correct   : 1587:හොඳ | 185:අපි | 771:තේරුම් ගන්නවා | 330:ඉවරයි
#   Predicted : 1587:හොඳ | 185:අපි | 771:තේරුම් ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [16/1653] හැමෝම ජාතික කොඩිය ඔසවනවා
#   Correct   : 1566:හැමෝම | 689:ජාතික කොඩිය | 420:ඔසවනවා
#   Predicted : 1566:හැමෝම | 687:ජාතික | 525:කුඩා ගල් කඩනවා
#   Overlap   : word=33%  id=33%  exact=✗
#
# [17/1653] පතෝල
#   Correct   : 909:පතෝල
#   Predicted : 941:ප් | 133:අ | 739:ත් | 133:අ | 1292:ල් | 133:අ | 1581:හෙට | 910:පන්ති කාමරය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [18/1653] අම්මා අද සතුටින් ඉන්නවා
#   Correct   : 194:අම්මා | 166:අද | 1464:සතුටු | 316:ඉන්නවා
#   Predicted : 194:අම්මා | 166:අද | 1464:සතුටු | 316:ඉන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [19/1653] සිටගන්නවා
#   Correct   : 1501:සිටගන්නවා
#   Predicted : 1501:සිටගන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [20/1653] මට රුපියල් නවසිය හතළිස්නවයක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 120:900 | 61:49 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 120:900 | 61:49 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [21/1653] අද රැස්වීමට මිනිසුන් දහ හතරදහස්පන්සියක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 5:10000 | 50:4000 | 64:500 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 50:4000 | 64:500 | 478:ක් | 260:ආවා
#   Overlap   : word=89%  id=89%  exact=✗
#
# [22/1653] ගෙවත්තේ ගස් හයසිය හැත්තෑදෙකක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 78:600 | 96:72 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 78:600 | 96:72 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [23/1653] ගෙවත්තේ ගස් තුන්සිය හයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 35:300 | 76:6 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 35:300 | 76:6 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [24/1653] ඔයාගේ ගෙදර හැමෝම සනීපෙන් ඉන්නවද
#   Correct   : 409:ඔබගේ | 636:ගෙදර | 645:ගේ | 1566:හැමෝම | 1521:සුවය | 637:ගෙන් | 316:ඉන්නවා | 779:ද?
#   Predicted : 409:ඔබගේ | 636:ගෙදර | 1564:හැමදාම | 1471:සමගි කරනවා | 316:ඉන්නවා | 779:ද?
#   Overlap   : word=50%  id=50%  exact=✗
#
# [25/1653] විභාගයේ ප්‍රශ්න හාරසිය පනස්හතරක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 49:400 | 70:54 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 49:400 | 70:54 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [26/1653] ඉවසීමෙන් ඉන්න.
#   Correct   : 333:ඉවසීමෙන් | 316:ඉන්නවා
#   Predicted : 332:ඉවසීම | 316:ඉන්නවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [27/1653] මම රුපියල් හැත්තෑනවයක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 103:79 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 103:79 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [28/1653] මේ කිරි රුපියල් 752ක්.
#   Correct   : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 92:700 | 68:52 | 478:ක්
#   Predicted : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 92:700 | 68:52 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [29/1653] මට අඹ 316 ක් ඕන.
#   Correct   : 1119:මට | 198:අඹ | 35:300 | 14:16 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 198:අඹ | 35:300 | 14:16 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [30/1653] අද දවස ගොඩක් රස්නෙයි
#   Correct   : 166:අද | 794:දවස | 650:ගොඩාක් | 1254:රස්නය
#   Predicted : 166:අද | 794:දවස | 650:ගොඩාක් | 1254:රස්නය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [31/1653] මේ ඇපල් රුපියල් හයසිය තිස්හතරක්.
#   Correct   : 1205:මෙ | 277:ඇපල් | 1272:රුපියල් | 78:600 | 41:34 | 478:ක්
#   Predicted : 1205:මෙ | 277:ඇපල් | 1272:රුපියල් | 78:600 | 41:34 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [32/1653] අපට පුලුවන්.
#   Correct   : 188:අපිට | 1012:පුලුවන්
#   Predicted : 188:අපිට | 1012:පුලුවන්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [33/1653] ළමයාට රොටී නවසිය එකක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 1281:රොටී | 120:900 | 1:1 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 1281:රොටී | 120:900 | 1:1 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [34/1653] අද රැස්වීමට මිනිසුන් විසිහත්දහස් එකසිය අසූදෙකක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 22:20000 | 93:7000 | 3:100 | 110:82 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 22:20000 | 93:7000 | 3:100 | 117:89 | 478:ක් | 260:ආවා
#   Overlap   : word=90%  id=90%  exact=✗
#
# [35/1653] ගෙවත්තේ ගස් හයදහස්දෙසියක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 79:6000 | 20:200 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 79:6000 | 20:200 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [36/1653] ඔව් මම ගත්තා.
#   Correct   : 415:ඔව් | 1128:මම | 583:ගන්න | 330:ඉවරයි
#   Predicted : 415:ඔව් | 1128:මම | 583:ගන්න | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [37/1653] රස්නෙට කන්න කෑම
#   Correct   : 1254:රස්නය | 442:කනවා | 262:ආහාර
#   Predicted : 1254:රස්නය | 442:කනවා | 262:ආහාර
#   Overlap   : word=100%  id=100%  exact=✓
#
# [38/1653] අද රැස්වීමට මිනිසුන් 178 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 3:100 | 102:78 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 3:100 | 102:78 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [39/1653] මේසය උඩින් තියන්න එපා.
#   Correct   : 1210:මේසය | 350:උඩ | 637:ගෙන් | 756:තියන්න | 390:එපා
#   Predicted : 1210:මේසය | 350:උඩ | 756:තියන්න | 390:එපා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [40/1653] ඔව් අපි ගස් ගැන ඉගෙන ගන්නවා.
#   Correct   : 415:ඔව් | 185:අපි | 596:ගස | 301:ඉගෙන ගන්නවා
#   Predicted : 415:ඔව් | 185:අපි | 596:ගස | 302:ඉගෙනගන්නවා
#   Overlap   : word=75%  id=75%  exact=✗
#
# [41/1653] මම රුපියල් දහතුන්දහස් පන්සියක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 5:10000 | 36:3000 | 64:500 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 5:10000 | 36:3000 | 64:500 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [42/1653] අපි තර්ක කරා.
#   Correct   : 185:අපි | 732:තර්ක කරනවා | 330:ඉවරයි
#   Predicted : 185:අපි | 732:තර්ක කරනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [43/1653] හැමෝම ගස් වැල් ගැන තොරතුරු ලියනවා
#   Correct   : 1566:හැමෝම | 596:ගස | 1393:වැල් | 1422:විස්තරය | 1300:ලියනවා
#   Predicted : 1566:හැමෝම | 596:ගස | 1393:වැල් | 1300:ලියනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [44/1653] මම හත්සිය හැත්තෑහය පිටුව කියවනවා.
#   Correct   : 1128:මම | 92:700 | 100:76 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 92:700 | 100:76 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [45/1653] විභාගයේ ප්‍රශ්න 113 ක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 11:13 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 11:13 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [46/1653] ළමයාට අඹ 996 ක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 198:අඹ | 120:900 | 128:96 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 198:අඹ | 120:900 | 128:96 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [47/1653] හමුවෙනවා
#   Correct   : 1188:මුණගැහෙනවා
#   Predicted : 1545:හමුදාව
#   Overlap   : word=0%  id=0%  exact=✗
#
# [48/1653] මේ කිරි රුපියල් තුන්සිය විසිහතක්.
#   Correct   : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 35:300 | 30:27 | 478:ක්
#   Predicted : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 35:300 | 30:27 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [49/1653] මේ කිරි රුපියල් 516ක්.
#   Correct   : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 64:500 | 14:16 | 478:ක්
#   Predicted : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 64:500 | 14:16 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [50/1653] මම නවසිය හැටනවය පිටුව කියවනවා.
#   Correct   : 1128:මම | 120:900 | 89:69 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 120:900 | 89:69 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [51/1653] දැන් කොළ එකතු කරන වෙලාව.
#   Correct   : 801:දැන් | 569:කොළ | 387:එකතු කරනවා | 1437:වෙලාව
#   Predicted : 801:දැන් | 569:කොළ | 387:එකතු කරනවා
#   Overlap   : word=75%  id=75%  exact=✗
#
# [52/1653] අපි ගීත ගායනා කරන්න කැමතියි
#   Correct   : 185:අපි | 625:ගීතයක් | 605:ගායනා කරනවා | 501:කැමති
#   Predicted : 185:අපි | 625:ගීතයක් | 605:ගායනා කරනවා | 501:කැමති
#   Overlap   : word=100%  id=100%  exact=✓
#
# [53/1653] සන්ධ්‍යා දැන් පාඩම් කරමු
#   Correct   : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 801:දැන් | 956:පාඩම් කරනවා
#   Predicted : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 801:දැන් | 956:පාඩම් කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [54/1653] අපි ඇත්ත කිව්වා.
#   Correct   : 185:අපි | 268:ඇත්ත | 514:කියනවා | 330:ඉවරයි
#   Predicted : 185:අපි | 268:ඇත්ත | 514:කියනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [55/1653] මම හයසිය දහහතර පිටුව කියවනවා.
#   Correct   : 1128:මම | 78:600 | 12:14 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 78:600 | 12:14 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [56/1653] ගෙවත්තේ ගස් තුන්දහස්හයසියක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 36:3000 | 78:600 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 36:3000 | 78:600 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [57/1653] කඩදාසිය
#   Correct   : 433:කඩදාසිය
#   Predicted : 433:කඩදාසිය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [58/1653] අපි සමාව ගන්නවා.
#   Correct   : 185:අපි | 1478:සමාවෙන්න | 584:ගන්නවා
#   Predicted : 185:අපි | 1478:සමාවෙන්න | 584:ගන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [59/1653] දුක් වෙන්න
#   Correct   : 818:දුක්වීම
#   Predicted : 817:දුක
#   Overlap   : word=0%  id=0%  exact=✗
#
# [60/1653] මම රුපියල් නවසිය විසිහතක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 120:900 | 30:27 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 120:900 | 30:27 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [61/1653] මට ඇපල් තුන්සිය හතරක් ඕන.
#   Correct   : 1119:මට | 277:ඇපල් | 35:300 | 47:4 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 277:ඇපල් | 35:300 | 47:4 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [62/1653] දැන් අපි පන්ති කාමරයට යමු.
#   Correct   : 801:දැන් | 185:අපි | 910:පන්ති කාමරය | 699:ට | 1231:යමු
#   Predicted : 801:දැන් | 185:අපි | 910:පන්ති කාමරය | 699:ට | 1231:යමු
#   Overlap   : word=100%  id=100%  exact=✓
#
# [63/1653] මම රුපියල් අටසිය හතළිස්හතක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 106:800 | 59:47 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 106:800 | 59:47 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [64/1653] මට පාට පැන්සල් නැ.
#   Correct   : 1119:මට | 953:පාට පැන්සල | 870:නැ
#   Predicted : 1119:මට | 953:පාට පැන්සල | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [65/1653] මම හැමදාම පොත් මේසය හදනවා.
#   Correct   : 1128:මම | 1564:හැමදාම | 1024:පොත | 1210:මේසය | 1538:හදනවා
#   Predicted : 1128:මම | 1564:හැමදාම | 1024:පොත | 1210:මේසය | 1538:හදනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [66/1653] ඇහැළ මල
#   Correct   : 290:ඇහැළ මල
#   Predicted : 287:ඇස
#   Overlap   : word=0%  id=0%  exact=✗
#
# [67/1653] මම කෙසෙල් 41 ක් ගත්තා.
#   Correct   : 1128:මම | 543:කෙසෙල් | 53:41 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 543:කෙසෙල් | 53:41 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [68/1653] ළමයාට බත් පන්සිය හැටපහක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 1054:බත් | 64:500 | 85:65 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 1054:බත් | 64:500 | 85:65 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [69/1653] උත්තර හිතන්න.
#   Correct   : 1001:පිළිතුර | 235:අහගන්නවා
#   Predicted : 356:උත්තරය | 235:අහගන්නවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [70/1653] මට රුපියල් දෙසිය දහසයක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 20:200 | 14:16 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 20:200 | 14:16 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [71/1653] පරිස්සමින් අදින්න.
#   Correct   : 924:පරිස්සමින් | 669:චිත්‍ර අදිනවා
#   Predicted : 924:පරිස්සමින් | 669:චිත්‍ර අදිනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [72/1653] මම කිරි දෙසිය දහසයක් ගත්තා.
#   Correct   : 1128:මම | 517:කිරි | 20:200 | 14:16 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 517:කිරි | 20:200 | 14:16 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [73/1653] දිගටම කරන්න.
#   Correct   : 806:දිග | 699:ට | 458:කරන්න
#   Predicted : 806:දිග | 699:ට | 458:කරන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [74/1653] නරියා
#   Correct   : 859:නරියා
#   Predicted : 910:පන්ති කාමරය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [75/1653] ඉදගන්න
#   Correct   : 309:ඉදගන්න
#   Predicted : 310:ඉදගන්නවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [76/1653] අනුර හෙට එන්නෙ නැ
#   Correct   : 133:අ | 862:න් | 342:උ | 1257:ර් | 133:අ | 1581:හෙට | 389:එනවා | 870:නැ
#   Predicted : 133:අ | 862:න් | 342:උ | 1257:ර් | 133:අ | 1581:හෙට | 389:එනවා | 870:නැ
#   Overlap   : word=88%  id=88%  exact=✓
#
# [77/1653] උත්සවයට සැරසිලි කරන්න
#   Correct   : 357:උත්සවය | 699:ට | 1291:ලස්සන කරනවා
#   Predicted : 358:උත්සාහය | 699:ට | 1531:සෙල්ලම් කරනවා
#   Overlap   : word=33%  id=33%  exact=✗
#
# [78/1653] ඔබ පාසල් වත්ත පිරිසිදු කරනවා
#   Correct   : 408:ඔබ | 334:ඉස්කෝලෙ | 1335:වත්ත | 996:පිරිසුදු කරනවා
#   Predicted : 408:ඔබ | 334:ඉස්කෝලෙ | 1335:වත්ත | 996:පිරිසුදු කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [79/1653] අද රැස්වීමට මිනිසුන් දහසයක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 14:16 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 14:16 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [80/1653] මට රුපියල් 244 ක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 20:200 | 56:44 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 20:200 | 56:44 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [81/1653] අද රැස්වීමට මිනිසුන් 85 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 113:85 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 113:85 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [82/1653] සෞන්දර්‍ය
#   Correct   : 1536:සෞන්දර්‍ය
#   Predicted : 1524:සූර්‍යා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [83/1653] අරවින්ද දැන් පාසල් යනවා
#   Correct   : 133:අ | 1257:ර් | 133:අ | 1362:ව් | 296:ඉ | 862:න් | 796:ද් | 133:අ | 801:දැන් | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා
#   Predicted : 133:අ | 1257:ර් | 133:අ | 1362:ව් | 296:ඉ | 862:න් | 796:ද් | 133:අ | 801:දැන් | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා
#   Overlap   : word=83%  id=83%  exact=✓
#
# [84/1653] අපි ගෙනාවේ නැහැ.
#   Correct   : 185:අපි | 638:ගෙනාවා | 870:නැ
#   Predicted : 185:අපි | 638:ගෙනාවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [85/1653] අද රැස්වීමට මිනිසුන් අටසිය හැටහතක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 106:800 | 87:67 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 106:800 | 87:67 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [86/1653] මට දොඩම් හත්සිය හැත්තෑපහක් ඕන.
#   Correct   : 1119:මට | 846:දොඩම් | 92:700 | 99:75 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 846:දොඩම් | 92:700 | 99:75 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [87/1653] මම 842 වන පිටුව කියවනවා.
#   Correct   : 1128:මම | 106:800 | 54:42 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 106:800 | 54:42 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [88/1653] මම රුපියල් පනහක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 63:50 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 63:50 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [89/1653] ඔයාගේ පන්තිය මොකක්ද?
#   Correct   : 409:ඔබගේ | 910:පන්ති කාමරය | 1212:මොකක්ද
#   Predicted : 409:ඔබගේ | 910:පන්ති කාමරය | 1212:මොකක්ද
#   Overlap   : word=100%  id=100%  exact=✓
#
# [90/1653] ළමයාට රොටී හැත්තෑහයදහසක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 1281:රොටී | 94:70000 | 79:6000 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 1281:රොටී | 94:70000 | 79:6000 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [91/1653] කල්පනා හෙට පාසල් යමු
#   Correct   : 478:ක් | 133:අ | 1292:ල් | 941:ප් | 133:අ | 862:න් | 241:ආ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Predicted : 478:ක් | 133:අ | 1292:ල් | 941:ප් | 133:අ | 862:න් | 241:ආ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1231:යමු
#   Overlap   : word=91%  id=91%  exact=✓
#
# [92/1653] මම අට පිටුව කියවනවා.
#   Correct   : 1128:මම | 104:8 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 104:8 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [93/1653] ප්‍රසාන් අද පන්තිය අතුගානවා
#   Correct   : 941:ප් | 1239:රකාරාංශය | 1485:ස් | 241:ආ | 862:න් | 166:අද | 910:පන්ති කාමරය | 164:අතුගානවා
#   Predicted : 941:ප් | 1239:රකාරාංශය | 1485:ස් | 241:ආ | 862:න් | 166:අද | 910:පන්ති කාමරය | 164:අතුගානවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [94/1653] අද රැස්වීමට මිනිසුන් 671 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 78:600 | 95:71 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 78:600 | 95:71 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [95/1653] අපි එකතු වෙලා මේ වැඩේ කරමු
#   Correct   : 185:අපි | 388:එකතුව | 330:ඉවරයි | 1205:මෙ | 1383:වැඩ කරනවා | 1185:මු
#   Predicted : 185:අපි | 387:එකතු කරනවා | 1205:මෙ | 1382:වැඩ | 458:කරන්න
#   Overlap   : word=33%  id=33%  exact=✗
#
# [96/1653] ඉක්මනින් සනීප වෙයි.
#   Correct   : 299:ඉක්මනින් | 1521:සුවය
#   Predicted : 299:ඉක්මනින් | 1521:සුවය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [97/1653] පුටු මේස හදන්න පේළියට
#   Correct   : 1008:පුටුව | 1210:මේසය | 1538:හදනවා | 1042:පෝලිම | 699:ට
#   Predicted : 1008:පුටුව | 1210:මේසය | 1538:හදනවා | 1042:පෝලිම | 699:ට
#   Overlap   : word=100%  id=100%  exact=✓
#
# [98/1653] මම බත් 219 ක් ගත්තා.
#   Correct   : 1128:මම | 1054:බත් | 20:200 | 17:19 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1054:බත් | 20:200 | 17:19 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [99/1653] අපට උදව් කරන්න කවුරු හරි එන්න.
#   Correct   : 188:අපිට | 363:උදව් කරනවා | 472:කවුද | 389:එනවා
#   Predicted : 188:අපිට | 363:උදව් කරනවා | 472:කවුද | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [100/1653] එරන්දි හෙට පාසල් යනවා
#   Correct   : 386:එ | 1257:ර් | 133:අ | 862:න් | 796:ද් | 296:ඉ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා
#   Predicted : 796:ද් | 133:අ | 862:න් | 796:ද් | 296:ඉ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 1229:යනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [101/1653] අපි හවස 15ට යනවා.
#   Correct   : 185:අපි | 1550:හවස | 13:15 | 699:ට | 1229:යනවා
#   Predicted : 185:අපි | 1550:හවස | 13:15 | 699:ට | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [102/1653] එයාලා අපිට ගොඩක් ආදරෙයි
#   Correct   : 416:ඔව්න් | 188:අපිට | 650:ගොඩාක් | 245:ආදරය
#   Predicted : 416:ඔව්න් | 188:අපිට | 650:ගොඩාක් | 245:ආදරය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [103/1653] ආදරයෙන්
#   Correct   : 247:ආදරයෙන්
#   Predicted : 246:ආදරය කරනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [104/1653] මම රතුලූණු598 ක් ගත්තා.
#   Correct   : 1128:මම | 1244:රතුලූණු | 64:500 | 130:98 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1244:රතුලූණු | 64:500 | 130:98 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [105/1653] ඉමාෂි මට පෑනක් දුන්නා
#   Correct   : 296:ඉ | 1145:ම් | 241:ආ | 1455:ෂ් | 296:ඉ | 1119:මට | 978:පෑන | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 296:ඉ | 1145:ම් | 241:ආ | 1455:ෂ් | 296:ඉ | 1119:මට | 978:පෑන | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=90%  id=90%  exact=✓
#
# [106/1653] ළමයාට ගෙඩි පන්සිය අනූඑකක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 635:ගෙඩියක් | 64:500 | 123:91 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 635:ගෙඩියක් | 64:500 | 123:91 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [107/1653] කුණු කූඩය වහලා තියන්න.
#   Correct   : 526:කුණුකූඩය | 1357:වසනවා | 330:ඉවරයි | 756:තියන්න
#   Predicted : 526:කුණුකූඩය | 1358:වහන්න | 330:ඉවරයි | 756:තියන්න
#   Overlap   : word=75%  id=75%  exact=✗
#
# [108/1653] අක්කා ව්‍යාකරණ ඉගෙන ගන්නවා
#   Correct   : 138:අක්කා | 1367:ව්‍යාකරණ | 302:ඉගෙනගන්නවා
#   Predicted : 138:අක්කා | 1367:ව්‍යාකරණ | 302:ඉගෙනගන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [109/1653] මම තුන්සිය හතළිස්හය පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 58:46 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 58:46 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [110/1653] අද රැස්වීමට මිනිසුන් අටසිය අනූහයක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 106:800 | 128:96 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 106:800 | 128:96 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [111/1653] මම දන්නෙ නැහැ.
#   Correct   : 1128:මම | 787:දන්නවා | 870:නැ
#   Predicted : 1128:මම | 788:දන්නෙ නැ | 870:නැ
#   Overlap   : word=67%  id=67%  exact=✗
#
# [112/1653] පන්තියේ වැඩ කරන කොට කතා කරන්න තහනම්
#   Correct   : 910:පන්ති කාමරය | 645:ගේ | 1383:වැඩ කරනවා | 439:කතා කරනවා | 738:තහනම්
#   Predicted : 910:පන්ති කාමරය | 645:ගේ | 1382:වැඩ | 458:කරන්න | 738:තහනම්
#   Overlap   : word=60%  id=60%  exact=✗
#
# [113/1653] සන්ධ්‍යා දැන් පන්තිය පිරිසිදු කරමු
#   Correct   : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 801:දැන් | 910:පන්ති කාමරය | 996:පිරිසුදු කරනවා
#   Predicted : 1485:ස් | 133:අ | 862:න් | 850:ධ් | 1223:යංශය | 241:ආ | 801:දැන් | 910:පන්ති කාමරය | 996:පිරිසුදු කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [114/1653] විභාගයේ ප්‍රශ්න නවයක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 118:9 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 118:9 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [115/1653] මට දොඩම් 583 ක් ඕන.
#   Correct   : 1119:මට | 846:දොඩම් | 64:500 | 111:83 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 846:දොඩම් | 64:500 | 111:83 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [116/1653] ළමයි හැමෝම දැන් පන්තියට එනවා
#   Correct   : 1596:ළමයි | 1566:හැමෝම | 801:දැන් | 910:පන්ති කාමරය | 699:ට | 389:එනවා
#   Predicted : 1596:ළමයි | 1566:හැමෝම | 801:දැන් | 910:පන්ති කාමරය | 699:ට | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [117/1653] අපි හවස එකට යනවා.
#   Correct   : 185:අපි | 1550:හවස | 1:1 | 699:ට | 1229:යනවා
#   Predicted : 185:අපි | 1550:හවස | 699:ට | 1229:යනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [118/1653] බත් කෑවම නිදිමත එනවා.
#   Correct   : 1054:බත් | 442:කනවා | 330:ඉවරයි | 886:නිදිමත | 389:එනවා
#   Predicted : 1054:බත් | 442:කනවා | 330:ඉවරයි | 389:එනවා
#   Overlap   : word=80%  id=80%  exact=✗
#
# [119/1653] මම දුවනවා.
#   Correct   : 1128:මම | 829:දුවනවා
#   Predicted : 1128:මම | 829:දුවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [120/1653] අංජලී දැන් බත් කනවා
#   Correct   : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 801:දැන් | 1054:බත් | 442:කනවා
#   Predicted : 133:අ | 132:ං | 685:ජ් | 133:අ | 1292:ල් | 335:ඊ | 801:දැන් | 1054:බත් | 442:කනවා
#   Overlap   : word=89%  id=89%  exact=✓
#
# [121/1653] ළමයි වැඩ වලට එකතු වෙනවා
#   Correct   : 1596:ළමයි | 1382:වැඩ | 699:ට | 387:එකතු කරනවා
#   Predicted : 1596:ළමයි | 1382:වැඩ | 699:ට | 388:එකතුව
#   Overlap   : word=75%  id=75%  exact=✗
#
# [122/1653] මට රුපියල් තුන්සිය හැත්තෑඅටක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 35:300 | 102:78 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 35:300 | 102:78 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [123/1653] සම
#   Correct   : 1543:හම
#   Predicted : 1478:සමාවෙන්න
#   Overlap   : word=0%  id=0%  exact=✗
#
# [124/1653] මට රුපියල් අනූදහස්හත්දහසක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 122:90000 | 93:7000 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 122:90000 | 93:7000 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [125/1653] මම ලස්සන වුනා.
#   Correct   : 1128:මම | 1290:ලස්සන | 330:ඉවරයි
#   Predicted : 1128:මම | 1290:ලස්සන | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [126/1653] කට පාඩම් කරන්න.
#   Correct   : 429:කට | 956:පාඩම් කරනවා
#   Predicted : 1119:මට | 956:පාඩම් කරනවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [127/1653] අද රැස්වීමට මිනිසුන් 37000 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 37:30000 | 93:7000 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 37:30000 | 93:7000 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [128/1653] මම එන්නද?
#   Correct   : 1128:මම | 389:එනවා | 779:ද?
#   Predicted : 1128:මම | 389:එනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [129/1653] මට බිත්තර 934 ක් ඕන.
#   Correct   : 1119:මට | 1087:බිත්තර | 120:900 | 41:34 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1087:බිත්තර | 120:900 | 41:34 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [130/1653] මම 303 වන පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 33:3 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 33:3 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [131/1653] පාර පනින්න
#   Correct   : 954:පාර | 914:පනිනවා
#   Predicted : 964:පාර | 914:පනිනවා
#   Overlap   : word=100%  id=50%  exact=✓
#
# [132/1653] මට බිත්තර 491 ක් ඕන.
#   Correct   : 1119:මට | 1087:බිත්තර | 49:400 | 123:91 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1087:බිත්තර | 49:400 | 123:91 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [133/1653] දැන් වෙලාව එකයි විසිපහයි.
#   Correct   : 801:දැන් | 1437:වෙලාව | 1:1 | 28:25
#   Predicted : 801:දැන් | 1437:වෙලාව | 1:1 | 28:25
#   Overlap   : word=100%  id=100%  exact=✓
#
# [134/1653] මම හත්සිය තිස්තුන පිටුව කියවනවා.
#   Correct   : 1128:මම | 92:700 | 40:33 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 92:700 | 40:33 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [135/1653] අමිත් අද නිදාගන්නවා
#   Correct   : 133:අ | 1145:ම් | 296:ඉ | 739:ත් | 166:අද | 884:නිදාගන්නවා
#   Predicted : 133:අ | 1145:ම් | 296:ඉ | 739:ත් | 166:අද | 884:නිදාගන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [136/1653] මට බිත්තර නවසිය තුනක් ඕන.
#   Correct   : 1119:මට | 1087:බිත්තර | 120:900 | 33:3 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1087:බිත්තර | 120:900 | 33:3 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [137/1653] ඔව් ගුරුතුමී අපි බසයෙන් ආවා.
#   Correct   : 415:ඔව් | 627:ගුරුතුමිය | 185:අපි | 1070:බසය | 260:ආවා
#   Predicted : 415:ඔව් | 627:ගුරුතුමිය | 185:අපි | 1070:බසය | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [138/1653] සතුටින් සෙල්ලම් කරන්න.
#   Correct   : 1463:සතුට | 1531:සෙල්ලම් කරනවා
#   Predicted : 1463:සතුට | 1531:සෙල්ලම් කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [139/1653] ළමයාට කරවිල පන්සිය දොළොසක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 459:කරවිල | 64:500 | 10:12 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 459:කරවිල | 64:500 | 10:12 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [140/1653] ප්‍රදීප් හෙට මුණගැහෙමු
#   Correct   : 941:ප් | 1239:රකාරාංශය | 796:ද් | 335:ඊ | 941:ප් | 1581:හෙට | 1189:මුණගැහෙමු
#   Predicted : 941:ප් | 1239:රකාරාංශය | 796:ද් | 335:ඊ | 941:ප් | 1581:හෙට | 1189:මුණගැහෙමු
#   Overlap   : word=86%  id=86%  exact=✓
#
# [141/1653] අම්මා මට ආදරෙයි.
#   Correct   : 194:අම්මා | 1119:මට | 246:ආදරය කරනවා
#   Predicted : 194:අම්මා | 1119:මට | 245:ආදරය
#   Overlap   : word=67%  id=67%  exact=✗
#
# [142/1653] මට රුපියල් එක්දහස් හත්සියක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 4:1000 | 92:700 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 4:1000 | 92:700 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [143/1653] උස බලන්න
#   Correct   : 380:උස | 1065:බලන්න
#   Predicted : 380:උස | 1065:බලන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [144/1653] දෙන්න
#   Correct   : 835:දෙන්න
#   Predicted : 838:දෙමළ
#   Overlap   : word=0%  id=0%  exact=✗
#
# [145/1653] රණ්ඩු සරුවල් වෙන්න එපා
#   Correct   : 1242:රණ්ඩු කරනවා | 390:එපා
#   Predicted : 1242:රණ්ඩු කරනවා | 390:එපා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [146/1653] මම රුපියල් 511 ක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 64:500 | 9:11 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 64:500 | 9:11 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [147/1653] මම කිරි 216 ක් ගත්තා.
#   Correct   : 1128:මම | 517:කිරි | 20:200 | 14:16 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 517:කිරි | 20:200 | 14:16 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [148/1653] අද රැස්වීමට මිනිසුන් දෙසිය හැටඑකක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 81:61 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 81:61 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [149/1653] මම රුපියල් 23 ක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 26:23 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 26:23 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [150/1653] මම අඹ හත්සිය දහහතරක් ගත්තා.
#   Correct   : 1128:මම | 198:අඹ | 92:700 | 12:14 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 198:අඹ | 92:700 | 12:14 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [151/1653] ගෙවත්තේ ගස් නවසිය හැත්තෑපහක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 120:900 | 99:75 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 120:900 | 99:75 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [152/1653] අපි ගස් වලට ආදරය කරන්න ඕන.
#   Correct   : 185:අපි | 596:ගස | 699:ට | 246:ආදරය කරනවා | 427:ඕන
#   Predicted : 185:අපි | 596:ගස | 699:ට | 246:ආදරය කරනවා | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [153/1653] තුෂාර හෙට වැඩ කරන්නෙ නැ
#   Correct   : 739:ත් | 342:උ | 1455:ෂ් | 241:ආ | 1257:ර් | 133:අ | 1581:හෙට | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 739:ත් | 342:උ | 1455:ෂ් | 241:ආ | 1257:ර් | 133:අ | 1581:හෙට | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [154/1653] ඈතින් ඉන්න.
#   Correct   : 295:ඈතින් | 316:ඉන්නවා
#   Predicted : 380:උස | 316:ඉන්නවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [155/1653] මම සමාව දෙන්නම්.
#   Correct   : 1128:මම | 1478:සමාවෙන්න | 834:දෙනවා
#   Predicted : 1128:මම | 1478:සමාවෙන්න | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [156/1653] බන්දුල මට පොතක් දුන්නා
#   Correct   : 1073:බ් | 133:අ | 862:න් | 796:ද් | 342:උ | 1292:ල් | 133:අ | 1119:මට | 1024:පොත | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1073:බ් | 133:අ | 862:න් | 796:ද් | 342:උ | 1292:ල් | 133:අ | 1119:මට | 1024:පොත | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=92%  id=92%  exact=✓
#
# [157/1653] අද රැස්වීමට මිනිසුන් හාරදහස්හත්සියක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 50:4000 | 92:700 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 50:4000 | 92:700 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [158/1653] අද රැස්වීමට මිනිසුන් 214 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 12:14 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 12:14 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [159/1653] ගොටුකොල
#   Correct   : 648:ගොටුකොල
#   Predicted : 654:ගොවිතැන
#   Overlap   : word=0%  id=0%  exact=✗
#
# [160/1653] සතිය
#   Correct   : 1462:සතිය
#   Predicted : 234:අස්ථිය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [161/1653] ජීවනී මට පෑනක් දුන්නා
#   Correct   : 685:ජ් | 335:ඊ | 1362:ව් | 133:අ | 862:න් | 335:ඊ | 1119:මට | 978:පෑන | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 685:ජ් | 335:ඊ | 1362:ව් | 133:අ | 862:න් | 335:ඊ | 1119:මට | 978:පෑන | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=91%  id=91%  exact=✓
#
# [162/1653] අද රැස්වීමට මිනිසුන් හතලිස්දහසක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 51:40000 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 51:40000 | 93:7000 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✗
#
# [163/1653] ශක්තිමත්
#   Correct   : 1483:සවිමත්
#   Predicted : 853:ධෛර්යය
#   Overlap   : word=0%  id=0%  exact=✗
#
# [164/1653] විභාගයේ ප්‍රශ්න එකසිය තිහක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 34:30 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 3:100 | 34:30 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [165/1653] ළමයි සිල් ගන්නවා
#   Correct   : 1596:ළමයි | 1505:සිල් | 584:ගන්නවා
#   Predicted : 1596:ළමයි | 1505:සිල් | 584:ගන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [166/1653] හොට ගේන්න.
#   Correct   : 1581:හෙට | 647:ගේනවා
#   Predicted : 1587:හොඳ | 647:ගේනවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [167/1653] ගෙවත්තේ ගස් එකසිය අනූහතක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 3:100 | 129:97 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 3:100 | 129:97 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [168/1653] දිනන්න.
#   Correct   : 682:ජයග්‍රහණය
#   Predicted : 813:දිව
#   Overlap   : word=0%  id=0%  exact=✗
#
# [169/1653] මේ කිරි රුපියල් තුන්සිය අසූහතරක්.
#   Correct   : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 35:300 | 112:84 | 478:ක්
#   Predicted : 1205:මෙ | 517:කිරි | 1272:රුපියල් | 35:300 | 112:84 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [170/1653] තුවාල සෝදනවා
#   Correct   : 762:තුවාල සෝදනවා
#   Predicted : 739:ත් | 342:උ | 1362:ව් | 241:ආ | 1292:ල් | 133:අ | 1534:සෝදනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [171/1653] අද රැස්වීමට මිනිසුන් හයදහස්හත්සියක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 79:6000 | 92:700 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 79:6000 | 92:700 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [172/1653] අද අහස හරිම ලස්සනයි.
#   Correct   : 166:අද | 240:අහස | 650:ගොඩාක් | 1290:ලස්සන
#   Predicted : 166:අද | 1290:ලස්සන | 650:ගොඩාක් | 1290:ලස්සන
#   Overlap   : word=75%  id=75%  exact=✗
#
# [173/1653] බනිනවා
#   Correct   : 1058:බනිනවා
#   Predicted : 1059:බනිස්
#   Overlap   : word=0%  id=0%  exact=✗
#
# [174/1653] තැපැල් කාර්‍යාලය
#   Correct   : 748:තැපැල් කාර්‍යාලය
#   Predicted : 750:තැපැල්කරු
#   Overlap   : word=0%  id=0%  exact=✗
#
# [175/1653] මට රුපියල් 45 ක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 57:45 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 57:45 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [176/1653] ලොකුම
#   Correct   : 1322:ලොකුම
#   Predicted : 1322:ලොකුම
#   Overlap   : word=100%  id=100%  exact=✓
#
# [177/1653] චම්පා අද වැඩ කරන්නෙ නැ
#   Correct   : 665:ච් | 133:අ | 1145:ම් | 941:ප් | 241:ආ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 665:ච් | 133:අ | 1145:ම් | 941:ප් | 241:ආ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [178/1653] මම අලුත් කරන්නම්.
#   Correct   : 1128:මම | 217:අලුත් | 458:කරන්න
#   Predicted : 1128:මම | 217:අලුත් | 458:කරන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [179/1653] ගෙවත්තේ ගස් දහතුනක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 11:13 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 11:13 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [180/1653] ඉඳුවර අද වැඩ කරන්නෙ නැ
#   Correct   : 296:ඉ | 905:ඳ් | 342:උ | 1362:ව් | 133:අ | 1257:ර් | 133:අ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 296:ඉ | 905:ඳ් | 342:උ | 1362:ව් | 133:අ | 1257:ර් | 133:අ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=90%  id=90%  exact=✓
#
# [181/1653] මම බිත්තර හයදහසක් ගත්තා.
#   Correct   : 1128:මම | 1087:බිත්තර | 79:6000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1087:බිත්තර | 79:6000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [182/1653] සම්බන්ද කරනවා
#   Correct   : 1475:සම්බන්ද කරනවා
#   Predicted : 1460:සක්මන් කරනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [183/1653] මට අඹ නවදහස්හයසියක් ඕන.
#   Correct   : 1119:මට | 198:අඹ | 121:9000 | 78:600 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 198:අඹ | 121:9000 | 78:600 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [184/1653] කොණ්ඩය
#   Correct   : 555:කොණ්ඩය
#   Predicted : 1576:හිසකෙස්
#   Overlap   : word=0%  id=0%  exact=✗
#
# [185/1653] ගෙවත්තේ ගස් එකසිය අනූඅටක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 3:100 | 130:98 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 3:100 | 130:98 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [186/1653] හැමෝම මල් පැළ සිටවනවා
#   Correct   : 1566:හැමෝම | 1132:මල් | 596:ගස | 1502:සිටවනවා
#   Predicted : 1566:හැමෝම | 1132:මල් | 596:ගස | 1502:සිටවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [187/1653] අද රැස්වීමට මිනිසුන් 341 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 35:300 | 53:41 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 35:300 | 53:41 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [188/1653] මේ දොඩම් රුපියල් 772ක්.
#   Correct   : 1205:මෙ | 846:දොඩම් | 1272:රුපියල් | 92:700 | 96:72 | 478:ක්
#   Predicted : 1205:මෙ | 846:දොඩම් | 1272:රුපියල් | 92:700 | 96:72 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [189/1653] දුමින්ද මට සල්ලි දුන්නා
#   Correct   : 796:ද් | 342:උ | 1145:ම් | 296:ඉ | 862:න් | 796:ද් | 133:අ | 1119:මට | 1194:මුදල් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 796:ද් | 342:උ | 1145:ම් | 296:ඉ | 862:න් | 796:ද් | 133:අ | 1119:මට | 1194:මුදල් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=91%  id=91%  exact=✓
#
# [190/1653] අද රැස්වීමට මිනිසුන් 255 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 71:55 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 71:55 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [191/1653] ඉරිදා
#   Correct   : 324:ඉරිදා
#   Predicted : 1524:සූර්‍යා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [192/1653] මට රුපියල් පන්දහස් දෙසියක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 65:5000 | 20:200 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 65:5000 | 20:200 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [193/1653] මට රුපියල් නවදහස්තුන්සියක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 121:9000 | 35:300 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 121:9000 | 35:300 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [194/1653] වලං බිදිනවා
#   Correct   : 1352:වලං බිදිනවා
#   Predicted : 1360:වළන්
#   Overlap   : word=0%  id=0%  exact=✗
#
# [195/1653] මේ රොටී රුපියල් 8100ක්.
#   Correct   : 1205:මෙ | 1281:රොටී | 1272:රුපියල් | 107:8000 | 3:100 | 478:ක්
#   Predicted : 1205:මෙ | 1281:රොටී | 1272:රුපියල් | 107:8000 | 3:100 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [196/1653] අපි හවස හතරට යනවා.
#   Correct   : 185:අපි | 1550:හවස | 47:4 | 699:ට | 1229:යනවා
#   Predicted : 185:අපි | 1550:හවස | 47:4 | 699:ට | 1229:යනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [197/1653] මම ගෝවා පනස් හයදහස් හත්සිය අසූනවයක් ගත්තා.
#   Correct   : 1128:මම | 658:ගෝවා | 66:50000 | 79:6000 | 92:700 | 117:89 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 658:ගෝවා | 79:6000 | 92:700 | 117:89 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=89%  id=89%  exact=✗
#
# [198/1653] අපි ලියලා ඉවරයි.
#   Correct   : 185:අපි | 1300:ලියනවා | 330:ඉවරයි
#   Predicted : 185:අපි | 1300:ලියනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [199/1653] අපි ස්වභාවධර්මය රැකගන්න ඕන.
#   Correct   : 185:අපි | 922:පරිසරය | 257:ආරක්ෂාව | 427:ඕන
#   Predicted : 185:අපි | 922:පරිසරය | 699:ට | 1230:යන්න | 427:ඕන
#   Overlap   : word=75%  id=75%  exact=✗
#
# [200/1653] ඔව් දැන් සනීපයි.
#   Correct   : 415:ඔව් | 801:දැන් | 232:අසනීපය
#   Predicted : 415:ඔව් | 801:දැන් | 1521:සුවය
#   Overlap   : word=67%  id=67%  exact=✗
#
# [201/1653] ගෙවත්තේ ගස් අටසිය අසූනවයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 106:800 | 117:89 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 106:800 | 117:89 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [202/1653] බය වෙන්න එපා.
#   Correct   : 1060:බය | 390:එපා
#   Predicted : 1060:බය | 390:එපා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [203/1653] අපි බොනවා.
#   Correct   : 185:අපි | 1103:බොනවා
#   Predicted : 185:අපි | 1103:බොනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [204/1653] නැ ගුරුතුමී අපි ඇහුවේ නැ.
#   Correct   : 870:නැ | 627:ගුරුතුමිය | 185:අපි | 237:අහනවා | 330:ඉවරයි | 870:නැ
#   Predicted : 870:නැ | 627:ගුරුතුමිය | 185:අපි | 237:අහනවා | 330:ඉවරයි | 870:නැ
#   Overlap   : word=83%  id=83%  exact=✓
#
# [205/1653] මේ බිත්තර රුපියල් දෙසිය විස්සක්.
#   Correct   : 1205:මෙ | 1087:බිත්තර | 1272:රුපියල් | 20:200 | 19:20 | 478:ක්
#   Predicted : 1205:මෙ | 1087:බිත්තර | 1272:රුපියල් | 20:200 | 19:20 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [206/1653] මට රුපියල් හාරසිය අනූතුනක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 49:400 | 125:93 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 49:400 | 125:93 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [207/1653] කිහිල්ල
#   Correct   : 520:කිහිල්ල
#   Predicted : 1425:විහිලු
#   Overlap   : word=0%  id=0%  exact=✗
#
# [208/1653] පාසලට ආදරෙයිද?
#   Correct   : 334:ඉස්කෝලෙ | 699:ට | 245:ආදරය | 779:ද?
#   Predicted : 334:ඉස්කෝලෙ | 699:ට | 245:ආදරය | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [209/1653] අද රැස්වීමට මිනිසුන් දෙසිය දහහතරක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 12:14 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 20:200 | 12:14 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [210/1653] මම කතා කරන්නම්.
#   Correct   : 1128:මම | 439:කතා කරනවා
#   Predicted : 1128:මම | 439:කතා කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [211/1653] මම කෝපි 350 ක් ගත්තා.
#   Correct   : 1128:මම | 574:කෝපි | 35:300 | 63:50 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 574:කෝපි | 35:300 | 63:50 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [212/1653] ගෙවත්තේ ගස් 799 ක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 92:700 | 131:99 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 92:700 | 131:99 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [213/1653] ඔව් අපි පිරිසුදුකමට ගරු කරන්න ඕන.
#   Correct   : 415:ඔව් | 185:අපි | 996:පිරිසුදු කරනවා | 699:ට | 590:ගරු කරනවා | 427:ඕන
#   Predicted : 415:ඔව් | 185:අපි | 996:පිරිසුදු කරනවා | 699:ට | 590:ගරු කරනවා | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [214/1653] මම රුපියල් එකසිය තිස්නවයක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 3:100 | 46:39 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 3:100 | 46:39 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [215/1653] ශ්‍යාමා දැන් සින්දු කියනවාද?
#   Correct   : 1452:ශ් | 1223:යංශය | 241:ආ | 1145:ම් | 241:ආ | 801:දැන් | 625:ගීතයක් | 514:කියනවා | 779:ද?
#   Predicted : 1452:ශ් | 1223:යංශය | 241:ආ | 1145:ම් | 241:ආ | 801:දැන් | 625:ගීතයක් | 514:කියනවා | 779:ද?
#   Overlap   : word=89%  id=89%  exact=✓
#
# [216/1653] අනාගතයට ඕන.
#   Correct   : 176:අනාගතය | 699:ට | 427:ඕන
#   Predicted : 176:අනාගතය | 699:ට | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [217/1653] මම හයසිය හැටදෙක පිටුව කියවනවා.
#   Correct   : 1128:මම | 78:600 | 82:62 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 78:600 | 82:62 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [218/1653] මම 338 වන පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 45:38 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 45:38 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [219/1653] රණ්ඩු වෙන්න එපා.
#   Correct   : 1242:රණ්ඩු කරනවා | 390:එපා
#   Predicted : 1242:රණ්ඩු කරනවා | 390:එපා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [220/1653] හෙට අපි ගෙදරින් කෑම ගේමු.
#   Correct   : 1581:හෙට | 185:අපි | 636:ගෙදර | 637:ගෙන් | 262:ආහාර | 647:ගේනවා
#   Predicted : 1581:හෙට | 185:අපි | 636:ගෙදර | 636:ගෙදර | 262:ආහාර
#   Overlap   : word=67%  id=67%  exact=✗
#
# [221/1653] පිටගැස්ම
#   Correct   : 984:පිටගැස්ම
#   Predicted : 1501:සිටගන්නවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [222/1653] කුමාර හෙට වැඩ කරනවා
#   Correct   : 478:ක් | 342:උ | 1145:ම් | 241:ආ | 1257:ර් | 133:අ | 1581:හෙට | 1383:වැඩ කරනවා
#   Predicted : 478:ක් | 342:උ | 1145:ම් | 241:ආ | 1257:ර් | 133:අ | 1581:හෙට | 1383:වැඩ කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [223/1653] විභාගයේ ප්‍රශ්න 465 ක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 49:400 | 85:65 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 49:400 | 85:65 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [224/1653] මුහු කරනවා
#   Correct   : 1202:මුහු කරනවා
#   Predicted : 1200:මුවහත් කරනවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [225/1653] ඔව් ගුරුතුමී.
#   Correct   : 415:ඔව් | 627:ගුරුතුමිය
#   Predicted : 415:ඔව් | 627:ගුරුතුමිය
#   Overlap   : word=100%  id=100%  exact=✓
#
# [226/1653] වතුර බෝතලය මට දෙන්න.
#   Correct   : 1336:වතුර | 354:උණුවතුර බෝතලය | 1119:මට | 835:දෙන්න
#   Predicted : 1336:වතුර | 354:උණුවතුර බෝතලය | 1119:මට | 835:දෙන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [227/1653] මම අටසිය පහ පිටුව කියවනවා.
#   Correct   : 1128:මම | 106:800 | 62:5 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 106:800 | 62:5 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [228/1653] ගෙවත්තේ ගස් හාරසිය අසූවක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 49:400 | 105:80 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 49:400 | 105:80 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [229/1653] ප්‍රබෝධා හෙට සින්දු කියමු
# ...
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1580/1653] හැමෝම නිශ්ශබ්දව අහනවා
#   Correct   : 1566:හැමෝම | 896:නිශ්ශබ්ද වෙන්න | 237:අහනවා
#   Predicted : 1566:හැමෝම | 896:නිශ්ශබ්ද වෙන්න | 237:අහනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1581/1653] ජනේලය අරින්න
#   Correct   : 679:ජනේලය | 209:අරින්න
#   Predicted : 679:ජනේලය | 209:අරින්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1582/1653] මට කරවිල නවසිය හතළිස්දෙකක් ඕන.
#   Correct   : 1119:මට | 459:කරවිල | 120:900 | 54:42 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 459:කරවිල | 120:900 | 54:42 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1583/1653] ඔබ ජනේලයෙන් පරිසරය නරඹනවා
#   Correct   : 408:ඔබ | 679:ජනේලය | 637:ගෙන් | 922:පරිසරය | 1064:බලනවා
#   Predicted : 408:ඔබ | 679:ජනේලය | 923:පරිස්සම් කරන්න
#   Overlap   : word=40%  id=40%  exact=✗
#
# [1584/1653] ප්‍රදීප් මට උදව් කළා
#   Correct   : 941:ප් | 1239:රකාරාංශය | 796:ද් | 335:ඊ | 941:ප් | 1119:මට | 363:උදව් කරනවා | 330:ඉවරයි
#   Predicted : 941:ප් | 1239:රකාරාංශය | 796:ද් | 335:ඊ | 941:ප් | 1119:මට | 363:උදව් කරනවා | 330:ඉවරයි
#   Overlap   : word=88%  id=88%  exact=✓
#
# [1585/1653] කියලා එන්න.
#   Correct   : 514:කියනවා | 330:ඉවරයි | 389:එනවා
#   Predicted : 514:කියනවා | 330:ඉවරයි | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1586/1653] දැන් පොත් ගන්න.
#   Correct   : 801:දැන් | 1024:පොත | 583:ගන්න
#   Predicted : 801:දැන් | 1024:පොත | 583:ගන්න
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1587/1653] ඔයා දවල් කෑමට මොනවද කන්නේ?
#   Correct   : 408:ඔබ | 793:දවල් | 262:ආහාර | 699:ට | 1216:මොනවද | 442:කනවා
#   Predicted : 408:ඔබ | 793:දවල් | 699:ට | 262:ආහාර | 442:කනවා
#   Overlap   : word=83%  id=83%  exact=✗
#
# [1588/1653] විභාගයේ ප්‍රශ්න තුන්සිය අසූවක් තිබෙනවා.
#   Correct   : 1412:විභාගය | 947:ප්‍රශ්න | 35:300 | 105:80 | 478:ක් | 758:තියෙනවා
#   Predicted : 1412:විභාගය | 947:ප්‍රශ්න | 35:300 | 105:80 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1589/1653] සල්ලි එකතු කරන්න වෙයි.
#   Correct   : 1194:මුදල් | 388:එකතුව | 458:කරන්න
#   Predicted : 1194:මුදල් | 387:එකතු කරනවා
#   Overlap   : word=33%  id=33%  exact=✗
#
# [1590/1653] මට රුපියල් පන්දහස් එකසියයක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 65:5000 | 3:100 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 65:5000 | 3:100 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1591/1653] පැළ වලට අව්ව ඕන.
#   Correct   : 596:ගස | 699:ට | 228:අව්ව | 427:ඕන
#   Predicted : 974:පැය | 699:ට | 229:අව්වට | 427:ඕන
#   Overlap   : word=50%  id=50%  exact=✗
#
# [1592/1653] මම වේලාසනින් එනවා.
#   Correct   : 1128:මම | 1020:පෙර | 389:එනවා
#   Predicted : 1128:මම | 1020:පෙර | 389:එනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1593/1653] ඔබ කොහේද ඉන්නේ?
#   Correct   : 408:ඔබ | 567:කොහේද | 316:ඉන්නවා
#   Predicted : 408:ඔබ | 567:කොහේද | 316:ඉන්නවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1594/1653] මම තුන්සිය හත පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 90:7 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 90:7 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1595/1653] ළමයාට කෝපි තුන්දහස් එකසියයක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 574:කෝපි | 36:3000 | 3:100 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 574:කෝපි | 36:3000 | 3:100 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1596/1653] කෑම පෙට්ටිය හෝදන්න හොඳට
#   Correct   : 508:කෑම පෙට්ටිය | 1534:සෝදනවා | 1587:හොඳ
#   Predicted : 508:කෑම පෙට්ටිය | 1587:හොඳ | 1534:සෝදනවා | 1587:හොඳ | 699:ට
#   Overlap   : word=100%  id=100%  exact=✗
#
# [1597/1653] අද රැස්වීමට මිනිසුන් 427 ක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 49:400 | 30:27 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 49:400 | 30:27 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1598/1653] ඔබ පාසලට ආදරය කරනවා
#   Correct   : 408:ඔබ | 334:ඉස්කෝලෙ | 699:ට | 246:ආදරය කරනවා
#   Predicted : 408:ඔබ | 334:ඉස්කෝලෙ | 699:ට | 246:ආදරය කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1599/1653] ඕෂිනී අද වැඩ කරන්නෙ නැ
#   Correct   : 426:ඕ | 1455:ෂ් | 296:ඉ | 862:න් | 335:ඊ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 426:ඕ | 1455:ෂ් | 296:ඉ | 862:න් | 335:ඊ | 166:අද | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1600/1653] ඉෂානි හෙට පාඩම් කරමු
#   Correct   : 296:ඉ | 1455:ෂ් | 241:ආ | 862:න් | 296:ඉ | 1581:හෙට | 956:පාඩම් කරනවා
#   Predicted : 296:ඉ | 1455:ෂ් | 241:ආ | 862:න් | 296:ඉ | 1581:හෙට | 956:පාඩම් කරනවා
#   Overlap   : word=86%  id=86%  exact=✓
#
# [1601/1653] මිටියි.
#   Correct   : 1170:මිටි
#   Predicted : 1501:සිටගන්නවා
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1602/1653] මට රුපියල් 911 ක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 120:900 | 9:11 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 120:900 | 9:11 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1603/1653] ගෙවත්තේ ගස් එකසිය පනස්හතරක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 3:100 | 70:54 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 3:100 | 70:54 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1604/1653] අපි ක්‍රීඩා පිටියට යමු
#   Correct   : 185:අපි | 484:ක්‍රීඩා පිටිය | 699:ට | 1231:යමු
#   Predicted : 185:අපි | 484:ක්‍රීඩා පිටිය | 699:ට | 1231:යමු
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1605/1653] මට රුපියල් තුනක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 33:3 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 33:3 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1606/1653] මම රතුලූණු143 ක් ගත්තා.
#   Correct   : 1128:මම | 1244:රතුලූණු | 3:100 | 55:43 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1244:රතුලූණු | 3:100 | 55:43 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1607/1653] දැන්ම ගෙනියන්න එපා.
#   Correct   : 801:දැන් | 647:ගේනවා | 390:එපා
#   Predicted : 801:දැන් | 638:ගෙනාවා | 390:එපා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [1608/1653] මම තුන්සිය හැටහතර පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 84:64 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 84:64 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1609/1653] පාඩම ගැන විතරක් කතා කරන්න.
#   Correct   : 956:පාඩම් කරනවා | 1402:විතරක් | 439:කතා කරනවා
#   Predicted : 956:පාඩම් කරනවා | 1382:වැඩ | 478:ක් | 439:කතා කරනවා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [1610/1653] අතුල දැන් වැඩ කරන්නෙ නැ
#   Correct   : 133:අ | 739:ත් | 342:උ | 1292:ල් | 133:අ | 801:දැන් | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 133:අ | 739:ත් | 342:උ | 1292:ල් | 133:අ | 801:දැන් | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=88%  id=88%  exact=✓
#
# [1611/1653] කොළයක් ගන්න.
#   Correct   : 569:කොළ | 478:ක් | 583:ගන්න
#   Predicted : 569:කොළ | 583:ගන්න
#   Overlap   : word=67%  id=67%  exact=✗
#
# [1612/1653] අපි ක්‍රීඩා උත්සවයට ලෑස්ති වෙනවා
#   Correct   : 185:අපි | 485:ක්‍රීඩාව | 357:උත්සවය | 699:ට | 1297:ලෑස්ති වෙනවා
#   Predicted : 185:අපි | 485:ක්‍රීඩාව | 357:උත්සවය | 699:ට | 1297:ලෑස්ති වෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1613/1653] ළමයාට ගෝවා දෙසිය හතළිස්එකක් දෙන්න.
#   Correct   : 1595:ළමයා | 699:ට | 658:ගෝවා | 20:200 | 53:41 | 478:ක් | 834:දෙනවා
#   Predicted : 1595:ළමයා | 699:ට | 658:ගෝවා | 20:200 | 53:41 | 478:ක් | 834:දෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1614/1653] ඔයාට අද සල්ලි තියෙනවද
#   Correct   : 410:ඔබට | 166:අද | 1194:මුදල් | 758:තියෙනවා | 779:ද?
#   Predicted : 410:ඔබට | 166:අද | 1194:මුදල් | 758:තියෙනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1615/1653] මට ඇපල් හාරදහස්අටසියක් ඕන.
#   Correct   : 1119:මට | 277:ඇපල් | 50:4000 | 106:800 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 277:ඇපල් | 50:4000 | 106:800 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1616/1653] මම කෝපි දහහතක් ගත්තා.
#   Correct   : 1128:මම | 574:කෝපි | 15:17 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 574:කෝපි | 15:17 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1617/1653] මම උදව් කරන්නම්.
#   Correct   : 1128:මම | 363:උදව් කරනවා
#   Predicted : 1128:මම | 363:උදව් කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1618/1653] නැහැ හොරකම් කරන්න නරකයි.
#   Correct   : 870:නැ | 1590:හොරකම් කරනවා | 858:නරක
#   Predicted : 870:නැ | 1587:හොඳ | 458:කරන්න
#   Overlap   : word=33%  id=33%  exact=✗
#
# [1619/1653] අද රැස්වීමට මිනිසුන් හැටදෙකක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 82:62 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 82:62 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1620/1653] හවසට සෙල්ලම් කරමු.
#   Correct   : 1550:හවස | 699:ට | 1531:සෙල්ලම් කරනවා
#   Predicted : 1550:හවස | 699:ට | 1531:සෙල්ලම් කරනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1621/1653] පාට කරන්න එපා.
#   Correct   : 952:පාට කරනවා | 390:එපා
#   Predicted : 952:පාට කරනවා | 390:එපා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1622/1653] මිරිස් ගල
#   Correct   : 1177:මිරිස් ගල
#   Predicted : 1152:මාලුමිරිස්
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1623/1653] මම රුපියල් එක්දහස් පන්සියක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 4:1000 | 64:500 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 4:1000 | 64:500 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1624/1653] අද රැස්වීමට මිනිසුන් එකසිය හැත්තෑඅටක් ආවා.
#   Correct   : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 3:100 | 102:78 | 478:ක් | 260:ආවා
#   Predicted : 166:අද | 1264:රැස්වීම | 699:ට | 1010:පුද්ගලයින් | 3:100 | 102:78 | 478:ක් | 260:ආවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1625/1653] අපි හෙට හමුවෙමු.
#   Correct   : 185:අපි | 1581:හෙට | 1546:හමුවෙන්න
#   Predicted : 185:අපි | 1581:හෙට | 1188:මුණගැහෙනවා
#   Overlap   : word=67%  id=67%  exact=✗
#
# [1626/1653] මම 912 පිටුව කියවනවා.
#   Correct   : 1128:මම | 120:900 | 10:12 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 120:900 | 10:12 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1627/1653] කතන්දරයක් කියන්න.
#   Correct   : 438:කතන්දරය | 478:ක් | 514:කියනවා
#   Predicted : 438:කතන්දරය | 478:ක් | 514:කියනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1628/1653] ඔව් අපි ඉගෙන ගන්න ආසයි.
#   Correct   : 415:ඔව් | 185:අපි | 301:ඉගෙන ගන්නවා | 501:කැමති
#   Predicted : 415:ඔව් | 185:අපි | 301:ඉගෙන ගන්නවා | 501:කැමති
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1629/1653] බෙලි
#   Correct   : 1101:බෙලි
#   Predicted : 1097:බෙදීම
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1630/1653] මම අඹ 79000 ක් ගත්තා.
#   Correct   : 1128:මම | 198:අඹ | 94:70000 | 121:9000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 198:අඹ | 94:70000 | 121:9000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1631/1653] මාණික්‍යා දැන් පාඩම් කරමු
#   Correct   : 1145:ම් | 241:ආ | 715:ණ් | 296:ඉ | 478:ක් | 1223:යංශය | 241:ආ | 801:දැන් | 956:පාඩම් කරනවා
#   Predicted : 956:පාඩම් කරනවා | 241:ආ | 715:ණ් | 296:ඉ | 478:ක් | 1223:යංශය | 241:ආ | 801:දැන් | 956:පාඩම් කරනවා
#   Overlap   : word=78%  id=78%  exact=✗
#
# [1632/1653] ඔයා වැසිකිලියට යනවද?
#   Correct   : 408:ඔබ | 1399:වැසිකිලිය | 699:ට | 1229:යනවා | 779:ද?
#   Predicted : 408:ඔබ | 1399:වැසිකිලිය | 699:ට | 1229:යනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1633/1653] ගෙවත්තේ ගස් 537 ක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 64:500 | 44:37 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 64:500 | 44:37 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1634/1653] මේ ගෝවා රුපියල් තුන්සිය හැත්තෑහතක්.
#   Correct   : 1205:මෙ | 658:ගෝවා | 1272:රුපියල් | 35:300 | 101:77 | 478:ක්
#   Predicted : 1205:මෙ | 658:ගෝවා | 1272:රුපියල් | 35:300 | 101:77 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1635/1653] දිනේෂ් දැන් වැඩ කරන්නෙ නැ
#   Correct   : 796:ද් | 296:ඉ | 862:න් | 401:ඒ | 1455:ෂ් | 801:දැන් | 1383:වැඩ කරනවා | 870:නැ
#   Predicted : 796:ද් | 296:ඉ | 862:න් | 401:ඒ | 1455:ෂ් | 801:දැන් | 1383:වැඩ කරනවා | 870:නැ
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1636/1653] මම රුපියල් 545 ක් දුන්නා
#   Correct   : 1128:මම | 1272:රුපියල් | 64:500 | 57:45 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1272:රුපියල් | 64:500 | 57:45 | 478:ක් | 834:දෙනවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1637/1653] ප්‍රශ්න තියෙනවාද?
#   Correct   : 947:ප්‍රශ්න | 758:තියෙනවා | 779:ද?
#   Predicted : 947:ප්‍රශ්න | 758:තියෙනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1638/1653] මේසය අස් කරන්න.
#   Correct   : 1210:මේසය | 165:අතුගාන්න
#   Predicted : 1210:මේසය | 996:පිරිසුදු කරනවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [1639/1653] මට රුපියල් හාරසිය හතළිස්හතක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 49:400 | 59:47 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 49:400 | 59:47 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1640/1653] මම බිත්තර එකසිය අසූතුනක් ගත්තා.
#   Correct   : 1128:මම | 1087:බිත්තර | 3:100 | 111:83 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1087:බිත්තර | 3:100 | 111:83 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1641/1653] ගෙවත්තේ ගස් දහනවයක් තියෙනවා.
#   Correct   : 1335:වත්ත | 596:ගස | 17:19 | 478:ක් | 758:තියෙනවා
#   Predicted : 1335:වත්ත | 596:ගස | 17:19 | 478:ක් | 758:තියෙනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1642/1653] මැයි
#   Correct   : 1161:මැයි
#   Predicted : 1162:මැයි මල
#   Overlap   : word=0%  id=0%  exact=✗
#
# [1643/1653] මම 302 පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 18:2 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 18:2 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1644/1653] මම තුන්සිය පනස්හත පිටුව කියවනවා.
#   Correct   : 1128:මම | 35:300 | 73:57 | 987:පිටුව | 515:කියවනවා
#   Predicted : 1128:මම | 35:300 | 73:57 | 987:පිටුව | 515:කියවනවා
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1645/1653] මම කෙසෙල් 56 ක් ගත්තා.
#   Correct   : 1128:මම | 543:කෙසෙල් | 72:56 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 543:කෙසෙල් | 72:56 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1646/1653] මේ රොටී රුපියල් විසිහතරක්.
#   Correct   : 1205:මෙ | 1281:රොටී | 1272:රුපියල් | 27:24 | 478:ක්
#   Predicted : 1205:මෙ | 1281:රොටී | 1272:රුපියල් | 27:24 | 478:ක්
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1647/1653] මට රුපියල් හත්සිය විසිහතක් ඕන.
#   Correct   : 1119:මට | 1272:රුපියල් | 92:700 | 30:27 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1272:රුපියල් | 92:700 | 30:27 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1648/1653] ගෙයක් පේනවා.
#   Correct   : 636:ගෙදර | 1022:පේනවා
#   Predicted : 1335:වත්ත | 1022:පේනවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [1649/1653] වාඩි වෙන්න පුටුවක් ගේන්නද?
#   Correct   : 1373:වාඩිවෙන්න | 1008:පුටුව | 478:ක් | 647:ගේනවා | 779:ද?
#   Predicted : 1373:වාඩිවෙන්න | 1008:පුටුව | 478:ක් | 647:ගේනවා | 779:ද?
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1650/1653] දත් කැඩෙයි.
#   Correct   : 785:දත් | 434:කඩනවා
#   Predicted : 801:දැන් | 434:කඩනවා
#   Overlap   : word=50%  id=50%  exact=✗
#
# [1651/1653] මම රතුලූණුවිස්සහතරදහසක් ගත්තා.
#   Correct   : 1128:මම | 1244:රතුලූණු | 22:20000 | 50:4000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Predicted : 1128:මම | 1244:රතුලූණු | 22:20000 | 50:4000 | 478:ක් | 584:ගන්නවා | 330:ඉවරයි
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1652/1653] මට බිත්තර තුන්සිය විසිහයක් ඕන.
#   Correct   : 1119:මට | 1087:බිත්තර | 35:300 | 29:26 | 478:ක් | 427:ඕන
#   Predicted : 1119:මට | 1087:බිත්තර | 35:300 | 29:26 | 478:ක් | 427:ඕන
#   Overlap   : word=100%  id=100%  exact=✓
#
# [1653/1653] මාණික්‍යා හෙට පොතක් කියවනවා
#   Correct   : 1145:ම් | 241:ආ | 715:ණ් | 296:ඉ | 478:ක් | 1223:යංශය | 241:ආ | 1581:හෙට | 1024:පොත | 515:කියවනවා
#   Predicted : 1145:ම් | 241:ආ | 715:ණ් | 296:ඉ | 478:ක් | 1223:යංශය | 241:ආ | 1581:හෙට | 1024:පොත | 515:කියවනවා
#   Overlap   : word=90%  id=90%  exact=✓
#
# Eval: 1111.89s  |  Avg: 672.6ms/sentence
# =======================================================
#   TEST RESULTS
# =======================================================
#   Sentences         : 1653
#   Word Overlap      : 84.32%
#   SSL ID Overlap    : 84.24%
#   Position Accuracy : 82.77%
#   Exact Match       : 74.83%
# =======================================================
#
# ✓ Results → /kaggle/working/test_results.csv

# %%
# ═══════════════════════════════════════════════════════════════════════
# TRANSLATE UNSEEN SINHALA SENTENCES
# Every predicted token is GUARANTEED to be a valid SSL sign token.
# No fuzzy matching needed — out-of-vocab is architecturally impossible.
# ═══════════════════════════════════════════════════════════════════════

UNSEEN_SENTENCES = [
    "ඔයා කොහෙද ඉන්නේ",
    "මම ගෙදර යනවා",
    "ඔයාගේ නම මොකක්ද",
    "අපි හෙට ගමට යමු",
    "ඔබට ස්තූතියි",
    "මම 1ට පාසලට එනවා",
    "මම එකට පාසලට එනවා",
    "අපි සියලු දෙනාම නිමල් සමග යනවා",
    "කුමාර හෙට ගෙදර යනවා",
    "ඇය හෙට කතරගම යනවා",
    "ඔහු ඊයෙ ගම්පහ ගියා",
    "ගුරුවරයා අඹ දහයක් ගෙනාවා"
    "අපි හෙට පාසලට එනවද?",
    "අපි හෙට තැබිලි බොමු"
    # ← add more here
]

print("=" * 65)
print("  UNSEEN SENTENCE PREDICTIONS  (SSL-only decoder)")
print("=" * 65)

for text in UNSEEN_SENTENCES:
    result = translate(text, beam_size=4)
    print(f"\nSource     : {result['source']}")
    print(f"SSL output : {result['ssl_string']}")
    print(f"Tokens     :")
    for tok in result["ssl_tokens"]:
        print(f"  {tok['word']:20s} → Sign ID: {tok['sign_id']}")
    print("-" * 65)


def predict_single(sinhala_text: str) -> Dict:
    """Translate a single Sinhala sentence. Usage: predict_single('ඔයා හොඳද')"""
    result = translate(sinhala_text, beam_size=4)
    print(f"Source : {result['source']}")
    print(f"Output : {result['ssl_string']}")
    return result

# predict_single("ඔයා හොඳද")
# Out:
# =================================================================
#   UNSEEN SENTENCE PREDICTIONS  (SSL-only decoder)
# =================================================================
#
# Source     : ඔයා කොහෙද ඉන්නේ
# SSL output : 408:ඔබ | 567:කොහේද | 316:ඉන්නවා
# Tokens     :
#   ඔබ                   → Sign ID: 408
#   කොහේද                → Sign ID: 567
#   ඉන්නවා               → Sign ID: 316
# -----------------------------------------------------------------
#
# Source     : මම ගෙදර යනවා
# SSL output : 1128:මම | 636:ගෙදර | 1229:යනවා
# Tokens     :
#   මම                   → Sign ID: 1128
#   ගෙදර                 → Sign ID: 636
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : ඔයාගේ නම මොකක්ද
# SSL output : 409:ඔබගේ | 857:නම් | 1212:මොකක්ද
# Tokens     :
#   ඔබගේ                 → Sign ID: 409
#   නම්                  → Sign ID: 857
#   මොකක්ද               → Sign ID: 1212
# -----------------------------------------------------------------
#
# Source     : අපි හෙට ගමට යමු
# SSL output : 185:අපි | 1581:හෙට | 1231:යමු
# Tokens     :
#   අපි                  → Sign ID: 185
#   හෙට                  → Sign ID: 1581
#   යමු                  → Sign ID: 1231
# -----------------------------------------------------------------
#
# Source     : ඔබට ස්තූතියි
# SSL output : 410:ඔබට | 1487:ස්තූතියි
# Tokens     :
#   ඔබට                  → Sign ID: 410
#   ස්තූතියි             → Sign ID: 1487
# -----------------------------------------------------------------
#
# Source     : මම 1ට පාසලට එනවා
# SSL output : 1128:මම | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා
# Tokens     :
#   මම                   → Sign ID: 1128
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   එනවා                 → Sign ID: 389
# -----------------------------------------------------------------
#
# Source     : මම එකට පාසලට එනවා
# SSL output : 1128:මම | 334:ඉස්කෝලෙ | 699:ට | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා
# Tokens     :
#   මම                   → Sign ID: 1128
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   එනවා                 → Sign ID: 389
# -----------------------------------------------------------------
#
# Source     : අපි සියලු දෙනාම නිමල් සමග යනවා
# SSL output : 187:අපි සියලු දෙනාම | 388:එකතුව | 834:දෙනවා
# Tokens     :
#   අපි සියලු දෙනාම      → Sign ID: 187
#   එකතුව                → Sign ID: 388
#   දෙනවා                → Sign ID: 834
# -----------------------------------------------------------------
#
# Source     : කුමාර හෙට ගෙදර යනවා
# SSL output : 478:ක් | 342:උ | 1145:ම් | 241:ආ | 1257:ර් | 133:අ | 1581:හෙට | 636:ගෙදර | 1229:යනවා
# Tokens     :
#   ක්                   → Sign ID: 478
#   උ                    → Sign ID: 342
#   ම්                   → Sign ID: 1145
#   ආ                    → Sign ID: 241
#   ර්                   → Sign ID: 1257
#   අ                    → Sign ID: 133
#   හෙට                  → Sign ID: 1581
#   ගෙදර                 → Sign ID: 636
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : ඇය හෙට කතරගම යනවා
# SSL output : 279:ඇය | 1581:හෙට | 133:අ | 1145:ම් | 133:අ | 1597:ළ් | 133:අ | 602:ග් | 133:අ | 1145:ම් | 133:අ | 1229:යනවා
# Tokens     :
#   ඇය                   → Sign ID: 279
#   හෙට                  → Sign ID: 1581
#   අ                    → Sign ID: 133
#   ම්                   → Sign ID: 1145
#   අ                    → Sign ID: 133
#   ළ්                   → Sign ID: 1597
#   අ                    → Sign ID: 133
#   ග්                   → Sign ID: 602
#   අ                    → Sign ID: 133
#   ම්                   → Sign ID: 1145
#   අ                    → Sign ID: 133
#   යනවා                 → Sign ID: 1229
# -----------------------------------------------------------------
#
# Source     : ඔහු ඊයෙ ගම්පහ ගියා
# SSL output : 421:ඔහු | 337:ඊයෙ | 584:ගන්නවා | 330:ඉවරයි
# Tokens     :
#   ඔහු                  → Sign ID: 421
#   ඊයෙ                  → Sign ID: 337
#   ගන්නවා               → Sign ID: 584
#   ඉවරයි                → Sign ID: 330
# -----------------------------------------------------------------
#
# Source     : ගුරුවරයා අඹ දහයක් ගෙනාවාඅපි හෙට පාසලට එනවද?
# SSL output : 627:ගුරුතුමිය | 198:අඹ | 133:අ | 1222:ඹ් | 133:අ | 1257:ර් | 133:අ | 1581:හෙට | 334:ඉස්කෝලෙ | 699:ට | 389:එනවා | 779:ද?
# Tokens     :
#   ගුරුතුමිය            → Sign ID: 627
#   අඹ                   → Sign ID: 198
#   අ                    → Sign ID: 133
#   ඹ්                   → Sign ID: 1222
#   අ                    → Sign ID: 133
#   ර්                   → Sign ID: 1257
#   අ                    → Sign ID: 133
#   හෙට                  → Sign ID: 1581
#   ඉස්කෝලෙ              → Sign ID: 334
#   ට                    → Sign ID: 699
#   එනවා                 → Sign ID: 389
#   ද?                   → Sign ID: 779
# -----------------------------------------------------------------
#
# Source     : අපි හෙට තැබිලි බොමු
# SSL output : 185:අපි | 1581:හෙට | 751:තැඹිලි | 1103:බොනවා
# Tokens     :
#   අපි                  → Sign ID: 185
#   හෙට                  → Sign ID: 1581
#   තැඹිලි               → Sign ID: 751
#   බොනවා                → Sign ID: 1103
# -----------------------------------------------------------------
